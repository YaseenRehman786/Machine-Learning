# %% [markdown]
# # Installation of Pandas and Ucimlrepo

# %%
#!pip install pandas
#!pip install ucimlrepo
#%pip install matplotlib

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo 
import numpy as np
import math
import matplotlib.pyplot as plt
import string
from pprint import pprint
import random

# %% [markdown]
# # Breast Cancer Classification Tree

# %%
# Fetch dataset my version
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# Data (as pandas dataframes) 
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets
z = breast_cancer_wisconsin_diagnostic.targets

# Place the target variable as the last column of your dataset
data = pd.DataFrame(data=X, columns=z)
data['Diagnosis'] = y

# Split the dataset function
def split_data(data, test_size):
    data = data.sample(frac=1)  # Shuffle the data
    train_data = data.iloc[:int(len(data)*(1-test_size))]
    test_data = data.iloc[int(len(data)*(1-test_size)):]
    return train_data, test_data

# Convert all feature columns to strings for consistency
data = data.astype(str)

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)

# Function to calculate entropy
def calculate_entropy(data):
    target_col = data['Diagnosis']
    elements, counts = np.unique(target_col, return_counts=True)
    entropy = sum([-counts[i] / sum(counts) * np.log2(counts[i] / sum(counts)) for i in range(len(elements))])
    return entropy

# Function to calculate information gain
def calculate_information_gain(data, attribute):
    total_entropy = calculate_entropy(data)
    vals, counts = np.unique(data[attribute], return_counts=True)
    weighted_entropy = sum(
        (counts[i] / sum(counts)) * calculate_entropy(data.where(data[attribute] == vals[i]).dropna())
        for i in range(len(vals))
    )
    information_gain = total_entropy - weighted_entropy
    return information_gain

# ID3 Decision Tree Algorithm
def id3(data, original_data, features, target_attribute_name="Diagnosis", parent_node_class=None):
    # Check if all target values are the same
    if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    
    # If dataset is empty, return the mode of the target attribute in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_attribute_name])[np.argmax(np.unique(original_data[target_attribute_name], return_counts=True)[1])]
    
    # If features are empty, return the mode of the target attribute in the dataset
    elif len(features) == 0:
        return parent_node_class
    
    # If none of the above, create the tree recursively
    else:
        parent_node_class = np.unique(data[target_attribute_name])[np.argmax(np.unique(data[target_attribute_name], return_counts=True)[1])]
        item_values = [calculate_information_gain(data, feature) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        
        # Create the tree structure with the best feature as the root
        tree = {best_feature: {}}
        features = [i for i in features if i != best_feature]
        
        # Grow tree branches for each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_attribute_name, parent_node_class)
            tree[best_feature][value] = subtree
            
        return tree

# Train the ID3 decision tree on training data
features = train_data.columns[:-1]  # Exclude the target column
decision_tree = id3(train_data, train_data, features, target_attribute_name="Diagnosis")

# Pretty-print the generated decision tree
pprint(decision_tree)

# Function to predict using the decision tree
def predict(query, tree, default='M'):  # Set default to 'M' or 'B' as needed
    for key in list(query.keys()):
        if key in tree.keys():
            try:
                result = tree[key][query[key]]
            except KeyError:
                return default
            
            # If the result is a subtree, continue down the tree
            if isinstance(result, dict):
                return predict(query, result, default)
            else:
                return result
    return default  # Return the default if no key is found in the tree

# Test the decision tree on the test data
def test_decision_tree(test_data, tree):
    queries = test_data.iloc[:, :-1].to_dict(orient="records")
    predicted = pd.Series([predict(query, tree) for query in queries]).reset_index(drop=True)
    accuracy = np.sum(predicted == test_data['Diagnosis'].reset_index(drop=True)) / len(test_data)
    return accuracy

# Calculate accuracy
accuracy = test_decision_tree(test_data, decision_tree)
print("Accuracy of ID3 Decision Tree:", accuracy)

# Apply the decision tree to the test dataset
predictions = test_data.apply(lambda x: predict(x, decision_tree), axis=1)
print("\nPredictions:")
print(predictions)

# Optional: Compare predictions to actual diagnosis
print("\nActual Values:")
print(test_data['Diagnosis'])

# Function to calculate accuracy
def calculate_accuracy(predictions, actual):
    correct = sum(predictions[i] == actual[i] for i in range(len(predictions)))
    return correct / len(predictions)

# Print accuracy result
print("\nAccuracy:", calculate_accuracy(predictions.tolist(), test_data['Diagnosis'].tolist()))
print(f"\nTest Accuracy: {accuracy*100:.2f}%")
# Out:
# {'smoothness2': {'0.001713': 'B',
#                  '0.002667': 'M',
#                  '0.002826': 'M',
#                  '0.002838': 'B',
#                  '0.002866': 'M',
#                  '0.003139': 'M',
#                  '0.003245': 'B',
#                  '0.003271': 'B',
#                  '0.00328': 'M',
#                  '0.00329': 'M',
#                  '0.003308': 'B',
#                  '0.003338': 'B',
#                  '0.00335': 'M',
#                  '0.003418': 'B',
#                  '0.003443': 'B',
#                  '0.003457': 'B',
#                  '0.003492': 'B',
#                  '0.003495': 'B',
#                  '0.003535': 'B',
#                  '0.003629': 'B',
#                  '0.003632': 'B',
#                  '0.003653': 'B',
#                  '0.003659': 'M',
#                  '0.003681': 'B',
#                  '0.003704': 'B',
#                  '0.003741': 'B',
#                  '0.003818': 'B',
#                  '0.003828': 'B',
#                  '0.003872': 'M',
#                  '0.003888': 'B',
#                  '0.003899': 'M',
#                  '0.003958': 'B',
#                  '0.003978': 'M',
#                  '0.004024': 'M',
#                  '0.004029': 'M',
#                  '0.004044': 'M',
#                  '0.004057': 'M',
#                  '0.004097': 'B',
#                  '0.004107': 'B',
#                  '0.004117': 'M',
#                  '0.004123': 'B',
#                  '0.004147': 'B',
#                  '0.004148': 'B',
#                  '0.004185': 'M',
#                  '0.0042': 'B',
#                  '0.00423': 'B',
#                  '0.004235': 'B',
#                  '0.004242': 'B',
#                  '0.004253': 'M',
#                  '0.004271': 'B',
#                  '0.004314': 'M',
#                  '0.004348': 'B',
#                  '0.004351': 'B',
#                  '0.004359': 'B',
#                  '0.004369': 'B',
#                  '0.004394': 'B',
#                  '0.004405': 'B',
#                  '0.004413': 'B',
#                  '0.004426': 'M',
#                  '0.004428': 'M',
#                  '0.004449': 'B',
#                  '0.00445': 'B',
#                  '0.004474': 'B',
#                  '0.004481': 'B',
#                  '0.004493': 'M',
#                  '0.00451': 'B',
#                  '0.004536': 'M',
#                  '0.004551': 'M',
#                  '0.004563': 'M',
#                  '0.004577': 'B',
#                  '0.004578': 'M',
#                  '0.004599': 'B',
#                  '0.004625': 'M',
#                  '0.004626': 'M',
#                  '0.004631': 'M',
#                  '0.004649': 'M',
#                  '0.004675': 'M',
#                  '0.004714': 'M',
#                  '0.004717': 'M',
#                  '0.004728': 'M',
#                  '0.004729': 'B',
#                  '0.004731': 'B',
#                  '0.004732': 'B',
#                  '0.004756': 'M',
#                  '0.004757': 'M',
#                  '0.004775': 'B',
#                  '0.004796': 'B',
#                  '0.004821': 'M',
#                  '0.004837': 'B',
#                  '0.004854': 'B',
#                  '0.004873': 'B',
#                  '0.004911': 'B',
#                  '0.004938': 'M',
#                  '0.004942': 'B',
#                  '0.004952': 'M',
#                  '0.004957': 'B',
#                  '0.005012': 'B',
#                  '0.005015': 'M',
#                  '0.00502': 'M',
#                  '0.005038': 'M',
#                  '0.005042': 'B',
#                  '0.005043': 'M',
#                  '0.005072': 'M',
#                  '0.00508': 'B',
#                  '0.005089': 'M',
#                  '0.005096': 'B',
#                  '0.005133': 'B',
#                  '0.005158': 'B',
#                  '0.005169': 'B',
#                  '0.005212': 'B',
#                  '0.005215': 'M',
#                  '0.005217': 'B',
#                  '0.005231': 'B',
#                  '0.005233': 'M',
#                  '0.005251': 'B',
#                  '0.005273': 'B',
#                  '0.005283': 'M',
#                  '0.005288': 'M',
#                  '0.005293': 'B',
#                  '0.005296': 'B',
#                  '0.005298': 'B',
#                  '0.005314': 'M',
#                  '0.005324': 'B',
#                  '0.005332': 'B',
#                  '0.005343': 'B',
#                  '0.005345': 'M',
#                  '0.005356': 'B',
#                  '0.005371': 'B',
#                  '0.005393': 'M',
#                  '0.005403': 'B',
#                  '0.005414': 'M',
#                  '0.005415': 'B',
#                  '0.005421': 'B',
#                  '0.005427': 'M',
#                  '0.005433': 'B',
#                  '0.005436': 'B',
#                  '0.005442': 'B',
#                  '0.005444': 'M',
#                  '0.005463': 'B',
#                  '0.005467': 'M',
#                  '0.005485': 'M',
#                  '0.005488': 'B',
#                  '0.005498': 'B',
#                  '0.005501': 'B',
#                  '0.005508': 'B',
#                  '0.005515': 'B',
#                  '0.005517': 'B',
#                  '0.005518': 'B',
#                  '0.005524': 'M',
#                  '0.00553': 'M',
#                  '0.005532': 'M',
#                  '0.005541': 'B',
#                  '0.005551': 'M',
#                  '0.005568': 'M',
#                  '0.005596': 'M',
#                  '0.005607': 'M',
#                  '0.005608': 'B',
#                  '0.005617': 'B',
#                  '0.005627': 'M',
#                  '0.005635': 'M',
#                  '0.005654': 'M',
#                  '0.005687': 'M',
#                  '0.005704': 'B',
#                  '0.005706': 'B',
#                  '0.005724': 'B',
#                  '0.005726': 'M',
#                  '0.005727': 'B',
#                  '0.005731': 'M',
#                  '0.005753': 'M',
#                  '0.005756': 'B',
#                  '0.005768': 'B',
#                  '0.005769': 'M',
#                  '0.005776': 'M',
#                  '0.00579': 'B',
#                  '0.0058': 'B',
#                  '0.00582': 'M',
#                  '0.005833': 'B',
#                  '0.005839': 'M',
#                  '0.005851': 'B',
#                  '0.005857': 'B',
#                  '0.005868': 'B',
#                  '0.005872': 'M',
#                  '0.005878': 'M',
#                  '0.005883': 'B',
#                  '0.005884': 'B',
#                  '0.005888': 'B',
#                  '0.005903': 'M',
#                  '0.00591': 'B',
#                  '0.005919': 'B',
#                  '0.005954': 'B',
#                  '0.00596': 'M',
#                  '0.005969': 'B',
#                  '0.006011': 'B',
#                  '0.006016': 'M',
#                  '0.00604': 'B',
#                  '0.006048': 'M',
#                  '0.006056': 'M',
#                  '0.006064': 'B',
#                  '0.00609': 'M',
#                  '0.006113': 'M',
#                  '0.006122': 'B',
#                  '0.006123': 'M',
#                  '0.006131': 'B',
#                  '0.006133': 'B',
#                  '0.00615': 'M',
#                  '0.006153': 'B',
#                  '0.006174': 'M',
#                  '0.006175': 'B',
#                  '0.006176': 'M',
#                  '0.006208': 'M',
#                  '0.006211': 'M',
#                  '0.006248': 'M',
#                  '0.006261': 'B',
#                  '0.006272': 'B',
#                  '0.006294': 'M',
#                  '0.006298': 'B',
#                  '0.006307': 'B',
#                  '0.006351': 'M',
#                  '0.006356': 'M',
#                  '0.006383': 'B',
#                  '0.006399': 'M',
#                  '0.006418': 'B',
#                  '0.006428': 'M',
#                  '0.006429': 'M',
#                  '0.006432': 'B',
#                  '0.006455': 'M',
#                  '0.006458': 'M',
#                  '0.00647': 'B',
#                  '0.006472': 'B',
#                  '0.006494': 'B',
#                  '0.006513': 'B',
#                  '0.006515': 'M',
#                  '0.006522': 'M',
#                  '0.00653': 'B',
#                  '0.006532': 'M',
#                  '0.006538': 'B',
#                  '0.006543': 'B',
#                  '0.006547': 'B',
#                  '0.006548': 'M',
#                  '0.006578': 'B',
#                  '0.006583': 'B',
#                  '0.006588': 'B',
#                  '0.006652': 'B',
#                  '0.006663': 'B',
#                  '0.006664': 'B',
#                  '0.006666': 'M',
#                  '0.006692': 'B',
#                  '0.006697': 'M',
#                  '0.006708': 'B',
#                  '0.006709': 'B',
#                  '0.006715': 'B',
#                  '0.006719': 'B',
#                  '0.006739': 'B',
#                  '0.006766': 'M',
#                  '0.00677': 'M',
#                  '0.006773': 'B',
#                  '0.006794': 'B',
#                  '0.006804': 'M',
#                  '0.006809': 'B',
#                  '0.006831': 'M',
#                  '0.006836': 'B',
#                  '0.006883': 'M',
#                  '0.006905': 'B',
#                  '0.006908': 'B',
#                  '0.006953': 'B',
#                  '0.006982': 'B',
#                  '0.006983': 'M',
#                  '0.007017': 'B',
#                  '0.007086': 'B',
#                  '0.007089': 'B',
#                  '0.007138': 'B',
#                  '0.007159': 'M',
#                  '0.00718': 'B',
#                  '0.007189': 'B',
#                  '0.00721': 'B',
#                  '0.007231': 'M',
#                  '0.007234': 'B',
#                  '0.007256': 'B',
#                  '0.007257': 'B',
#                  '0.007269': 'M',
#                  '0.007278': 'B',
#                  '0.007295': 'B',
#                  '0.007327': 'B',
#                  '0.007334': 'B',
#                  '0.007339': 'B',
#                  '0.007356': 'B',
#                  '0.007357': 'B',
#                  '0.007364': 'B',
#                  '0.007389': 'B',
#                  '0.007392': 'M',
#                  '0.007405': 'M',
#                  '0.007416': 'B',
#                  '0.00744': 'B',
#                  '0.007491': 'B',
#                  '0.007499': 'M',
#                  '0.007501': 'B',
#                  '0.007509': 'B',
#                  '0.00751': 'M',
#                  '0.007514': 'B',
#                  '0.007517': 'B',
#                  '0.007545': 'M',
#                  '0.007548': 'M',
#                  '0.007594': 'B',
#                  '0.007595': 'B',
#                  '0.00765': 'M',
#                  '0.007702': 'B',
#                  '0.007762': 'B',
#                  '0.007781': 'M',
#                  '0.007802': 'B',
#                  '0.007803': 'B',
#                  '0.007807': 'B',
#                  '0.007809': 'B',
#                  '0.007831': 'B',
#                  '0.007881': 'B',
#                  '0.007897': 'B',
#                  '0.007959': 'M',
#                  '0.007962': 'B',
#                  '0.007964': 'M',
#                  '0.00797': 'M',
#                  '0.007974': 'M',
#                  '0.007997': 'M',
#                  '0.008005': 'M',
#                  '0.008029': 'M',
#                  '0.008034': 'B',
#                  '0.008045': 'B',
#                  '0.008064': 'M',
#                  '0.008074': 'M',
#                  '0.008081': 'M',
#                  '0.008109': 'M',
#                  '0.008124': 'M',
#                  '0.008146': 'B',
#                  '0.008166': 'M',
#                  '0.008198': 'M',
#                  '0.0082': 'B',
#                  '0.008261': 'B',
#                  '0.008268': 'M',
#                  '0.008312': 'M',
#                  '0.00832': 'B',
#                  '0.008412': 'B',
#                  '0.008426': 'B',
#                  '0.008439': 'M',
#                  '0.008462': 'B',
#                  '0.008482': 'M',
#                  '0.008499': 'B',
#                  '0.008534': 'B',
#                  '0.00854': 'B',
#                  '0.008565': 'B',
#                  '0.008577': 'B',
#                  '0.008584': 'B',
#                  '0.008699': 'M',
#                  '0.008725': 'B',
#                  '0.008732': 'B',
#                  '0.00874': 'M',
#                  '0.008805': 'M',
#                  '0.008824': 'M',
#                  '0.008875': 'B',
#                  '0.008902': 'B',
#                  '0.008968': 'B',
#                  '0.008998': 'B',
#                  '0.009019': 'B',
#                  '0.009037': 'M',
#                  '0.009058': 'B',
#                  '0.009087': 'M',
#                  '0.009098': 'M',
#                  '0.00911': 'M',
#                  '0.009113': 'B',
#                  '0.00925': 'M',
#                  '0.009282': 'B',
#                  '0.009327': 'M',
#                  '0.009329': 'M',
#                  '0.009369': 'M',
#                  '0.009406': 'M',
#                  '0.009407': 'M',
#                  '0.009433': 'B',
#                  '0.009501': 'B',
#                  '0.009519': 'B',
#                  '0.009536': 'B',
#                  '0.009538': 'M',
#                  '0.009549': 'B',
#                  '0.009606': 'B',
#                  '0.00968': 'M',
#                  '0.009702': 'B',
#                  '0.009719': 'B',
#                  '0.009783': 'B',
#                  '0.009853': 'B',
#                  '0.009882': 'M',
#                  '0.009895': 'B',
#                  '0.009976': 'B',
#                  '0.01011': 'B',
#                  '0.01015': 'M',
#                  '0.01017': 'B',
#                  '0.01019': 'B',
#                  '0.01027': 'B',
#                  '0.0103': 'M',
#                  '0.01037': 'B',
#                  '0.01038': 'M',
#                  '0.01039': 'B',
#                  '0.01049': 'B',
#                  '0.01052': 'B',
#                  '0.01056': 'M',
#                  '0.01061': 'M',
#                  '0.01072': 'B',
#                  '0.01088': 'M',
#                  '0.01093': 'B',
#                  '0.01094': 'B',
#                  '0.01097': 'B',
#                  '0.01098': 'B',
#                  '0.01113': 'B',
#                  '0.01124': 'M',
#                  '0.01127': 'B',
#                  '0.01134': 'B',
#                  '0.01159': 'B',
#                  '0.01164': 'B',
#                  '0.01188': 'B',
#                  '0.0119': 'M',
#                  '0.01193': 'B',
#                  '0.01205': 'B',
#                  '0.01215': 'B',
#                  '0.01236': 'M',
#                  '0.01266': 'B',
#                  '0.01286': 'B',
#                  '0.01288': 'B',
#                  '0.01289': 'B',
#                  '0.01291': 'B',
#                  '0.01307': 'B',
#                  '0.01345': 'M',
#                  '0.0138': 'B',
#                  '0.01418': 'B',
#                  '0.01439': 'B',
#                  '0.01474': 'B',
#                  '0.01496': 'B',
#                  '0.01546': 'B',
#                  '0.01547': 'B',
#                  '0.01574': 'B',
#                  '0.01582': 'B',
#                  '0.01604': 'B',
#                  '0.01835': 'B',
#                  '0.02075': 'B',
#                  '0.02177': 'B',
#                  '0.02333': 'M',
#                  '0.03113': 'M'}}
# Accuracy of ID3 Decision Tree: 0.3684210526315789
#
# Predictions:
# 216    M
# 528    M
# 128    M
# 165    M
# 51     M
#       ..
# 217    M
# 17     M
# 175    M
# 353    B
# 318    M
# Length: 114, dtype: object
#
# Actual Values:
# 216    B
# 528    B
# 128    B
# 165    B
# 51     B
#       ..
# 217    B
# 17     M
# 175    B
# 353    M
# 318    B
# Name: Diagnosis, Length: 114, dtype: object
#
# Accuracy: 0.3684210526315789
#
# Test Accuracy: 36.84%

# %% [markdown]
# # Mushroom Classification Tree

# %%
# Fetch mushroom dataset
mushroom = fetch_ucirepo(id=73)

# Extract features and target variable
X = mushroom.data.features  # Attributes
y = mushroom.data.targets   # Target variable
z = mushroom.targets        # Feature names

# Create a DataFrame and add the target column ('poisonous') as the last column
data = pd.DataFrame(data=X, columns=z)
data['poisonous'] = y

# Convert all feature columns to strings to ensure consistent data types
data = data.astype(str)

# Function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1)  # Shuffle the data
    train_data = data.iloc[:int(len(data)*(1-test_size))]  # 80% training data
    test_data = data.iloc[int(len(data)*(1-test_size)):]   # 20% testing data
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)

# Function to calculate entropy
def calculate_entropy(data):
    target_col = data['poisonous']
    elements, counts = np.unique(target_col, return_counts=True)
    entropy = sum([-counts[i]/sum(counts) * np.log2(counts[i]/sum(counts)) for i in range(len(elements))])
    return entropy

# Function to calculate information gain
def calculate_information_gain(data, attribute):
    total_entropy = calculate_entropy(data)
    vals, counts = np.unique(data[attribute], return_counts=True)
    weighted_entropy = sum((counts[i]/sum(counts)) * calculate_entropy(data.where(data[attribute] == vals[i]).dropna()) for i in range(len(vals)))
    information_gain = total_entropy - weighted_entropy
    return information_gain

# ID3 Decision Tree Algorithm
def id3(data, original_data, features, target_attribute_name="poisonous", parent_node_class=None):
    # Check if all target values are the same
    if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    
    # If dataset is empty, return the mode of the target attribute in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_attribute_name])[np.argmax(np.unique(original_data[target_attribute_name], return_counts=True)[1])]
    
    # If features are empty, return the mode of the target attribute in the dataset
    elif len(features) == 0:
        return parent_node_class
    
    # If none of the above, create the tree recursively
    else:
        parent_node_class = np.unique(data[target_attribute_name])[np.argmax(np.unique(data[target_attribute_name], return_counts=True)[1])]
        item_values = [calculate_information_gain(data, feature) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        
        # Create the tree structure with the best feature as the root
        tree = {best_feature: {}}
        features = [i for i in features if i != best_feature]
        
        # Grow tree branches for each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_attribute_name, parent_node_class)
            tree[best_feature][value] = subtree
            
        return tree

# Train the ID3 decision tree on training data
features = train_data.columns[:-1]  # Exclude the target column
decision_tree = id3(train_data, train_data, features)

# Pretty-print the generated decision tree
pprint(decision_tree)

# Function to predict using the decision tree
def predict(query, tree, default='poisonous'):
    for key in list(query.keys()):
        if key in tree.keys():
            try:
                result = tree[key][query[key]]
            except:
                return default
            
            # If the result is not a subtree, return the result
            if isinstance(result, dict):
                return predict(query, result)
            else:
                return result

# Test the decision tree on the test data
def test_decision_tree(test_data, tree):
    queries = test_data.iloc[:, :-1].to_dict(orient="records")
    predicted = pd.Series([predict(query, tree) for query in queries])
    predicted.index = test_data.index  # Align indices
    accuracy = np.sum(predicted == test_data['poisonous']) / len(test_data)
    return accuracy

# Calculate accuracy
accuracy = test_decision_tree(test_data, decision_tree)
print("Accuracy of ID3 Decision Tree:", accuracy)

# Apply the decision tree to the test dataset
predictions = test_data.apply(lambda x: predict(x, decision_tree), axis=1)
print("\nPredictions:")
print(predictions)

# Optional: Compare predictions to actual diagnosis
print("\nActual Values:")
print(test_data['poisonous'])

def accuracy(predictions, actual):
    correct = 0
    for i in range(len(predictions)):
        if predictions[i] == actual[i]:
            correct += 1
    return correct / len(predictions)

print("\nAccuracy:")
print(accuracy(predictions.tolist(), test_data['poisonous'].tolist()))
print(f"\nTest Accuracy: {accuracy(predictions.tolist(), test_data['poisonous'].tolist())*100:.2f}%")
# Out:
# {'odor': {'a': 'e',
#           'c': 'p',
#           'f': 'p',
#           'l': 'e',
#           'm': 'p',
#           'n': {'spore-print-color': {'b': 'e',
#                                       'h': 'e',
#                                       'k': 'e',
#                                       'n': 'e',
#                                       'o': 'e',
#                                       'r': 'p',
#                                       'w': {'habitat': {'d': {'gill-size': {'b': 'e',
#                                                                             'n': 'p'}},
#                                                         'g': 'e',
#                                                         'l': {'cap-color': {'c': 'e',
#                                                                             'n': 'e',
#                                                                             'w': 'p',
#                                                                             'y': 'p'}},
#                                                         'p': 'e',
#                                                         'w': 'e'}},
#                                       'y': 'e'}},
#           'p': 'p',
#           's': 'p',
#           'y': 'p'}}
# Accuracy of ID3 Decision Tree: 1.0
#
# Predictions:
# 850     e
# 7306    e
# 111     e
# 5499    p
# 942     p
#        ..
# 4335    p
# 167     e
# 3903    p
# 1387    e
# 5335    e
# Length: 1625, dtype: object
#
# Actual Values:
# 850     e
# 7306    e
# 111     e
# 5499    p
# 942     p
#        ..
# 4335    p
# 167     e
# 3903    p
# 1387    e
# 5335    e
# Name: poisonous, Length: 1625, dtype: object
#
# Accuracy:
# 1.0
#
# Test Accuracy: 100.00%

# %% [markdown]
# # Letter Recognition Regression Tree

# %%
# Fetch the Letter Recognition dataset
letter_recognition = fetch_ucirepo(id=59)

# Data (as pandas dataframes)
X = letter_recognition.data.features  # Features (attributes)
y = letter_recognition.data.targets   # Target variable (lettr)
z = letter_recognition.data.feature_names  # Attribute names

# Place the target variable ('lettr') column as the last column in your data
data = pd.DataFrame(data=X, columns=z)
data['lettr'] = y  # Add the target variable to the dataframe

# Function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1)  # Shuffle the data
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * (1 - test_size)):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)
X_train, y_train = train_data.iloc[:, :-1], train_data[['lettr']]
X_test, y_test = test_data.iloc[:, :-1], test_data[['lettr']]

# Select a random subset of 5 features
all_features = X_train.columns
selected_features = random.sample(list(all_features), 3)
print("Selected Features:", selected_features)

# Function to calculate variance for categorical target
def calculate_variance(data):
    target_col = data['lettr']
    variance = np.var(target_col.astype('category').cat.codes)
    return variance

# Function to calculate variance reduction for a split
def calculate_variance_reduction(data, attribute):
    total_variance = calculate_variance(data)
    vals, counts = np.unique(data[attribute], return_counts=True)
    weighted_variance = sum(
        (counts[i] / sum(counts)) * calculate_variance(data.where(data[attribute] == vals[i]).dropna())
        for i in range(len(vals))
    )
    variance_reduction = total_variance - weighted_variance
    return variance_reduction

# ID3 Regression Tree Algorithm
def id3_regression(data, original_data, features, target_attribute_name="lettr", parent_node_value=None):
    # If all target values have the same value, return that value
    if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    
    # If dataset is empty, return the mode of the target attribute in the original dataset
    elif len(data) == 0:
        return original_data[target_attribute_name].mode()[0]
    
    # If features are empty, return the mode of the target attribute in the dataset
    elif len(features) == 0:
        return parent_node_value
    
    # If none of the above, create the tree recursively
    else:
        parent_node_value = data[target_attribute_name].mode()[0]
        item_values = [calculate_variance_reduction(data, feature) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        
        # Create the tree structure with the best feature as the root
        tree = {best_feature: {}}
        features = [i for i in features if i != best_feature]
        
        # Grow tree branches for each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3_regression(sub_data, original_data, features, target_attribute_name, parent_node_value)
            tree[best_feature][value] = subtree
            
        return tree

# Train the ID3 regression tree on the selected 5 features
regression_tree = id3_regression(pd.concat([X_train[selected_features], y_train], axis=1), pd.concat([X_train[selected_features], y_train], axis=1), selected_features)

# Pretty-print the generated regression tree
pprint(regression_tree)

# Function to predict using the regression tree
def predict_regression(query, tree, default='A'):
    for key in list(query.keys()):
        if key in tree.keys():
            try:
                result = tree[key][query[key]]
            except KeyError:
                return default
            
            # If the result is a subtree, continue down the tree
            if isinstance(result, dict):
                return predict_regression(query, result, default)
            else:
                return result
    return default  # Return the default if no key is found in the tree

# Test the regression tree on the test data
def test_regression_tree(test_data, tree):
    queries = test_data[selected_features].to_dict(orient="records")
    predicted = pd.Series([predict_regression(query, tree) for query in queries], index=test_data.index)
    return predicted

# Predict the values for the test set
predictions = test_regression_tree(X_test, regression_tree)

# Print actual vs predicted values
print("\nActual vs Predicted:")
print(pd.DataFrame({'Actual': y_test['lettr'], 'Predicted': predictions}))

# Calculate accuracy
accuracy = np.sum(predictions == y_test['lettr']) / len(y_test)
print("\nAccuracy of ID3 Regression Tree:", accuracy)
print(f"\nTest Accuracy: {accuracy*100:.2f}%")
# Out:
# Selected Features: ['xybar', 'yegvx', 'x-bar']
# {'x-bar': {np.int64(0): {'xybar': {np.float64(0.0): 'L',
#                                    np.float64(1.0): 'L',
#                                    np.float64(11.0): 'F',
#                                    np.float64(12.0): 'F',
#                                    np.float64(13.0): 'F'}},
#            np.int64(1): {'xybar': {np.float64(0.0): 'L',
#                                    np.float64(1.0): 'L',
#                                    np.float64(9.0): 'W',
#                                    np.float64(10.0): 'W',
#                                    np.float64(11.0): {'yegvx': {np.float64(5.0): 'W',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(5.0): 'F',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F'}},
#                                    np.float64(13.0): 'F'}},
#            np.int64(2): {'xybar': {np.float64(0.0): 'L',
#                                    np.float64(1.0): 'L',
#                                    np.float64(2.0): 'L',
#                                    np.float64(7.0): 'E',
#                                    np.float64(9.0): {'yegvx': {np.float64(5.0): 'W',
#                                                                np.float64(6.0): 'W',
#                                                                np.float64(7.0): 'V'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(4.0): 'K',
#                                                                 np.float64(6.0): 'W',
#                                                                 np.float64(7.0): 'W',
#                                                                 np.float64(8.0): 'V'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(4.0): 'K',
#                                                                 np.float64(5.0): 'K',
#                                                                 np.float64(6.0): 'V',
#                                                                 np.float64(7.0): 'V',
#                                                                 np.float64(8.0): 'V'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'F'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(7.0): 'V',
#                                                                 np.float64(8.0): 'V'}}}},
#            np.int64(3): {'xybar': {np.float64(1.0): 'L',
#                                    np.float64(2.0): 'L',
#                                    np.float64(3.0): {'yegvx': {np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'L',
#                                                                np.float64(8.0): 'M'}},
#                                    np.float64(4.0): 'M',
#                                    np.float64(5.0): 'E',
#                                    np.float64(6.0): {'yegvx': {np.float64(9.0): 'E',
#                                                                np.float64(10.0): 'E',
#                                                                np.float64(11.0): 'K'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(6.0): 'E',
#                                                                np.float64(7.0): 'E',
#                                                                np.float64(8.0): 'E',
#                                                                np.float64(9.0): 'E',
#                                                                np.float64(10.0): 'E',
#                                                                np.float64(11.0): 'K'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(7.0): 'V',
#                                                                np.float64(9.0): 'E'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(3.0): 'U',
#                                                                np.float64(4.0): 'U',
#                                                                np.float64(5.0): 'V',
#                                                                np.float64(6.0): 'V',
#                                                                np.float64(7.0): 'V',
#                                                                np.float64(8.0): 'V',
#                                                                np.float64(9.0): 'C'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(4.0): 'U',
#                                                                 np.float64(5.0): 'V',
#                                                                 np.float64(6.0): 'V',
#                                                                 np.float64(7.0): 'V',
#                                                                 np.float64(8.0): 'V'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(4.0): 'Y',
#                                                                 np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(7.0): 'Y',
#                                                                 np.float64(8.0): 'Y'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(4.0): 'Y',
#                                                                 np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(7.0): 'Y',
#                                                                 np.float64(8.0): 'Y'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(4.0): 'Y',
#                                                                 np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(7.0): 'U'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(6.0): 'Y',
#                                                                 np.float64(8.0): 'N'}}}},
#            np.int64(4): {'xybar': {np.float64(1.0): 'L',
#                                    np.float64(2.0): 'L',
#                                    np.float64(3.0): {'yegvx': {np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'N',
#                                                                np.float64(8.0): 'N'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(6.0): 'U',
#                                                                np.float64(7.0): 'M',
#                                                                np.float64(8.0): 'M'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'C'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'L',
#                                                                np.float64(10.0): 'L',
#                                                                np.float64(11.0): 'K'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(5.0): 'W',
#                                                                np.float64(7.0): 'L',
#                                                                np.float64(8.0): 'K',
#                                                                np.float64(9.0): 'K',
#                                                                np.float64(10.0): 'K',
#                                                                np.float64(11.0): 'K'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(5.0): 'W',
#                                                                np.float64(6.0): 'W',
#                                                                np.float64(7.0): 'V',
#                                                                np.float64(8.0): 'W',
#                                                                np.float64(9.0): 'C'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(1.0): 'U',
#                                                                np.float64(3.0): 'W',
#                                                                np.float64(4.0): 'W',
#                                                                np.float64(5.0): 'W',
#                                                                np.float64(6.0): 'W',
#                                                                np.float64(7.0): 'W',
#                                                                np.float64(8.0): 'W',
#                                                                np.float64(9.0): 'C'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(3.0): 'Y',
#                                                                 np.float64(4.0): 'P',
#                                                                 np.float64(5.0): 'P',
#                                                                 np.float64(6.0): 'P',
#                                                                 np.float64(7.0): 'P',
#                                                                 np.float64(8.0): 'P'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(3.0): 'Y',
#                                                                 np.float64(4.0): 'Y',
#                                                                 np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(7.0): 'Y',
#                                                                 np.float64(8.0): 'Y',
#                                                                 np.float64(9.0): 'C'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(3.0): 'T',
#                                                                 np.float64(4.0): 'C',
#                                                                 np.float64(5.0): 'C',
#                                                                 np.float64(6.0): 'C',
#                                                                 np.float64(7.0): 'C',
#                                                                 np.float64(8.0): 'C'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(3.0): 'T',
#                                                                 np.float64(4.0): 'F',
#                                                                 np.float64(5.0): 'F',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'N',
#                                                                 np.float64(9.0): 'N'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(7.0): 'F',
#                                                                 np.float64(9.0): 'N'}}}},
#            np.int64(5): {'xybar': {np.float64(1.0): 'L',
#                                    np.float64(2.0): 'L',
#                                    np.float64(3.0): {'yegvx': {np.float64(2.0): 'A',
#                                                                np.float64(4.0): 'A',
#                                                                np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'L'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(3.0): 'A',
#                                                                np.float64(5.0): 'U',
#                                                                np.float64(6.0): 'U',
#                                                                np.float64(7.0): 'U',
#                                                                np.float64(8.0): 'U'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'D',
#                                                                np.float64(7.0): 'D',
#                                                                np.float64(8.0): 'D',
#                                                                np.float64(9.0): 'D',
#                                                                np.float64(10.0): 'C'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(5.0): 'K',
#                                                                np.float64(6.0): 'K',
#                                                                np.float64(7.0): 'K',
#                                                                np.float64(8.0): 'K',
#                                                                np.float64(9.0): 'K',
#                                                                np.float64(10.0): 'K',
#                                                                np.float64(11.0): 'K'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(2.0): 'S',
#                                                                np.float64(5.0): 'R',
#                                                                np.float64(6.0): 'R',
#                                                                np.float64(7.0): 'R',
#                                                                np.float64(8.0): 'R',
#                                                                np.float64(9.0): 'R',
#                                                                np.float64(10.0): 'R',
#                                                                np.float64(11.0): 'R'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(0.0): 'S',
#                                                                np.float64(1.0): 'C',
#                                                                np.float64(2.0): 'U',
#                                                                np.float64(3.0): 'C',
#                                                                np.float64(4.0): 'C',
#                                                                np.float64(5.0): 'C',
#                                                                np.float64(6.0): 'C',
#                                                                np.float64(7.0): 'C',
#                                                                np.float64(8.0): 'C',
#                                                                np.float64(9.0): 'C',
#                                                                np.float64(10.0): 'C',
#                                                                np.float64(11.0): 'C'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(3.0): 'P',
#                                                                np.float64(4.0): 'P',
#                                                                np.float64(5.0): 'P',
#                                                                np.float64(6.0): 'P',
#                                                                np.float64(7.0): 'P',
#                                                                np.float64(8.0): 'P',
#                                                                np.float64(9.0): 'P',
#                                                                np.float64(10.0): 'P'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(3.0): 'Y',
#                                                                 np.float64(4.0): 'F',
#                                                                 np.float64(5.0): 'F',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'F',
#                                                                 np.float64(9.0): 'G',
#                                                                 np.float64(10.0): 'F'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(2.0): 'F',
#                                                                 np.float64(3.0): 'T',
#                                                                 np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'T',
#                                                                 np.float64(6.0): 'T',
#                                                                 np.float64(7.0): 'T',
#                                                                 np.float64(8.0): 'T'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(2.0): 'Z',
#                                                                 np.float64(3.0): 'T',
#                                                                 np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'T',
#                                                                 np.float64(6.0): 'T',
#                                                                 np.float64(7.0): 'T',
#                                                                 np.float64(8.0): 'T'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'F',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'F',
#                                                                 np.float64(9.0): 'N'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(7.0): 'F'}},
#                                    np.float64(15.0): 'J'}},
#            np.int64(6): {'xybar': {np.float64(2.0): 'L',
#                                    np.float64(3.0): {'yegvx': {np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'U',
#                                                                np.float64(7.0): 'U'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(4.0): 'A',
#                                                                np.float64(5.0): 'A',
#                                                                np.float64(6.0): 'A',
#                                                                np.float64(7.0): 'A',
#                                                                np.float64(8.0): 'A',
#                                                                np.float64(9.0): 'C'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(3.0): 'U',
#                                                                np.float64(4.0): 'A',
#                                                                np.float64(5.0): 'C',
#                                                                np.float64(6.0): 'C',
#                                                                np.float64(7.0): 'C',
#                                                                np.float64(8.0): 'C',
#                                                                np.float64(9.0): 'C',
#                                                                np.float64(10.0): 'L',
#                                                                np.float64(12.0): 'W'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(2.0): 'U',
#                                                                np.float64(3.0): 'U',
#                                                                np.float64(4.0): 'U',
#                                                                np.float64(5.0): 'R',
#                                                                np.float64(6.0): 'R',
#                                                                np.float64(7.0): 'R',
#                                                                np.float64(8.0): 'R',
#                                                                np.float64(9.0): 'R',
#                                                                np.float64(10.0): 'R',
#                                                                np.float64(11.0): 'R',
#                                                                np.float64(12.0): 'L',
#                                                                np.float64(13.0): 'R'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(1.0): 'S',
#                                                                np.float64(3.0): 'S',
#                                                                np.float64(4.0): 'R',
#                                                                np.float64(5.0): 'R',
#                                                                np.float64(6.0): 'R',
#                                                                np.float64(7.0): 'R',
#                                                                np.float64(8.0): 'R',
#                                                                np.float64(9.0): 'R',
#                                                                np.float64(10.0): 'R',
#                                                                np.float64(11.0): 'R',
#                                                                np.float64(12.0): 'R',
#                                                                np.float64(13.0): 'K'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(1.0): 'S',
#                                                                np.float64(3.0): 'C',
#                                                                np.float64(4.0): 'C',
#                                                                np.float64(5.0): 'C',
#                                                                np.float64(6.0): 'C',
#                                                                np.float64(7.0): 'C',
#                                                                np.float64(8.0): 'C',
#                                                                np.float64(9.0): 'C',
#                                                                np.float64(10.0): 'C',
#                                                                np.float64(11.0): 'C',
#                                                                np.float64(12.0): 'F'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(4.0): 'G',
#                                                                np.float64(5.0): 'G',
#                                                                np.float64(6.0): 'G',
#                                                                np.float64(7.0): 'G',
#                                                                np.float64(8.0): 'G',
#                                                                np.float64(9.0): 'G',
#                                                                np.float64(10.0): 'G',
#                                                                np.float64(11.0): 'G'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(2.0): 'F',
#                                                                 np.float64(4.0): 'K',
#                                                                 np.float64(5.0): 'K',
#                                                                 np.float64(6.0): 'K',
#                                                                 np.float64(7.0): 'K',
#                                                                 np.float64(8.0): 'K',
#                                                                 np.float64(9.0): 'K',
#                                                                 np.float64(10.0): 'K',
#                                                                 np.float64(11.0): 'E'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(3.0): 'T',
#                                                                 np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'T',
#                                                                 np.float64(6.0): 'T',
#                                                                 np.float64(7.0): 'T',
#                                                                 np.float64(8.0): 'T',
#                                                                 np.float64(9.0): 'T',
#                                                                 np.float64(10.0): 'T'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(3.0): 'Z',
#                                                                 np.float64(4.0): 'P',
#                                                                 np.float64(5.0): 'P',
#                                                                 np.float64(6.0): 'P',
#                                                                 np.float64(7.0): 'P',
#                                                                 np.float64(8.0): 'P',
#                                                                 np.float64(9.0): 'P'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'F',
#                                                                 np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'F',
#                                                                 np.float64(9.0): 'F'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                 np.float64(7.0): 'F',
#                                                                 np.float64(8.0): 'F',
#                                                                 np.float64(9.0): 'P'}},
#                                    np.float64(15.0): 'J'}},
#            np.int64(7): {'xybar': {np.float64(3.0): {'yegvx': {np.float64(6.0): 'N',
#                                                                np.float64(7.0): 'N'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(6.0): 'N',
#                                                                np.float64(7.0): 'N',
#                                                                np.float64(8.0): 'N',
#                                                                np.float64(9.0): 'G'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(4.0): 'N',
#                                                                np.float64(5.0): 'N',
#                                                                np.float64(6.0): 'N',
#                                                                np.float64(7.0): 'N',
#                                                                np.float64(8.0): 'N',
#                                                                np.float64(9.0): 'N',
#                                                                np.float64(10.0): 'N',
#                                                                np.float64(11.0): 'N'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(3.0): 'S',
#                                                                np.float64(4.0): 'G',
#                                                                np.float64(5.0): 'G',
#                                                                np.float64(6.0): 'G',
#                                                                np.float64(7.0): 'G',
#                                                                np.float64(8.0): 'G',
#                                                                np.float64(9.0): 'G',
#                                                                np.float64(10.0): 'G',
#                                                                np.float64(11.0): 'G',
#                                                                np.float64(12.0): 'G'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(1.0): 'A',
#                                                                np.float64(2.0): 'I',
#                                                                np.float64(3.0): 'I',
#                                                                np.float64(4.0): 'I',
#                                                                np.float64(5.0): 'I',
#                                                                np.float64(6.0): 'I',
#                                                                np.float64(7.0): 'I',
#                                                                np.float64(8.0): 'I',
#                                                                np.float64(9.0): 'I',
#                                                                np.float64(10.0): 'I',
#                                                                np.float64(11.0): 'I',
#                                                                np.float64(12.0): 'I',
#                                                                np.float64(13.0): 'K',
#                                                                np.float64(14.0): 'K'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(2.0): 'S',
#                                                                np.float64(3.0): 'S',
#                                                                np.float64(4.0): 'L',
#                                                                np.float64(5.0): 'L',
#                                                                np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'L',
#                                                                np.float64(8.0): 'L',
#                                                                np.float64(9.0): 'L',
#                                                                np.float64(10.0): 'L',
#                                                                np.float64(11.0): 'L',
#                                                                np.float64(12.0): 'L'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(3.0): 'F',
#                                                                np.float64(4.0): 'Y',
#                                                                np.float64(5.0): 'Z',
#                                                                np.float64(6.0): 'Z',
#                                                                np.float64(7.0): 'Z',
#                                                                np.float64(8.0): 'Z',
#                                                                np.float64(9.0): 'Z',
#                                                                np.float64(10.0): 'Z',
#                                                                np.float64(11.0): 'Z',
#                                                                np.float64(12.0): 'W'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(3.0): 'Y',
#                                                                 np.float64(4.0): 'H',
#                                                                 np.float64(5.0): 'H',
#                                                                 np.float64(6.0): 'H',
#                                                                 np.float64(7.0): 'H',
#                                                                 np.float64(8.0): 'H',
#                                                                 np.float64(9.0): 'H',
#                                                                 np.float64(10.0): 'H',
#                                                                 np.float64(11.0): 'H'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'E',
#                                                                 np.float64(6.0): 'E',
#                                                                 np.float64(7.0): 'E',
#                                                                 np.float64(8.0): 'E',
#                                                                 np.float64(9.0): 'E',
#                                                                 np.float64(10.0): 'E',
#                                                                 np.float64(11.0): 'E'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(4.0): 'T',
#                                                                 np.float64(5.0): 'P',
#                                                                 np.float64(6.0): 'P',
#                                                                 np.float64(7.0): 'P',
#                                                                 np.float64(8.0): 'P',
#                                                                 np.float64(9.0): 'P',
#                                                                 np.float64(10.0): 'L'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(5.0): 'I',
#                                                                 np.float64(6.0): 'I',
#                                                                 np.float64(7.0): 'I',
#                                                                 np.float64(8.0): 'I',
#                                                                 np.float64(9.0): 'I',
#                                                                 np.float64(10.0): 'J'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                 np.float64(7.0): 'I',
#                                                                 np.float64(8.0): 'I',
#                                                                 np.float64(9.0): 'P'}},
#                                    np.float64(15.0): 'J'}},
#            np.int64(8): {'xybar': {np.float64(3.0): {'yegvx': {np.float64(6.0): 'U',
#                                                                np.float64(7.0): 'N'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(6.0): 'N',
#                                                                np.float64(7.0): 'S',
#                                                                np.float64(8.0): 'S',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(5.0): 'Q',
#                                                                np.float64(6.0): 'Q',
#                                                                np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(11.0): 'Q',
#                                                                np.float64(13.0): 'Q',
#                                                                np.float64(14.0): 'Q'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(3.0): 'Q',
#                                                                np.float64(4.0): 'Q',
#                                                                np.float64(5.0): 'Q',
#                                                                np.float64(6.0): 'Q',
#                                                                np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(11.0): 'Q',
#                                                                np.float64(12.0): 'Q',
#                                                                np.float64(13.0): 'Q',
#                                                                np.float64(14.0): 'Q',
#                                                                np.float64(15.0): 'Q'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(0.0): 'N',
#                                                                np.float64(1.0): 'S',
#                                                                np.float64(3.0): 'O',
#                                                                np.float64(4.0): 'O',
#                                                                np.float64(5.0): 'O',
#                                                                np.float64(6.0): 'O',
#                                                                np.float64(7.0): 'O',
#                                                                np.float64(8.0): 'O',
#                                                                np.float64(9.0): 'O',
#                                                                np.float64(10.0): 'O',
#                                                                np.float64(11.0): 'O',
#                                                                np.float64(12.0): 'O',
#                                                                np.float64(13.0): 'O',
#                                                                np.float64(14.0): 'O'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(3.0): 'Q',
#                                                                np.float64(4.0): 'Q',
#                                                                np.float64(5.0): 'Q',
#                                                                np.float64(6.0): 'Q',
#                                                                np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(11.0): 'Q',
#                                                                np.float64(12.0): 'R',
#                                                                np.float64(13.0): 'C'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(2.0): 'I',
#                                                                np.float64(4.0): 'O',
#                                                                np.float64(5.0): 'O',
#                                                                np.float64(6.0): 'O',
#                                                                np.float64(7.0): 'O',
#                                                                np.float64(8.0): 'O',
#                                                                np.float64(9.0): 'O',
#                                                                np.float64(10.0): 'O',
#                                                                np.float64(11.0): 'O',
#                                                                np.float64(12.0): 'R'}},
#                                    np.float64(10.0): {'yegvx': {np.float64(5.0): 'B',
#                                                                 np.float64(6.0): 'B',
#                                                                 np.float64(7.0): 'B',
#                                                                 np.float64(8.0): 'B',
#                                                                 np.float64(9.0): 'B',
#                                                                 np.float64(10.0): 'B',
#                                                                 np.float64(11.0): 'B'}},
#                                    np.float64(11.0): {'yegvx': {np.float64(5.0): 'Z',
#                                                                 np.float64(6.0): 'Z',
#                                                                 np.float64(7.0): 'Z',
#                                                                 np.float64(8.0): 'Z',
#                                                                 np.float64(9.0): 'Z',
#                                                                 np.float64(10.0): 'Z',
#                                                                 np.float64(11.0): 'Z'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(6.0): 'Z',
#                                                                 np.float64(7.0): 'Z',
#                                                                 np.float64(8.0): 'Z',
#                                                                 np.float64(9.0): 'Z',
#                                                                 np.float64(10.0): 'Z',
#                                                                 np.float64(11.0): 'L'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(6.0): 'F',
#                                                                 np.float64(7.0): 'I',
#                                                                 np.float64(8.0): 'I',
#                                                                 np.float64(9.0): 'I',
#                                                                 np.float64(10.0): 'I'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                 np.float64(7.0): 'J',
#                                                                 np.float64(8.0): 'J',
#                                                                 np.float64(9.0): 'J'}},
#                                    np.float64(15.0): 'J'}},
#            np.int64(9): {'xybar': {np.float64(2.0): 'U',
#                                    np.float64(3.0): {'yegvx': {np.float64(6.0): 'Y',
#                                                                np.float64(7.0): 'N',
#                                                                np.float64(8.0): 'V',
#                                                                np.float64(9.0): 'Y',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(11.0): 'Q'}},
#                                    np.float64(4.0): {'yegvx': {np.float64(6.0): 'Q',
#                                                                np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(12.0): 'Q',
#                                                                np.float64(13.0): 'Q'}},
#                                    np.float64(5.0): {'yegvx': {np.float64(5.0): 'Q',
#                                                                np.float64(6.0): 'Q',
#                                                                np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): 'Q',
#                                                                np.float64(10.0): 'Q',
#                                                                np.float64(12.0): 'Q',
#                                                                np.float64(13.0): 'Q'}},
#                                    np.float64(6.0): {'yegvx': {np.float64(4.0): 'Y',
#                                                                np.float64(5.0): 'Y',
#                                                                np.float64(6.0): 'Y',
#                                                                np.float64(7.0): 'Y',
#                                                                np.float64(8.0): 'Y',
#                                                                np.float64(9.0): 'Y',
#                                                                np.float64(10.0): 'Y',
#                                                                np.float64(11.0): 'Y',
#                                                                np.float64(15.0): 'L'}},
#                                    np.float64(7.0): {'yegvx': {np.float64(3.0): 'D',
#                                                                np.float64(4.0): 'D',
#                                                                np.float64(5.0): 'D',
#                                                                np.float64(6.0): 'D',
#                                                                np.float64(7.0): 'D',
#                                                                np.float64(8.0): 'D',
#                                                                np.float64(9.0): 'D',
#                                                                np.float64(10.0): 'D',
#                                                                np.float64(11.0): 'D',
#                                                                np.float64(12.0): 'S'}},
#                                    np.float64(8.0): {'yegvx': {np.float64(4.0): 'A',
#                                                                np.float64(5.0): 'A',
#                                                                np.float64(6.0): 'A',
#                                                                np.float64(7.0): 'A',
#                                                                np.float64(8.0): 'A',
#                                                                np.float64(9.0): 'A',
#                                                                np.float64(10.0): 'A',
#                                                                np.float64(11.0): 'A',
#                                                                np.float64(12.0): 'A'}},
#                                    np.float64(9.0): {'yegvx': {np.float64(4.0): 'J',
# ...
#                                                                 np.float64(7.0): 'D',
#                                                                 np.float64(8.0): 'D',
#                                                                 np.float64(9.0): 'D',
#                                                                 np.float64(10.0): 'D',
#                                                                 np.float64(11.0): 'D',
#                                                                 np.float64(12.0): 'D',
#                                                                 np.float64(13.0): 'E'}},
#                                    np.float64(12.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                 np.float64(7.0): 'J',
#                                                                 np.float64(8.0): 'J',
#                                                                 np.float64(9.0): 'J',
#                                                                 np.float64(10.0): 'J',
#                                                                 np.float64(11.0): 'I'}},
#                                    np.float64(13.0): {'yegvx': {np.float64(7.0): 'P',
#                                                                 np.float64(8.0): 'P',
#                                                                 np.float64(9.0): 'P',
#                                                                 np.float64(10.0): 'P',
#                                                                 np.float64(11.0): 'I'}},
#                                    np.float64(14.0): {'yegvx': {np.float64(7.0): 'J',
#                                                                 np.float64(8.0): 'J',
#                                                                 np.float64(9.0): 'J',
#                                                                 np.float64(10.0): 'P'}},
#                                    np.float64(15.0): 'J'}},
#            np.int64(10): {'xybar': {np.float64(2.0): 'Y',
#                                     np.float64(3.0): {'yegvx': {np.float64(9.0): 'Y',
#                                                                 np.float64(10.0): 'Q'}},
#                                     np.float64(4.0): {'yegvx': {np.float64(5.0): 'N',
#                                                                 np.float64(6.0): 'T',
#                                                                 np.float64(7.0): 'W',
#                                                                 np.float64(8.0): 'T',
#                                                                 np.float64(9.0): 'Q',
#                                                                 np.float64(10.0): 'Q'}},
#                                     np.float64(5.0): {'yegvx': {np.float64(5.0): 'W',
#                                                                 np.float64(6.0): 'M',
#                                                                 np.float64(7.0): 'W',
#                                                                 np.float64(8.0): 'W',
#                                                                 np.float64(9.0): 'T',
#                                                                 np.float64(11.0): 'Q'}},
#                                     np.float64(6.0): {'yegvx': {np.float64(3.0): 'Y',
#                                                                 np.float64(4.0): 'Y',
#                                                                 np.float64(5.0): 'Y',
#                                                                 np.float64(6.0): 'Y',
#                                                                 np.float64(8.0): 'Y',
#                                                                 np.float64(10.0): 'S'}},
#                                     np.float64(7.0): {'yegvx': {np.float64(4.0): 'W',
#                                                                 np.float64(5.0): 'W',
#                                                                 np.float64(6.0): 'W',
#                                                                 np.float64(7.0): 'W',
#                                                                 np.float64(8.0): 'W',
#                                                                 np.float64(9.0): 'W',
#                                                                 np.float64(10.0): 'H',
#                                                                 np.float64(11.0): 'S',
#                                                                 np.float64(12.0): 'S'}},
#                                     np.float64(8.0): {'yegvx': {np.float64(4.0): 'M',
#                                                                 np.float64(5.0): 'A',
#                                                                 np.float64(6.0): 'A',
#                                                                 np.float64(7.0): 'A',
#                                                                 np.float64(8.0): 'A',
#                                                                 np.float64(9.0): 'A'}},
#                                     np.float64(9.0): {'yegvx': {np.float64(4.0): 'I',
#                                                                 np.float64(5.0): 'A',
#                                                                 np.float64(6.0): 'A',
#                                                                 np.float64(7.0): 'A',
#                                                                 np.float64(8.0): 'A',
#                                                                 np.float64(9.0): 'A',
#                                                                 np.float64(10.0): 'A',
#                                                                 np.float64(11.0): 'A',
#                                                                 np.float64(12.0): 'K',
#                                                                 np.float64(13.0): 'K'}},
#                                     np.float64(10.0): {'yegvx': {np.float64(7.0): 'R',
#                                                                  np.float64(8.0): 'R',
#                                                                  np.float64(9.0): 'R',
#                                                                  np.float64(10.0): 'R',
#                                                                  np.float64(11.0): 'R',
#                                                                  np.float64(12.0): 'R',
#                                                                  np.float64(13.0): 'Q'}},
#                                     np.float64(11.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                  np.float64(7.0): 'J',
#                                                                  np.float64(8.0): 'J',
#                                                                  np.float64(9.0): 'J',
#                                                                  np.float64(10.0): 'J',
#                                                                  np.float64(11.0): 'J',
#                                                                  np.float64(12.0): 'J',
#                                                                  np.float64(13.0): 'Q'}},
#                                     np.float64(12.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                  np.float64(7.0): 'J',
#                                                                  np.float64(8.0): 'J',
#                                                                  np.float64(9.0): 'J',
#                                                                  np.float64(10.0): 'J',
#                                                                  np.float64(11.0): 'J',
#                                                                  np.float64(12.0): 'J'}},
#                                     np.float64(13.0): {'yegvx': {np.float64(6.0): 'N',
#                                                                  np.float64(7.0): 'I',
#                                                                  np.float64(8.0): 'I',
#                                                                  np.float64(9.0): 'I',
#                                                                  np.float64(10.0): 'I'}},
#                                     np.float64(14.0): {'yegvx': {np.float64(6.0): 'J',
#                                                                  np.float64(7.0): 'J',
#                                                                  np.float64(8.0): 'J',
#                                                                  np.float64(10.0): 'I',
#                                                                  np.float64(11.0): 'I'}},
#                                     np.float64(15.0): 'J'}},
#            np.int64(11): {'yegvx': {np.float64(6.0): {'xybar': {np.float64(4.0): 'M',
#                                                                 np.float64(8.0): 'M',
#                                                                 np.float64(12.0): 'J'}},
#                                     np.float64(7.0): {'xybar': {np.float64(4.0): 'M',
#                                                                 np.float64(5.0): 'W',
#                                                                 np.float64(9.0): 'J',
#                                                                 np.float64(10.0): 'J',
#                                                                 np.float64(11.0): 'J'}},
#                                     np.float64(8.0): {'xybar': {np.float64(5.0): 'W',
#                                                                 np.float64(6.0): 'W',
#                                                                 np.float64(8.0): 'A',
#                                                                 np.float64(9.0): 'A',
#                                                                 np.float64(10.0): 'A',
#                                                                 np.float64(11.0): 'A',
#                                                                 np.float64(12.0): 'J',
#                                                                 np.float64(13.0): 'J',
#                                                                 np.float64(14.0): 'J',
#                                                                 np.float64(15.0): 'J'}},
#                                     np.float64(9.0): {'xybar': {np.float64(8.0): 'A',
#                                                                 np.float64(9.0): 'A',
#                                                                 np.float64(10.0): 'A',
#                                                                 np.float64(11.0): 'A',
#                                                                 np.float64(12.0): 'A',
#                                                                 np.float64(13.0): 'A'}},
#                                     np.float64(10.0): {'xybar': {np.float64(9.0): 'R',
#                                                                  np.float64(10.0): 'R',
#                                                                  np.float64(11.0): 'R',
#                                                                  np.float64(12.0): 'R'}},
#                                     np.float64(11.0): {'xybar': {np.float64(8.0): 'H',
#                                                                  np.float64(9.0): 'Q',
#                                                                  np.float64(10.0): 'A',
#                                                                  np.float64(11.0): 'A',
#                                                                  np.float64(12.0): 'A'}},
#                                     np.float64(12.0): {'xybar': {np.float64(8.0): 'H',
#                                                                  np.float64(9.0): 'D',
#                                                                  np.float64(10.0): 'Q',
#                                                                  np.float64(11.0): 'Q',
#                                                                  np.float64(12.0): 'Q'}},
#                                     np.float64(13.0): {'xybar': {np.float64(11.0): 'Q',
#                                                                  np.float64(12.0): 'Q'}}}},
#            np.int64(12): {'yegvx': {np.float64(6.0): 'M',
#                                     np.float64(7.0): {'xybar': {np.float64(9.0): 'A',
#                                                                 np.float64(10.0): 'A',
#                                                                 np.float64(13.0): 'N'}},
#                                     np.float64(8.0): {'xybar': {np.float64(8.0): 'I',
#                                                                 np.float64(9.0): 'J',
#                                                                 np.float64(10.0): 'J',
#                                                                 np.float64(11.0): 'J',
#                                                                 np.float64(12.0): 'J',
#                                                                 np.float64(13.0): 'J',
#                                                                 np.float64(14.0): 'J'}},
#                                     np.float64(9.0): {'xybar': {np.float64(9.0): 'A',
#                                                                 np.float64(10.0): 'A',
#                                                                 np.float64(11.0): 'A',
#                                                                 np.float64(12.0): 'A'}},
#                                     np.float64(10.0): {'xybar': {np.float64(8.0): 'A',
#                                                                  np.float64(11.0): 'A',
#                                                                  np.float64(12.0): 'A'}},
#                                     np.float64(11.0): {'xybar': {np.float64(9.0): 'J',
#                                                                  np.float64(10.0): 'Z',
#                                                                  np.float64(11.0): 'A',
#                                                                  np.float64(12.0): 'A'}},
#                                     np.float64(12.0): {'xybar': {np.float64(10.0): 'Q',
#                                                                  np.float64(11.0): 'Q',
#                                                                  np.float64(12.0): 'I'}},
#                                     np.float64(13.0): 'Q',
#                                     np.float64(14.0): 'Q'}},
#            np.int64(13): {'yegvx': {np.float64(8.0): {'xybar': {np.float64(10.0): 'A',
#                                                                 np.float64(11.0): 'M',
#                                                                 np.float64(12.0): 'J',
#                                                                 np.float64(13.0): 'J',
#                                                                 np.float64(14.0): 'J'}},
#                                     np.float64(9.0): {'xybar': {np.float64(11.0): 'A',
#                                                                 np.float64(12.0): 'A',
#                                                                 np.float64(13.0): 'M'}},
#                                     np.float64(10.0): 'A',
#                                     np.float64(12.0): 'Z'}},
#            np.int64(14): {'yegvx': {np.float64(8.0): 'J',
#                                     np.float64(9.0): 'A',
#                                     np.float64(10.0): 'A'}},
#            np.int64(15): 'J'}}
#
# Actual vs Predicted:
#       Actual Predicted
# 15451      C         R
# 10094      X         C
# 9552       W         R
# 934        R         I
# 18876      D         O
# ...      ...       ...
# 1427       J         D
# 1100       Z         P
# 1856       A         Q
# 1904       D         R
# 1528       J         Q
#
# [4000 rows x 2 columns]
#
# Accuracy of ID3 Regression Tree: 0.27375
#
# Test Accuracy: 27.38%

# %% [markdown]
# # Adaboost and Random Forest Letter Recognition

# %%
import numpy as np
import pandas as pd
import random
from pprint import pprint

# Parameters for AdaBoost and Random Forest
NUM_TREES = 4  # Number of trees for ensemble
NUM_FEATURES = 4  # Number of random features per tree

# Fetch the Letter Recognition dataset
letter_recognition = fetch_ucirepo(id=59)

# Data (as pandas dataframes)
X = letter_recognition.data.features  # Features (attributes)
y = letter_recognition.data.targets   # Target variable (lettr)
z = letter_recognition.data.feature_names  # Attribute names

# Place the target variable ('lettr') column as the last column in your data
data = pd.DataFrame(data=X, columns=z)
data['lettr'] = y  # Add the target variable to the dataframe

# Function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1)  # Shuffle the data
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * test_size):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)
X_train, y_train = train_data.iloc[:, :-1], train_data[['lettr']]
X_test, y_test = test_data.iloc[:, :-1], test_data[['lettr']]

all_features = X_train.columns
selected_features = random.sample(list(all_features), 3)


# Function to calculate variance for categorical target
def calculate_variance(data):
    target_col = data['lettr']
    variance = np.var(target_col.astype('category').cat.codes)
    return variance

# Function to calculate variance reduction for a split
def calculate_variance_reduction(data, attribute):
    total_variance = calculate_variance(data)
    vals, counts = np.unique(data[attribute], return_counts=True)
    weighted_variance = sum(
        (counts[i] / sum(counts)) * calculate_variance(data.where(data[attribute] == vals[i]).dropna())
        for i in range(len(vals))
    )
    variance_reduction = total_variance - weighted_variance
    return variance_reduction

# ID3 Regression Tree Algorithm
def id3_regression(data, original_data, features, target_attribute_name="lettr", parent_node_value=None):
    if len(np.unique(data[target_attribute_name])) <= 1:
        return np.unique(data[target_attribute_name])[0]
    elif len(data) == 0:
        return original_data[target_attribute_name].mode()[0]
    elif len(features) == 0:
        return parent_node_value
    else:
        parent_node_value = data[target_attribute_name].mode()[0]
        item_values = [calculate_variance_reduction(data, feature) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        
        tree = {best_feature: {}}
        features = [i for i in features if i != best_feature]
        
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3_regression(sub_data, original_data, features, target_attribute_name, parent_node_value)
            tree[best_feature][value] = subtree
            
        return tree

# Function to predict using the regression tree
def predict_regression(query, tree, default='A'):
    for key in list(query.keys()):
        if key in tree.keys():
            try:
                result = tree[key][query[key]]
            except KeyError:
                return default
            if isinstance(result, dict):
                return predict_regression(query, result, default)
            else:
                return result
    return default

# Test the regression tree on the test data
def test_regression_tree(test_data, tree):
    queries = test_data.to_dict(orient="records")
    predicted = pd.Series([predict_regression(query, tree) for query in queries], index=test_data.index)
    return predicted

# AdaBoost Implementation with Index Alignment Fix
def adaboost(train_data, num_trees=NUM_TREES):
    weights = pd.Series(np.ones(len(train_data)) / len(train_data), index=train_data.index)
    classifiers = []
    alphas = []
    
    for i in range(num_trees):
        # Sample according to weights
        train_data_weighted = train_data.sample(frac=1, weights=weights, replace=True).reset_index(drop=True)
        features = random.sample(list(X_train.columns), NUM_FEATURES)
        
        # Train weak learner
        tree = id3_regression(train_data_weighted, train_data_weighted, features)
        
        # Calculate errors and alpha
        predictions = test_regression_tree(train_data_weighted[features], tree)
        misclassified = (predictions != train_data_weighted['lettr']).astype(int)
        
        # Calculate error rate with weighted misclassifications
        error = np.sum(weights * misclassified) / np.sum(weights)
        
        # If error is 0 or 1, stop to avoid division by zero or extreme values in alpha calculation
        if error == 0 or error == 1:
            break
            
        alpha = 0.5 * np.log((1 - error) / (error + 1e-10))
        alphas.append(alpha)
        classifiers.append(tree)
        
        # Update weights with the correct alignment
        weights = weights * np.exp(alpha * misclassified)
        weights /= weights.sum()  # Normalize weights to sum to 1
    
    return classifiers, alphas

# Function to predict using AdaBoost
def adaboost_predict(classifiers, alphas, X):
    results = pd.DataFrame()
    for i, tree in enumerate(classifiers):
        predictions = test_regression_tree(X, tree)
        results[i] = predictions.map(lambda x: alphas[i] if x == 'A' else -alphas[i])
    return results.sum(axis=1).map(lambda x: 'A' if x > 0 else 'B')  # Example of majority voting

# Random Forest Implementation
def random_forest(train_data, num_trees=NUM_TREES):
    classifiers = []
    
    for i in range(num_trees):
        # Bootstrap sample and feature subset
        sample_data = train_data.sample(frac=0.8, replace=True)
        features = random.sample(list(X_train.columns), NUM_FEATURES)
        
        # Train tree
        tree = id3_regression(sample_data, sample_data, features)
        classifiers.append(tree)
    
    return classifiers

# Function to predict using Random Forest
def random_forest_predict(classifiers, X):
    results = pd.DataFrame()
    for i, tree in enumerate(classifiers):
        results[i] = test_regression_tree(X, tree)
    return results.mode(axis=1)[0]  # Majority voting

# Train AdaBoost and Random Forest models


classifiers_adaboost, alphas = adaboost(train_data)
classifiers_rf = random_forest(train_data)

# Test predictions
print("\nAdaBoost Predictions:")
adaboost_preds = adaboost_predict(classifiers_adaboost, alphas, X_test[selected_features])
print(adaboost_preds)

print("\nRandom Forest Predictions:")
rf_preds = random_forest_predict(classifiers_rf, X_test[selected_features])
print(rf_preds)

# Calculate AdaBoost accuracy
adaboost_accuracy = np.sum(adaboost_preds == y_test['lettr']) / len(y_test)
print("\nAdaBoost Accuracy:", adaboost_accuracy)

print("\nActual vs Predicted:")
print(pd.DataFrame({'Actual': y_test['lettr'], 'AdaBoost Predicted': adaboost_preds, 'Random Forest Predicted': rf_preds}))

# Calculate Random Forest accuracy
rf_accuracy = np.sum(rf_preds == y_test['lettr']) / len(y_test)
print("\nRandom Forest Accuracy:", rf_accuracy)
print(f"\nTest Accuracy: {accuracy*100:.2f}%")
# Out:
# AdaBoost Predictions:
# 717      A
# 3512     A
# 7666     A
# 2434     A
# 1464     A
#         ..
# 19518    A
# 12025    A
# 16719    A
# 12370    A
# 10269    A
# Length: 16000, dtype: object
#
# Random Forest Predictions:
# 717      A
# 3512     A
# 7666     A
# 2434     A
# 1464     A
#         ..
# 19518    A
# 12025    A
# 16719    A
# 12370    A
# 10269    A
# Name: 0, Length: 16000, dtype: object
#
# AdaBoost Accuracy: 0.0399375
#
# Actual vs Predicted:
#       Actual AdaBoost Predicted Random Forest Predicted
# 717        J                  A                       A
# 3512       B                  A                       A
# 7666       T                  A                       A
# 2434       F                  A                       A
# 1464       Z                  A                       A
# ...      ...                ...                     ...
# 19518      G                  A                       A
# 12025      C                  A                       A
# 16719      E                  A                       A
# 12370      T                  A                       A
# 10269      H                  A                       A
#
# [16000 rows x 3 columns]
#
# Random Forest Accuracy: 0.0399375
#
# Test Accuracy: 27.38%

# %% [markdown]
# # Letter Recognition Classification Tree

# %%
# Fetch the Letter Recognition dataset
letter_recognition = fetch_ucirepo(id=59)

# Data (as pandas DataFrames)
X = letter_recognition.data.features  # Features
y = letter_recognition.data.targets   # Target variable (lettr)
z = letter_recognition.data.feature_names  # Attribute names

# Combine features and target into a single DataFrame
data = pd.DataFrame(data=X, columns=z)
data['lettr'] = y  # Add the target variable to the DataFrame

# Function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1, random_state=42)  # Shuffle with a fixed seed for reproducibility
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * test_size):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)
X_train, y_train = train_data.iloc[:, :-1], train_data[['lettr']]
X_test, y_test = test_data.iloc[:, :-1], test_data[['lettr']]

# Select a random subset of 5 features
all_features = X_train.columns
selected_features = random.sample(list(all_features), 5)
print("Selected Features:", selected_features)

# Calculate entropy
def entropy(data, target_col):
    values, counts = np.unique(data[target_col], return_counts=True)
    entropy = -sum((counts[i] / np.sum(counts)) * np.log2(counts[i] / np.sum(counts)) for i in range(len(values)))
    return entropy

# Calculate information gain
def info_gain(data, split_attribute, target_col):
    total_entropy = entropy(data, target_col)
    values, counts = np.unique(data[split_attribute], return_counts=True)
    weighted_entropy = sum((counts[i] / np.sum(counts)) * entropy(data[data[split_attribute] == values[i]], target_col)
                           for i in range(len(values)))
    return total_entropy - weighted_entropy

# ID3 algorithm to build the classification tree
def id3(data, original_data, features, target_col, parent_node=None):
    unique_targets = np.unique(data[target_col])

    # If all target values are the same, return that value
    if len(unique_targets) == 1:
        return unique_targets[0]

    # If the dataset is empty, return the mode target in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_col])[np.argmax(np.unique(original_data[target_col], return_counts=True)[1])]

    # If there are no more features to split on, return the parent node
    elif len(features) == 0:
        return parent_node

    # Otherwise, select the best feature to split on
    else:
        # Set the default value for the parent node (majority class)
        parent_node = np.unique(data[target_col])[np.argmax(np.unique(data[target_col], return_counts=True)[1])]
        
        # Select the feature with the highest information gain
        item_gains = [info_gain(data, feature, target_col) for feature in features]
        best_feature_index = np.argmax(item_gains)
        best_feature = features[best_feature_index]
        
        # Create the tree structure
        tree = {best_feature: {}}
        
        # Remove the best feature from the list of features
        features = [f for f in features if f != best_feature]
        
        # Grow a branch under each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_col, parent_node)
            tree[best_feature][value] = subtree
        
        return tree

# Build the tree using the ID3 algorithm with the selected subset of features
target_col = 'lettr'
tree = id3(train_data, train_data, selected_features, target_col)
print("\nID3 Classification Tree for Letter Recognition Dataset:")
pprint(tree)

# Prediction function to classify new data based on the tree
def predict(tree, instance):
    if not isinstance(tree, dict):
        return tree
    feature = next(iter(tree))
    value = instance[feature]
    if value in tree[feature]:
        return predict(tree[feature][value], instance)
    else:
        return None  # Handle unseen feature values gracefully

# Evaluate the model on the test data
def evaluate(tree, test_data, target_col):
    predictions = test_data.apply(lambda x: predict(tree, x), axis=1)
    actual_values = test_data[target_col]
    accuracy = (predictions == actual_values).mean() * 100
    print("\nPredicted vs Actual:")
    for pred, actual in zip(predictions, actual_values):
        print(f"Predicted: {pred}, Actual: {actual}")
    print(f"\nAccuracy: {accuracy:.2f}%")
    return accuracy

# Test and evaluate the tree
accuracy = evaluate(tree, test_data, target_col)
print(f"\nTest Accuracy: {accuracy:.2f}%")
# Out:
# Selected Features: ['y-box', 'high', 'y2bar', 'xegvy', 'onpix']
#
# ID3 Classification Tree for Letter Recognition Dataset:
# {'xegvy': {np.int64(1): {'y-box': {np.float64(9.0): 'Q',
#                                    np.float64(10.0): 'M',
#                                    np.float64(11.0): 'M',
#                                    np.float64(12.0): 'M',
#                                    np.float64(13.0): 'M',
#                                    np.float64(14.0): 'M',
#                                    np.float64(15.0): 'M'}},
#            np.int64(2): {'y-box': {np.float64(7.0): 'K',
#                                    np.float64(9.0): 'M',
#                                    np.float64(10.0): 'M',
#                                    np.float64(11.0): 'A',
#                                    np.float64(12.0): 'M',
#                                    np.float64(13.0): {'y2bar': {np.float64(1.0): 'A',
#                                                                 np.float64(2.0): 'M'}},
#                                    np.float64(14.0): 'A',
#                                    np.float64(15.0): 'A'}},
#            np.int64(3): {'onpix': {np.float64(3.0): {'high': {np.float64(4.0): 'M',
#                                                               np.float64(5.0): 'A',
#                                                               np.float64(6.0): 'A'}},
#                                    np.float64(4.0): {'y-box': {np.float64(9.0): 'M',
#                                                                np.float64(10.0): {'high': {np.float64(5.0): {'y2bar': {np.float64(2.0): 'A'}},
#                                                                                            np.float64(6.0): 'M'}},
#                                                                np.float64(11.0): 'A',
#                                                                np.float64(12.0): 'M',
#                                                                np.float64(13.0): 'A'}},
#                                    np.float64(5.0): {'y-box': {np.float64(12.0): 'A',
#                                                                np.float64(14.0): {'y2bar': {np.float64(2.0): 'A',
#                                                                                             np.float64(3.0): 'M'}},
#                                                                np.float64(15.0): 'A'}},
#                                    np.float64(6.0): 'M',
#                                    np.float64(7.0): 'K',
#                                    np.float64(8.0): 'Q',
#                                    np.float64(9.0): 'B',
#                                    np.float64(10.0): {'y-box': {np.float64(8.0): 'M',
#                                                                 np.float64(10.0): 'Q'}}}},
#            np.int64(4): {'y2bar': {np.float64(0.0): {'y-box': {np.float64(9.0): 'M',
#                                                                np.float64(14.0): 'A'}},
#                                    np.float64(1.0): {'onpix': {np.float64(3.0): 'A',
#                                                                np.float64(4.0): 'A',
#                                                                np.float64(5.0): 'M',
#                                                                np.float64(7.0): 'M'}},
#                                    np.float64(2.0): {'high': {np.float64(4.0): {'y-box': {np.float64(5.0): 'A',
#                                                                                           np.float64(9.0): {'onpix': {np.float64(3.0): 'A'}}}},
#                                                               np.float64(5.0): {'onpix': {np.float64(3.0): 'A',
#                                                                                           np.float64(4.0): 'M'}},
#                                                               np.float64(6.0): 'A',
#                                                               np.float64(7.0): 'A',
#                                                               np.float64(8.0): 'A'}},
#                                    np.float64(3.0): {'high': {np.float64(5.0): 'M',
#                                                               np.float64(6.0): 'A',
#                                                               np.float64(8.0): 'M'}},
#                                    np.float64(4.0): {'onpix': {np.float64(3.0): 'M',
#                                                                np.float64(5.0): 'K',
#                                                                np.float64(6.0): 'K',
#                                                                np.float64(7.0): {'y-box': {np.float64(8.0): 'K',
#                                                                                            np.float64(9.0): 'Q'}},
#                                                                np.float64(8.0): 'K',
#                                                                np.float64(10.0): 'K'}},
#                                    np.float64(5.0): {'y-box': {np.float64(5.0): 'Q',
#                                                                np.float64(6.0): 'Q',
#                                                                np.float64(7.0): {'high': {np.float64(5.0): 'M',
#                                                                                           np.float64(6.0): 'Q'}},
#                                                                np.float64(8.0): 'A',
#                                                                np.float64(9.0): 'K',
#                                                                np.float64(10.0): 'M',
#                                                                np.float64(14.0): 'H',
#                                                                np.float64(15.0): 'B'}},
#                                    np.float64(6.0): {'y-box': {np.float64(7.0): 'Q',
#                                                                np.float64(8.0): 'D',
#                                                                np.float64(10.0): 'R',
#                                                                np.float64(11.0): 'B',
#                                                                np.float64(12.0): 'B'}},
#                                    np.float64(7.0): {'high': {np.float64(7.0): 'L',
#                                                               np.float64(8.0): 'R'}},
#                                    np.float64(8.0): {'y-box': {np.float64(8.0): 'T',
#                                                                np.float64(9.0): 'T',
#                                                                np.float64(10.0): 'R',
#                                                                np.float64(14.0): 'Z'}},
#                                    np.float64(10.0): 'Z'}},
#            np.int64(5): {'y2bar': {np.float64(0.0): 'M',
#                                    np.float64(1.0): {'high': {np.float64(2.0): 'A',
#                                                               np.float64(3.0): 'A',
#                                                               np.float64(4.0): {'y-box': {np.float64(3.0): 'M',
#                                                                                           np.float64(6.0): 'M',
#                                                                                           np.float64(9.0): 'A'}},
#                                                               np.float64(5.0): 'M',
#                                                               np.float64(6.0): 'M',
#                                                               np.float64(7.0): 'M',
#                                                               np.float64(8.0): 'M'}},
#                                    np.float64(2.0): {'onpix': {np.float64(1.0): 'A',
#                                                                np.float64(2.0): 'A',
#                                                                np.float64(3.0): 'A',
#                                                                np.float64(4.0): {'y-box': {np.float64(5.0): 'M',
#                                                                                            np.float64(7.0): 'A',
#                                                                                            np.float64(8.0): 'A',
#                                                                                            np.float64(9.0): 'A',
#                                                                                            np.float64(10.0): 'A',
#                                                                                            np.float64(13.0): 'A',
#                                                                                            np.float64(15.0): 'A'}},
#                                                                np.float64(5.0): 'A',
#                                                                np.float64(6.0): 'A',
#                                                                np.float64(7.0): 'M',
#                                                                np.float64(8.0): 'M',
#                                                                np.float64(9.0): 'M',
#                                                                np.float64(10.0): 'M',
#                                                                np.float64(11.0): 'M'}},
#                                    np.float64(3.0): {'onpix': {np.float64(2.0): 'M',
#                                                                np.float64(3.0): 'M',
#                                                                np.float64(4.0): {'y-box': {np.float64(7.0): 'A',
#                                                                                            np.float64(10.0): 'M',
#                                                                                            np.float64(11.0): 'A',
#                                                                                            np.float64(12.0): 'A'}},
#                                                                np.float64(5.0): {'y-box': {np.float64(6.0): 'K',
#                                                                                            np.float64(7.0): 'K',
#                                                                                            np.float64(9.0): 'A'}},
#                                                                np.float64(6.0): {'y-box': {np.float64(5.0): 'R',
#                                                                                            np.float64(11.0): 'A'}},
#                                                                np.float64(7.0): {'y-box': {np.float64(10.0): {'high': {np.float64(8.0): 'K'}}}},
#                                                                np.float64(8.0): 'Q',
#                                                                np.float64(9.0): {'y-box': {np.float64(7.0): 'M',
#                                                                                            np.float64(8.0): 'H'}},
#                                                                np.float64(10.0): 'M',
#                                                                np.float64(12.0): 'M'}},
#                                    np.float64(4.0): {'y-box': {np.float64(1.0): 'M',
#                                                                np.float64(2.0): 'M',
#                                                                np.float64(3.0): 'M',
#                                                                np.float64(4.0): 'M',
#                                                                np.float64(5.0): {'onpix': {np.float64(3.0): 'Q',
#                                                                                            np.float64(4.0): 'M'}},
#                                                                np.float64(6.0): 'M',
#                                                                np.float64(7.0): {'onpix': {np.float64(4.0): 'M',
#                                                                                            np.float64(5.0): {'high': {np.float64(5.0): 'M'}},
#                                                                                            np.float64(6.0): 'K',
#                                                                                            np.float64(7.0): 'M',
#                                                                                            np.float64(8.0): 'M'}},
#                                                                np.float64(8.0): {'high': {np.float64(7.0): 'K',
#                                                                                           np.float64(10.0): 'Z'}},
#                                                                np.float64(9.0): {'onpix': {np.float64(5.0): {'high': {np.float64(6.0): 'M',
#                                                                                                                       np.float64(7.0): 'A'}},
#                                                                                            np.float64(6.0): 'M',
#                                                                                            np.float64(8.0): {'high': {np.float64(7.0): 'M',
#                                                                                                                       np.float64(8.0): 'A'}},
#                                                                                            np.float64(9.0): 'K',
#                                                                                            np.float64(10.0): 'R'}},
#                                                                np.float64(10.0): {'onpix': {np.float64(3.0): {'high': {np.float64(5.0): 'R',
#                                                                                                                        np.float64(6.0): 'R'}},
#                                                                                             np.float64(6.0): 'M',
#                                                                                             np.float64(12.0): 'U'}},
#                                                                np.float64(11.0): 'K',
#                                                                np.float64(13.0): 'R',
#                                                                np.float64(15.0): 'U'}},
#                                    np.float64(5.0): {'y-box': {np.float64(1.0): 'M',
#                                                                np.float64(2.0): 'M',
#                                                                np.float64(5.0): 'Q',
#                                                                np.float64(6.0): {'onpix': {np.float64(4.0): {'high': {np.float64(4.0): 'M'}},
#                                                                                            np.float64(6.0): 'M'}},
#                                                                np.float64(7.0): {'high': {np.float64(5.0): 'M',
#                                                                                           np.float64(6.0): {'onpix': {np.float64(5.0): 'Q',
#                                                                                                                       np.float64(6.0): 'Q'}}}},
#                                                                np.float64(8.0): {'high': {np.float64(6.0): 'M',
#                                                                                           np.float64(7.0): {'onpix': {np.float64(6.0): 'O'}}}},
#                                                                np.float64(9.0): {'onpix': {np.float64(3.0): {'high': {np.float64(4.0): 'L'}},
#                                                                                            np.float64(4.0): 'R',
#                                                                                            np.float64(5.0): 'B',
#                                                                                            np.float64(6.0): {'high': {np.float64(6.0): 'M',
#                                                                                                                       np.float64(7.0): 'M',
#                                                                                                                       np.float64(8.0): 'O'}},
#                                                                                            np.float64(7.0): 'M',
#                                                                                            np.float64(8.0): 'M',
#                                                                                            np.float64(9.0): 'X'}},
#                                                                np.float64(10.0): {'onpix': {np.float64(4.0): 'R',
#                                                                                             np.float64(5.0): {'high': {np.float64(5.0): 'B'}},
#                                                                                             np.float64(6.0): 'M',
#                                                                                             np.float64(7.0): 'M',
#                                                                                             np.float64(8.0): {'high': {np.float64(8.0): 'M'}},
#                                                                                             np.float64(10.0): 'U'}},
#                                                                np.float64(11.0): {'onpix': {np.float64(4.0): 'R',
#                                                                                             np.float64(6.0): 'M',
#                                                                                             np.float64(7.0): 'R'}},
#                                                                np.float64(12.0): {'onpix': {np.float64(5.0): 'R',
#                                                                                             np.float64(6.0): 'B',
#                                                                                             np.float64(7.0): 'B'}},
#                                                                np.float64(13.0): 'R',
#                                                                np.float64(14.0): {'onpix': {np.float64(4.0): 'U',
#                                                                                             np.float64(5.0): {'high': {np.float64(8.0): 'R'}}}},
#                                                                np.float64(15.0): {'onpix': {np.float64(4.0): 'S',
#                                                                                             np.float64(5.0): 'R',
#                                                                                             np.float64(6.0): 'U',
#                                                                                             np.float64(8.0): 'B'}}}},
#                                    np.float64(6.0): {'y-box': {np.float64(2.0): 'R',
#                                                                np.float64(6.0): 'L',
#                                                                np.float64(7.0): 'X',
#                                                                np.float64(8.0): {'high': {np.float64(6.0): 'R',
#                                                                                           np.float64(7.0): 'X'}},
#                                                                np.float64(9.0): {'onpix': {np.float64(4.0): 'R',
#                                                                                            np.float64(5.0): 'R',
#                                                                                            np.float64(6.0): 'X',
#                                                                                            np.float64(7.0): 'Q',
#                                                                                            np.float64(8.0): 'Q'}},
#                                                                np.float64(10.0): {'onpix': {np.float64(5.0): {'high': {np.float64(5.0): 'K',
#                                                                                                                        np.float64(8.0): 'L'}},
#                                                                                             np.float64(6.0): 'R',
#                                                                                             np.float64(7.0): 'R'}},
#                                                                np.float64(11.0): {'high': {np.float64(8.0): {'onpix': {np.float64(6.0): 'G',
#                                                                                                                        np.float64(7.0): 'R'}},
#                                                                                            np.float64(9.0): 'X'}},
#                                                                np.float64(12.0): 'K',
#                                                                np.float64(13.0): 'K',
#                                                                np.float64(14.0): {'onpix': {np.float64(4.0): 'U',
#                                                                                             np.float64(7.0): 'R'}},
#                                                                np.float64(15.0): {'onpix': {np.float64(4.0): 'S',
#                                                                                             np.float64(6.0): 'K',
#                                                                                             np.float64(7.0): 'R',
#                                                                                             np.float64(8.0): 'B'}}}},
#                                    np.float64(7.0): {'onpix': {np.float64(3.0): 'L',
#                                                                np.float64(4.0): {'y-box': {np.float64(7.0): 'R',
#                                                                                            np.float64(11.0): 'L'}},
#                                                                np.float64(5.0): {'y-box': {np.float64(8.0): 'D',
#                                                                                            np.float64(11.0): 'R'}},
#                                                                np.float64(6.0): {'y-box': {np.float64(7.0): 'D',
#                                                                                            np.float64(11.0): {'high': {np.float64(8.0): 'T'}}}},
#                                                                np.float64(7.0): 'D',
#                                                                np.float64(8.0): 'D'}},
#                                    np.float64(8.0): {'y-box': {np.float64(8.0): 'K',
#                                                                np.float64(9.0): {'onpix': {np.float64(3.0): 'L',
#                                                                                            np.float64(6.0): 'O',
#                                                                                            np.float64(7.0): 'D'}},
#                                                                np.float64(11.0): 'L',
#                                                                np.float64(12.0): 'X',
#                                                                np.float64(13.0): 'X',
#                                                                np.float64(15.0): 'X'}},
#                                    np.float64(9.0): {'y-box': {np.float64(9.0): 'Z',
#                                                                np.float64(12.0): 'X',
#                                                                np.float64(13.0): 'Z',
#                                                                np.float64(15.0): 'Z'}},
#                                    np.float64(10.0): 'S'}},
#            np.int64(6): {'y2bar': {np.float64(0.0): {'onpix': {np.float64(0.0): {'high': {np.float64(0.0): {'y-box': {np.float64(0.0): 'A'}},
#                                                                                           np.float64(1.0): 'A'}},
#                                                                np.float64(1.0): {'y-box': {np.float64(0.0): 'M',
#                                                                                            np.float64(1.0): {'high': {np.float64(1.0): 'M',
#                                                                                                                       np.float64(2.0): 'M'}}}},
#                                                                np.float64(2.0): 'A',
#                                                                np.float64(3.0): 'A',
#                                                                np.float64(4.0): 'M',
#                                                                np.float64(6.0): 'M'}},
#                                    np.float64(1.0): {'high': {np.float64(1.0): 'A',
#                                                               np.float64(2.0): {'y-box': {np.float64(1.0): {'onpix': {np.float64(1.0): 'M'}},
#                                                                                           np.float64(3.0): 'A',
#                                                                                           np.float64(4.0): 'A'}},
#                                                               np.float64(3.0): 'A',
#                                                               np.float64(4.0): {'y-box': {np.float64(3.0): 'M',
#                                                                                           np.float64(6.0): {'onpix': {np.float64(1.0): 'A',
#                                                                                                                       np.float64(2.0): 'M',
#                                                                                                                       np.float64(6.0): 'M'}},
#                                                                                           np.float64(7.0): 'A',
#                                                                                           np.float64(9.0): 'A'}},
#                                                               np.float64(5.0): {'y-box': {np.float64(3.0): 'M',
#                                                                                           np.float64(4.0): 'A',
#                                                                                           np.float64(7.0): {'onpix': {np.float64(2.0): 'A',
#                                                                                                                       np.float64(3.0): 'M',
#                                                                                                                       np.float64(8.0): 'M'}},
#                                                                                           np.float64(8.0): 'A',
#                                                                                           np.float64(10.0): 'A'}},
#                                                               np.float64(6.0): 'M',
#                                                               np.float64(7.0): {'y-box': {np.float64(9.0): 'A',
#                                                                                           np.float64(10.0): 'M'}},
#                                                               np.float64(8.0): 'M'}},
#                                    np.float64(2.0): {'onpix': {np.float64(1.0): 'A',
#                                                                np.float64(2.0): 'A',
#                                                                np.float64(3.0): {'y-box': {np.float64(4.0): 'M',
#                                                                                            np.float64(6.0): 'A',
#                                                                                            np.float64(7.0): 'A',
#                                                                                            np.float64(8.0): {'high': {np.float64(6.0): 'A'}},
#                                                                                            np.float64(9.0): {'high': {np.float64(6.0): 'A',
#                                                                                                                       np.float64(7.0): 'A'}},
#                                                                                            np.float64(10.0): 'A',
#                                                                                            np.float64(11.0): 'A'}},
#                                                                np.float64(4.0): {'y-box': {np.float64(4.0): {'high': {np.float64(6.0): 'H',
#                                                                                                                       np.float64(7.0): 'M'}},
#                                                                                            np.float64(5.0): 'M',
#                                                                                            np.float64(6.0): 'M',
#                                                                                            np.float64(7.0): 'R',
#                                                                                            np.float64(8.0): 'A',
#                                                                                            np.float64(9.0): {'high': {np.float64(6.0): 'A',
#                                                                                                                       np.float64(7.0): 'A'}},
#                                                                                            np.float64(10.0): {'high': {np.float64(7.0): 'M',
#                                                                                                                        np.float64(8.0): 'M'}},
#                                                                                            np.float64(11.0): {'high': {np.float64(8.0): 'M'}},
#                                                                                            np.float64(14.0): 'A'}},
#                                                                np.float64(5.0): {'y-box': {np.float64(6.0): {'high': {np.float64(4.0): 'H'}},
#                                                                                            np.float64(9.0): 'A',
#                                                                                            np.float64(10.0): 'A',
#                                                                                            np.float64(11.0): 'A'}},
#                                                                np.float64(6.0): 'M',
#                                                                np.float64(8.0): 'M',
#                                                                np.float64(9.0): {'high': {np.float64(6.0): 'M',
#                                                                                           np.float64(10.0): 'H'}},
#                                                                np.float64(10.0): 'M',
#                                                                np.float64(11.0): 'M',
#                                                                np.float64(12.0): 'M'}},
#                                    np.float64(3.0): {'onpix': {np.float64(0.0): 'R',
#                                                                np.float64(1.0): 'J',
#                                                                np.float64(2.0): {'high': {np.float64(2.0): 'M',
#                                                                                           np.float64(4.0): {'y-box': {np.float64(3.0): 'R',
#                                                                                                                       np.float64(6.0): 'A',
#                                                                                                                       np.float64(7.0): 'A'}},
#                                                                                           np.float64(5.0): 'A',
#                                                                                           np.float64(6.0): {'y-box': {np.float64(4.0): 'A',
#                                                                                                                       np.float64(8.0): 'A',
#                                                                                                                       np.float64(9.0): 'A'}},
#                                                                                           np.float64(7.0): {'y-box': {np.float64(10.0): 'A'}},
#                                                                                           np.float64(8.0): 'J'}},
#                                                                np.float64(3.0): {'y-box': {np.float64(6.0): {'high': {np.float64(4.0): 'A'}},
#                                                                                            np.float64(7.0): 'A',
#                                                                                            np.float64(8.0): {'high': {np.float64(6.0): 'A'}},
#                                                                                            np.float64(9.0): 'A',
#                                                                                            np.float64(10.0): 'A',
#                                                                                            np.float64(11.0): 'A'}},
#                                                                np.float64(4.0): {'y-box': {np.float64(5.0): 'Q',
#                                                                                            np.float64(6.0): {'high': {np.float64(4.0): 'R',
#                                                                                                                       np.float64(5.0): 'K'}},
#                                                                                            np.float64(7.0): 'A',
#                                                                                            np.float64(8.0): 'R',
#                                                                                            np.float64(9.0): 'A',
#                                                                                            np.float64(10.0): 'A',
#                                                                                            np.float64(11.0): 'A',
#                                                                                            np.float64(14.0): 'A'}},
#                                                                np.float64(5.0): {'high': {np.float64(4.0): 'R',
#                                                                                           np.float64(5.0): {'y-box': {np.float64(6.0): 'K',
#                                                                                                                       np.float64(7.0): 'K'}},
#                                                                                           np.float64(6.0): {'y-box': {np.float64(7.0): 'K',
#                                                                                                                       np.float64(8.0): 'A'}},
#                                                                                           np.float64(7.0): 'R',
#                                                                                           np.float64(8.0): 'A'}},
#                                                                np.float64(6.0): {'y-box': {np.float64(6.0): 'R',
#                                                                                            np.float64(8.0): 'R',
#                                                                                            np.float64(9.0): 'U'}},
#                                                                np.float64(7.0): {'high': {np.float64(6.0): 'R',
#                                                                                           np.float64(7.0): 'R',
#                                                                                           np.float64(8.0): 'K'}},
#                                                                np.float64(9.0): {'high': {np.float64(6.0): 'M',
#                                                                                           np.float64(8.0): {'y-box': {np.float64(10.0): 'G'}},
#                                                                                           np.float64(9.0): 'R'}},
#                                                                np.float64(10.0): 'M',
#                                                                np.float64(15.0): 'M'}},
#                                    np.float64(4.0): {'onpix': {np.float64(1.0): {'high': {np.float64(1.0): 'R',
#                                                                                           np.float64(4.0): 'J',
#                                                                                           np.float64(5.0): 'J',
#                                                                                           np.float64(6.0): 'J',
#                                                                                           np.float64(7.0): 'J',
#                                                                                           np.float64(8.0): 'J'}},
#                                                                np.float64(2.0): {'y-box': {np.float64(1.0): {'high': {np.float64(1.0): 'M',
#                                                                                                                       np.float64(2.0): 'M'}},
#                                                                                            np.float64(3.0): 'M',
#                                                                                            np.float64(6.0): 'J',
#                                                                                            np.float64(7.0): 'J',
#                                                                                            np.float64(9.0): {'high': {np.float64(4.0): 'J',
#                                                                                                                       np.float64(6.0): 'J'}},
#                                                                                            np.float64(10.0): {'high': {np.float64(5.0): 'S',
#                                                                                                                        np.float64(7.0): 'J'}},
#                                                                                            np.float64(12.0): 'S'}},
#                                                                np.float64(3.0): {'y-box': {np.float64(1.0): 'M',
#                                                                                            np.float64(3.0): 'M',
#                                                                                            np.float64(4.0): {'high': {np.float64(2.0): 'M',
#                                                                                                                       np.float64(3.0): 'M'}},
#                                                                                            np.float64(6.0): {'high': {np.float64(4.0): 'A'}},
#                                                                                            np.float64(7.0): {'high': {np.float64(5.0): 'J'}},
#                                                                                            np.float64(8.0): {'high': {np.float64(6.0): 'J'}},
#                                                                                            np.float64(9.0): 'A',
#                                                                                            np.float64(10.0): {'high': {np.float64(5.0): 'J',
#                                                                                                                        np.float64(7.0): 'J',
#                                                                                                                        np.float64(8.0): 'J'}},
#                                                                                            np.float64(11.0): {'high': {np.float64(6.0): 'R'}},
#                                                                                            np.float64(12.0): 'S',
#                                                                                            np.float64(15.0): 'S'}},
#                                                                np.float64(4.0): {'y-box': {np.float64(2.0): 'M',
#                                                                                            np.float64(4.0): 'M',
#                                                                                            np.float64(5.0): {'high': {np.float64(3.0): 'M',
#                                                                                                                       np.float64(4.0): 'M'}},
#                                                                                            np.float64(6.0): {'high': {np.float64(4.0): 'M',
#                                                                                                                       np.float64(5.0): 'K'}},
#                                                                                            np.float64(7.0): 'M',
#                                                                                            np.float64(8.0): {'high': {np.float64(6.0): 'A'}},
#                                                                                            np.float64(9.0): 'J',
#                                                                                            np.float64(10.0): 'J',
#                                                                                            np.float64(11.0): 'U'}},
#                                                                np.float64(5.0): {'y-box': {np.float64(5.0): {'high': {np.float64(4.0): 'Q',
#                                                                                                                       np.float64(5.0): 'K'}},
#                                                                                            np.float64(6.0): {'high': {np.float64(4.0): 'M'}},
#                                                                                            np.float64(7.0): {'high': {np.float64(5.0): 'M',
#                                                                                                                       np.float64(6.0): 'Q'}},
#                                                                                            np.float64(8.0): 'M',
#                                                                                            np.float64(9.0): {'high': {np.float64(6.0): 'K',
#                                                                                                                       np.float64(7.0): 'A'}},
#                                                                                            np.float64(13.0): 'U',
#                                                                                            np.float64(15.0): 'N'}},
#                                                                np.float64(6.0): {'y-box': {np.float64(6.0): {'high': {np.float64(4.0): 'K',
#                                                                                                                       np.float64(5.0): 'Q',
#                                                                                                                       np.float64(6.0): 'Q'}},
#                                                                                            np.float64(7.0): {'high': {np.float64(5.0): 'M'}},
#                                                                                            np.float64(8.0): {'high': {np.float64(6.0): 'M'}},
#                                                                                            np.float64(9.0): {'high': {np.float64(6.0): 'K',
#                                                                                                                       np.float64(7.0): 'K',
#                                                                                                                       np.float64(8.0): 'K'}},
#                                                                                            np.float64(10.0): {'high': {np.float64(7.0): 'M',
#                                                                                                                        np.float64(8.0): 'M'}},
#                                                                                            np.float64(11.0): 'A',
#                                                                                            np.float64(13.0): 'B'}},
#                                                                np.float64(7.0): {'high': {np.float64(4.0): 'M',
#                                                                                           np.float64(6.0): 'M',
#                                                                                           np.float64(7.0): {'y-box': {np.float64(8.0): 'K',
#                                                                                                                       np.float64(9.0): 'K',
#                                                                                                                       np.float64(10.0): 'K'}},
#                                                                                           np.float64(8.0): {'y-box': {np.float64(10.0): 'K',
#                                                                                                                       np.float64(11.0): 'Q'}},
#                                                                                           np.float64(10.0): 'Z'}},
#                                                                np.float64(8.0): {'y-box': {np.float64(9.0): {'high': {np.float64(6.0): 'M',
#                                                                                                                       np.float64(7.0): 'M',
#                                                                                                                       np.float64(8.0): 'A'}},
#                                                                                            np.float64(10.0): {'high': {np.float64(7.0): 'R',
#                                                                                                                        np.float64(8.0): 'M'}},
#                                                                                            np.float64(11.0): {'high': {np.float64(8.0): 'H'}}}},
#                                                                np.float64(9.0): {'y-box': {np.float64(9.0): 'K',
#                                                                                            np.float64(10.0): {'high': {np.float64(8.0): 'K',
#                                                                                                                        np.float64(9.0): 'N'}},
#                                                                                            np.float64(11.0): 'M'}},
#                                                                np.float64(10.0): {'y-box': {np.float64(9.0): 'R',
#                                                                                             np.float64(10.0): 'H',
#                                                                                             np.float64(11.0): 'H'}},
#                                                                np.float64(11.0): {'y-box': {np.float64(11.0): {'high': {np.float64(8.0): 'M'}}}},
#                                                                np.float64(12.0): {'y-box': {np.float64(9.0): 'M',
#                                                                                             np.float64(11.0): 'U'}}}},
# ...
# Predicted: U, Actual: U
# Predicted: G, Actual: U
# Predicted: R, Actual: R
# Predicted: M, Actual: M
# Predicted: S, Actual: B
# Predicted: R, Actual: J
# Predicted: G, Actual: O
# Predicted: X, Actual: T
# Predicted: E, Actual: C
# Predicted: X, Actual: U
# Predicted: X, Actual: X
# Predicted: A, Actual: A
# Predicted: K, Actual: K
# Predicted: None, Actual: S
# Predicted: U, Actual: U
# Predicted: None, Actual: W
# Predicted: None, Actual: P
# Predicted: D, Actual: U
# Predicted: A, Actual: A
# Predicted: None, Actual: C
# Predicted: V, Actual: V
# Predicted: K, Actual: E
# Predicted: O, Actual: N
# Predicted: O, Actual: Q
# Predicted: H, Actual: H
# Predicted: Z, Actual: N
# Predicted: J, Actual: J
# Predicted: F, Actual: F
# Predicted: S, Actual: R
# Predicted: Z, Actual: U
# Predicted: B, Actual: R
# Predicted: N, Actual: U
# Predicted: W, Actual: P
# Predicted: C, Actual: C
# Predicted: None, Actual: F
# Predicted: D, Actual: D
# Predicted: X, Actual: X
# Predicted: N, Actual: P
# Predicted: H, Actual: H
# Predicted: I, Actual: I
# Predicted: I, Actual: I
# Predicted: M, Actual: K
# Predicted: M, Actual: M
# Predicted: K, Actual: D
# Predicted: P, Actual: N
# Predicted: F, Actual: F
# Predicted: C, Actual: C
# Predicted: W, Actual: W
# Predicted: Z, Actual: Z
# Predicted: X, Actual: E
# Predicted: L, Actual: T
# Predicted: O, Actual: X
# Predicted: J, Actual: J
# Predicted: C, Actual: Z
# Predicted: L, Actual: L
# Predicted: N, Actual: D
# Predicted: I, Actual: O
# Predicted: O, Actual: G
# Predicted: I, Actual: I
# Predicted: H, Actual: H
# Predicted: M, Actual: M
# Predicted: Z, Actual: Z
# Predicted: N, Actual: O
# Predicted: None, Actual: M
# Predicted: H, Actual: D
# Predicted: C, Actual: E
# Predicted: U, Actual: U
# Predicted: Q, Actual: Q
# Predicted: I, Actual: I
# Predicted: C, Actual: S
# Predicted: Q, Actual: Q
# Predicted: M, Actual: M
# Predicted: L, Actual: L
# Predicted: D, Actual: S
# Predicted: B, Actual: V
# Predicted: N, Actual: N
# Predicted: X, Actual: X
# Predicted: None, Actual: Y
# Predicted: T, Actual: Y
# Predicted: B, Actual: B
# Predicted: Z, Actual: Z
# Predicted: A, Actual: A
# Predicted: C, Actual: C
# Predicted: K, Actual: S
# Predicted: V, Actual: P
# Predicted: N, Actual: N
# Predicted: O, Actual: O
# Predicted: I, Actual: I
# Predicted: R, Actual: J
# Predicted: L, Actual: L
# Predicted: R, Actual: D
# Predicted: Q, Actual: K
# Predicted: S, Actual: L
# Predicted: X, Actual: E
# Predicted: I, Actual: I
# Predicted: Y, Actual: Y
# Predicted: I, Actual: E
# Predicted: X, Actual: F
# Predicted: O, Actual: B
# Predicted: T, Actual: T
# Predicted: P, Actual: P
# Predicted: M, Actual: M
# Predicted: K, Actual: Z
# Predicted: V, Actual: V
# Predicted: Y, Actual: Y
# Predicted: T, Actual: K
# Predicted: V, Actual: V
# Predicted: None, Actual: Z
# Predicted: B, Actual: E
# Predicted: B, Actual: K
# Predicted: K, Actual: Q
# Predicted: C, Actual: T
# Predicted: U, Actual: E
# Predicted: C, Actual: T
# Predicted: B, Actual: B
# Predicted: Y, Actual: T
# Predicted: V, Actual: O
# Predicted: U, Actual: C
# Predicted: None, Actual: V
# Predicted: O, Actual: L
# Predicted: O, Actual: C
# Predicted: M, Actual: M
# Predicted: O, Actual: O
# Predicted: Y, Actual: Y
# Predicted: T, Actual: T
# Predicted: F, Actual: F
# Predicted: J, Actual: L
# Predicted: P, Actual: P
# Predicted: None, Actual: H
# Predicted: N, Actual: P
# Predicted: O, Actual: O
# Predicted: I, Actual: I
# Predicted: None, Actual: D
# Predicted: E, Actual: Z
# Predicted: A, Actual: A
# Predicted: H, Actual: N
# Predicted: M, Actual: M
# Predicted: A, Actual: A
# Predicted: C, Actual: L
# Predicted: T, Actual: R
# Predicted: R, Actual: O
# Predicted: Z, Actual: Z
# Predicted: F, Actual: K
# Predicted: O, Actual: E
# Predicted: O, Actual: J
# Predicted: H, Actual: D
# Predicted: N, Actual: N
# Predicted: X, Actual: F
# Predicted: B, Actual: A
# Predicted: L, Actual: L
# Predicted: H, Actual: H
# Predicted: None, Actual: T
# Predicted: U, Actual: L
# Predicted: E, Actual: K
# Predicted: K, Actual: K
# Predicted: W, Actual: W
# Predicted: S, Actual: S
# Predicted: E, Actual: E
# Predicted: R, Actual: R
# Predicted: L, Actual: L
# Predicted: C, Actual: C
# Predicted: A, Actual: A
# Predicted: L, Actual: L
# Predicted: Y, Actual: Y
# Predicted: R, Actual: R
# Predicted: P, Actual: P
# Predicted: P, Actual: P
# Predicted: H, Actual: B
# Predicted: None, Actual: H
# Predicted: U, Actual: B
# Predicted: S, Actual: K
# Predicted: A, Actual: A
# Predicted: O, Actual: D
# Predicted: N, Actual: N
# Predicted: T, Actual: R
# Predicted: F, Actual: F
# Predicted: E, Actual: E
# Predicted: V, Actual: W
# Predicted: Q, Actual: Q
# Predicted: B, Actual: D
# Predicted: J, Actual: J
# Predicted: S, Actual: D
# Predicted: F, Actual: N
# Predicted: F, Actual: F
# Predicted: U, Actual: U
# Predicted: V, Actual: V
# Predicted: L, Actual: L
# Predicted: I, Actual: T
# Predicted: Y, Actual: T
# Predicted: V, Actual: O
# Predicted: V, Actual: V
# Predicted: U, Actual: U
# Predicted: V, Actual: V
# Predicted: U, Actual: U
# Predicted: U, Actual: U
# Predicted: O, Actual: N
# Predicted: I, Actual: I
# Predicted: Z, Actual: Z
# Predicted: C, Actual: A
# Predicted: Z, Actual: Z
# Predicted: O, Actual: W
# Predicted: U, Actual: T
# Predicted: X, Actual: X
# Predicted: B, Actual: B
# Predicted: B, Actual: O
# Predicted: None, Actual: X
# Predicted: None, Actual: C
# Predicted: K, Actual: T
# Predicted: None, Actual: J
# Predicted: G, Actual: K
# Predicted: F, Actual: F
# Predicted: X, Actual: C
# Predicted: G, Actual: C
# Predicted: F, Actual: F
# Predicted: C, Actual: T
# Predicted: G, Actual: O
# Predicted: P, Actual: P
# Predicted: N, Actual: N
# Predicted: K, Actual: X
# Predicted: D, Actual: E
# Predicted: Y, Actual: Y
# Predicted: G, Actual: G
# Predicted: H, Actual: B
# Predicted: N, Actual: N
# Predicted: G, Actual: S
# Predicted: C, Actual: T
# Predicted: E, Actual: H
# Predicted: J, Actual: J
# Predicted: A, Actual: A
# Predicted: None, Actual: Z
# Predicted: G, Actual: E
# Predicted: I, Actual: I
# Predicted: R, Actual: J
# Predicted: None, Actual: R
# Predicted: W, Actual: W
# Predicted: B, Actual: H
# Predicted: T, Actual: T
# Predicted: M, Actual: M
# Predicted: A, Actual: A
# Predicted: None, Actual: P
# Predicted: U, Actual: U
# Predicted: L, Actual: T
# Predicted: Y, Actual: Y
# Predicted: Y, Actual: Y
# Predicted: D, Actual: I
# Predicted: H, Actual: B
# Predicted: L, Actual: I
# Predicted: H, Actual: K
# Predicted: K, Actual: F
# Predicted: None, Actual: Z
# Predicted: O, Actual: O
# Predicted: M, Actual: M
# Predicted: None, Actual: L
# Predicted: M, Actual: S
# Predicted: Q, Actual: Q
# Predicted: D, Actual: D
# Predicted: N, Actual: G
# Predicted: Y, Actual: Y
# Predicted: F, Actual: R
# Predicted: None, Actual: B
# Predicted: None, Actual: C
# Predicted: S, Actual: O
# Predicted: L, Actual: T
# Predicted: C, Actual: D
# Predicted: X, Actual: X
# Predicted: P, Actual: V
# Predicted: B, Actual: B
# Predicted: None, Actual: M
# Predicted: G, Actual: F
# Predicted: O, Actual: S
# Predicted: S, Actual: S
# Predicted: R, Actual: R
# Predicted: V, Actual: V
# Predicted: E, Actual: E
# Predicted: A, Actual: A
# Predicted: T, Actual: T
# Predicted: E, Actual: N
# Predicted: None, Actual: R
# Predicted: K, Actual: S
# Predicted: J, Actual: J
# Predicted: T, Actual: T
# Predicted: H, Actual: H
# Predicted: U, Actual: U
# Predicted: P, Actual: Z
# Predicted: Z, Actual: Z
# Predicted: R, Actual: R
# Predicted: I, Actual: B
# Predicted: B, Actual: K
# Predicted: H, Actual: B
# Predicted: M, Actual: M
# Predicted: N, Actual: N
# Predicted: K, Actual: B
# Predicted: V, Actual: W
# Predicted: H, Actual: H
# Predicted: D, Actual: D
# Predicted: O, Actual: G
# Predicted: X, Actual: D
# Predicted: None, Actual: B
# Predicted: F, Actual: N
# Predicted: Y, Actual: W
# Predicted: K, Actual: T
# Predicted: E, Actual: D
# Predicted: Q, Actual: Q
# Predicted: E, Actual: E
# Predicted: W, Actual: W
# Predicted: P, Actual: X
# Predicted: Y, Actual: Y
# Predicted: Q, Actual: E
# Predicted: R, Actual: R
# Predicted: Y, Actual: Y
# Predicted: C, Actual: U
# Predicted: D, Actual: D
# Predicted: D, Actual: D
# Predicted: Z, Actual: Z
# Predicted: B, Actual: M
# Predicted: O, Actual: O
# Predicted: V, Actual: V
# Predicted: U, Actual: G
# Predicted: G, Actual: G
# Predicted: Q, Actual: H
# Predicted: V, Actual: V
# Predicted: G, Actual: G
# Predicted: None, Actual: D
# Predicted: Z, Actual: X
# Predicted: C, Actual: C
# Predicted: F, Actual: U
# Predicted: G, Actual: J
# Predicted: E, Actual: T
# Predicted: Z, Actual: Z
# Predicted: None, Actual: V
# Predicted: A, Actual: Q
# Predicted: F, Actual: P
# Predicted: None, Actual: G
# Predicted: Y, Actual: Y
# Predicted: N, Actual: S
# Predicted: N, Actual: U
# Predicted: B, Actual: B
# Predicted: T, Actual: L
# Predicted: L, Actual: X
# Predicted: B, Actual: D
# Predicted: R, Actual: R
# Predicted: U, Actual: X
# Predicted: M, Actual: M
# Predicted: J, Actual: J
# Predicted: D, Actual: B
# Predicted: None, Actual: A
# Predicted: J, Actual: J
# Predicted: R, Actual: M
# Predicted: Z, Actual: Z
# Predicted: W, Actual: W
# Predicted: C, Actual: C
# Predicted: None, Actual: M
# Predicted: I, Actual: I
# Predicted: None, Actual: J
# Predicted: U, Actual: Y
# Predicted: N, Actual: N
# Predicted: W, Actual: W
# Predicted: L, Actual: R
# Predicted: N, Actual: F
# Predicted: T, Actual: S
# Predicted: R, Actual: R
# Predicted: O, Actual: R
# Predicted: Z, Actual: Z
# Predicted: W, Actual: B
# Predicted: M, Actual: K
# Predicted: R, Actual: R
# Predicted: None, Actual: M
# Predicted: R, Actual: R
# Predicted: D, Actual: D
# Predicted: None, Actual: F
# Predicted: P, Actual: N
# Predicted: None, Actual: X
# Predicted: E, Actual: E
# Predicted: K, Actual: Q
# Predicted: V, Actual: V
# Predicted: L, Actual: L
# Predicted: Y, Actual: Y
# Predicted: V, Actual: F
# Predicted: P, Actual: P
# Predicted: G, Actual: X
# Predicted: G, Actual: O
# Predicted: O, Actual: Q
# Predicted: C, Actual: U
# Predicted: E, Actual: I
# Predicted: Z, Actual: Z
# Predicted: Z, Actual: Z
# Predicted: B, Actual: B
# Predicted: P, Actual: P
# Predicted: None, Actual: W
# Predicted: V, Actual: V
# Predicted: A, Actual: A
# Predicted: None, Actual: P
# Predicted: H, Actual: B
# Predicted: U, Actual: U
# Predicted: None, Actual: V
# Predicted: None, Actual: R
# Predicted: D, Actual: H
# Predicted: Z, Actual: Z
# Predicted: O, Actual: N
# Predicted: G, Actual: G
# Predicted: Q, Actual: I
# Predicted: N, Actual: N
# Predicted: U, Actual: S
# Predicted: C, Actual: F
# Predicted: L, Actual: J
# Predicted: Y, Actual: T
# Predicted: B, Actual: B
# Predicted: None, Actual: Q
# Predicted: K, Actual: E
# Predicted: E, Actual: X
# Predicted: None, Actual: Q
# Predicted: None, Actual: Q
# Predicted: H, Actual: H
# Predicted: O, Actual: P
# Predicted: U, Actual: U
# Predicted: F, Actual: B
# Predicted: K, Actual: G
# Predicted: F, Actual: B
# Predicted: L, Actual: S
# Predicted: M, Actual: M
# Predicted: O, Actual: N
# Predicted: U, Actual: U
# Predicted: L, Actual: L
# Predicted: P, Actual: R
# Predicted: U, Actual: U
# Predicted: W, Actual: V
# Predicted: R, Actual: J
# Predicted: U, Actual: U
# Predicted: B, Actual: K
# Predicted: T, Actual: Y
# Predicted: H, Actual: H
# Predicted: S, Actual: T
# Predicted: B, Actual: B
# Predicted: Z, Actual: Z
# Predicted: X, Actual: S
# Predicted: U, Actual: U
# Predicted: F, Actual: F
# Predicted: H, Actual: H
# Predicted: S, Actual: E
# Predicted: P, Actual: P
# Predicted: P, Actual: P
# Predicted: P, Actual: Y
# Predicted: S, Actual: J
# Predicted: Z, Actual: U
# Predicted: None, Actual: B
# Predicted: L, Actual: L
# Predicted: K, Actual: D
# Predicted: D, Actual: D
# Predicted: P, Actual: V
# Predicted: V, Actual: P
# Predicted: H, Actual: R
# Predicted: Q, Actual: G
# Predicted: U, Actual: C
# Predicted: G, Actual: B
# Predicted: R, Actual: H
# Predicted: W, Actual: W
# Predicted: F, Actual: N
# Predicted: O, Actual: N
# Predicted: U, Actual: B
# Predicted: G, Actual: G
# Predicted: V, Actual: V
# Predicted: I, Actual: I
# Predicted: N, Actual: P
# Predicted: W, Actual: W
# Predicted: B, Actual: B
# Predicted: D, Actual: S
# Predicted: C, Actual: C
# Predicted: I, Actual: T
# Predicted: L, Actual: L
# Predicted: L, Actual: L
# Predicted: O, Actual: O
# Predicted: R, Actual: R
# Predicted: Y, Actual: F
# Predicted: Z, Actual: Z
# Predicted: F, Actual: X
# Predicted: None, Actual: G
# Predicted: I, Actual: I
# Predicted: F, Actual: S
# Predicted: L, Actual: S
# Predicted: V, Actual: V
# Predicted: L, Actual: L
# Predicted: None, Actual: Z
# Predicted: H, Actual: H
# Predicted: P, Actual: P
# Predicted: B, Actual: I
# Predicted: X, Actual: D
# Predicted: E, Actual: E
# Predicted: X, Actual: X
# Predicted: Z, Actual: Z
# Predicted: F, Actual: F
# Predicted: J, Actual: J
# Predicted: J, Actual: J
# Predicted: E, Actual: C
# Predicted: I, Actual: C
# Predicted: R, Actual: R
# Predicted: K, Actual: K
# Predicted: X, Actual: E
# Predicted: G, Actual: N
# Predicted: Q, Actual: Q
# Predicted: Z, Actual: Z
# Predicted: N, Actual: N
# Predicted: S, Actual: H
# Predicted: C, Actual: E
# Predicted: K, Actual: M
# Predicted: S, Actual: G
# Predicted: Y, Actual: Y
# Predicted: V, Actual: V
# Predicted: E, Actual: E
# Predicted: V, Actual: V
# Predicted: W, Actual: P
# Predicted: G, Actual: G
# Predicted: K, Actual: D
# Predicted: None, Actual: S
# Predicted: None, Actual: H
# Predicted: E, Actual: X
# Predicted: J, Actual: J
# Predicted: C, Actual: C
# Predicted: P, Actual: P
# Predicted: Q, Actual: C
# Predicted: H, Actual: H
# Predicted: O, Actual: I
# Predicted: K, Actual: D
# Predicted: P, Actual: P
# Predicted: None, Actual: L
# Predicted: I, Actual: I
# Predicted: C, Actual: U
# Predicted: D, Actual: K
# Predicted: W, Actual: W
# Predicted: U, Actual: S
# Predicted: L, Actual: L
# Predicted: T, Actual: T
# Predicted: V, Actual: F
# Predicted: B, Actual: D
# Predicted: F, Actual: F
# Predicted: B, Actual: C
# Predicted: H, Actual: D
# Predicted: J, Actual: J
# Predicted: T, Actual: F
# Predicted: D, Actual: I
# Predicted: W, Actual: W
# Predicted: B, Actual: H
# Predicted: V, Actual: V
# Predicted: N, Actual: N
# Predicted: K, Actual: G
# Predicted: None, Actual: F
# Predicted: H, Actual: B
# Predicted: W, Actual: W
# Predicted: F, Actual: C
# Predicted: A, Actual: A
# Predicted: Z, Actual: Z
# Predicted: H, Actual: H
# Predicted: None, Actual: D
# Predicted: D, Actual: X
# Predicted: O, Actual: O
# Predicted: None, Actual: P
# Predicted: P, Actual: V
# Predicted: E, Actual: T
# Predicted: K, Actual: K
# Predicted: O, Actual: S
# Predicted: L, Actual: D
# Predicted: P, Actual: P
# Predicted: D, Actual: K
# Predicted: B, Actual: B
# Predicted: J, Actual: G
# Predicted: F, Actual: T
# Predicted: Q, Actual: Q
# Predicted: T, Actual: T
# Predicted: B, Actual: B
# Predicted: S, Actual: Z
# Predicted: U, Actual: I
# Predicted: None, Actual: D
# Predicted: U, Actual: U
# Predicted: H, Actual: K
# Predicted: Y, Actual: Y
# Predicted: W, Actual: W
# Predicted: C, Actual: T
# Predicted: N, Actual: N
# Predicted: P, Actual: P
# Predicted: M, Actual: M
# Predicted: D, Actual: D
# Predicted: Z, Actual: Z
# Predicted: B, Actual: Z
# Predicted: U, Actual: G
# Predicted: None, Actual: F
# Predicted: P, Actual: O
# Predicted: I, Actual: I
# Predicted: P, Actual: P
# Predicted: U, Actual: U
# Predicted: D, Actual: B
# Predicted: Y, Actual: Y
# Predicted: T, Actual: T
# Predicted: Y, Actual: T
# Predicted: F, Actual: F
# Predicted: N, Actual: N
# Predicted: W, Actual: W
# Predicted: None, Actual: I
# Predicted: K, Actual: M
# Predicted: J, Actual: J
# Predicted: W, Actual: G
# Predicted: X, Actual: S
# Predicted: F, Actual: F
# Predicted: P, Actual: Z
# Predicted: V, Actual: V
# Predicted: C, Actual: Y
# Predicted: S, Actual: S
# Predicted: U, Actual: G
# Predicted: B, Actual: D
# Predicted: None, Actual: L
# Predicted: N, Actual: N
# Predicted: Q, Actual: Y
# Predicted: None, Actual: Y
# Predicted: B, Actual: B
# Predicted: Z, Actual: E
# Predicted: E, Actual: E
# Predicted: Y, Actual: Y
# Predicted: D, Actual: I
# Predicted: None, Actual: Q
# Predicted: Z, Actual: Z
# Predicted: U, Actual: U
# Predicted: S, Actual: D
# Predicted: O, Actual: O
# Predicted: R, Actual: K
# Predicted: None, Actual: L
# Predicted: B, Actual: M
# Predicted: A, Actual: A
# Predicted: R, Actual: R
# Predicted: A, Actual: N
# Predicted: D, Actual: D
# Predicted: K, Actual: D
# Predicted: X, Actual: T
# Predicted: T, Actual: Q
# Predicted: I, Actual: I
# Predicted: O, Actual: Q
# Predicted: N, Actual: N
# Predicted: M, Actual: M
# Predicted: P, Actual: P
# Predicted: F, Actual: N
# Predicted: S, Actual: F
# Predicted: F, Actual: P
# Predicted: Y, Actual: C
# Predicted: E, Actual: E
# Predicted: C, Actual: P
# Predicted: K, Actual: K
# Predicted: A, Actual: A
# Predicted: B, Actual: D
# Predicted: G, Actual: W
# Predicted: None, Actual: W
# Predicted: None, Actual: G
# Predicted: F, Actual: F
# Predicted: H, Actual: X
# Predicted: Q, Actual: U
# Predicted: Z, Actual: Z
# Predicted: P, Actual: G
# Predicted: O, Actual: Z
# Predicted: L, Actual: X
# Predicted: D, Actual: I
# Predicted: J, Actual: J
#
# Accuracy: 62.26%
#
# Test Accuracy: 62.26%

# %% [markdown]
# # Ecoli Regression Tree

# %%
import numpy as np
import pandas as pd
from pprint import pprint

# Fetch the E. coli dataset
ecoli = fetch_ucirepo(id=39)

# Data (as pandas dataframes)
X = ecoli.data.features  # Features (attributes)
y = ecoli.data.targets    # Target variable (class)
z = ecoli.targets         # Attribute names

# Place the target variable (class) column as the last column in your data
data = pd.DataFrame(data=X, columns=z)
data['class'] = y  # Add the target variable to the dataframe

# Function to discretize continuous variables
def discretize(data, bins=5):
    for col in data.columns:
        if data[col].dtype != 'object':  # If the column is numeric
            data[col] = pd.cut(data[col], bins, labels=False)
    return data

# Discretize continuous features
data = discretize(data)

# Split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1, random_state=42)  # Shuffle the data
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * (1 - test_size)):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)
X_train, y_train = train_data.iloc[:, :-1], train_data[['class']]
X_test, y_test = test_data.iloc[:, :-1], test_data[['class']]

# Function to calculate entropy for a dataset
def entropy(data, target_attribute='class'):
    values, counts = np.unique(data[target_attribute], return_counts=True)
    entropy = sum((-counts[i] / np.sum(counts)) * np.log2(counts[i] / np.sum(counts)) for i in range(len(values)))
    return entropy

# Function to calculate information gain for a split
def information_gain(data, attribute, target_attribute='class'):
    total_entropy = entropy(data, target_attribute)
    values, counts = np.unique(data[attribute], return_counts=True)
    
    weighted_entropy = sum((counts[i] / np.sum(counts)) * entropy(data[data[attribute] == values[i]], target_attribute) for i in range(len(values)))
    return total_entropy - weighted_entropy

# ID3 Classification Tree Algorithm
def id3_classification(data, original_data, features, target_attribute="class", parent_node_value=None, max_depth=10, depth=0):
    # If all target values have the same value, return that value
    if len(np.unique(data[target_attribute])) <= 1:
        return np.unique(data[target_attribute])[0]
    
    # If dataset is empty, return the most common value in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_attribute])[np.argmax(np.unique(original_data[target_attribute], return_counts=True)[1])]
    
    # If no more features or maximum depth is reached, return the most common value
    elif len(features) == 0 or depth == max_depth:
        return np.unique(data[target_attribute])[np.argmax(np.unique(data[target_attribute], return_counts=True)[1])]
    
    else:
        parent_node_value = np.unique(data[target_attribute])[np.argmax(np.unique(data[target_attribute], return_counts=True)[1])]
        # Find the feature with the highest information gain
        info_gains = [information_gain(data, feature, target_attribute) for feature in features]
        best_feature_index = np.argmax(info_gains)
        best_feature = features[best_feature_index]
        
        # Create the tree structure with the best feature as the root
        tree = {best_feature: {}}
        remaining_features = [i for i in features if i != best_feature]
        
        # Grow tree branches for each value of the best feature
        for value in np.unique(data[best_feature]):
            subset = data[data[best_feature] == value]
            subtree = id3_classification(subset, original_data, remaining_features, target_attribute, parent_node_value, max_depth, depth + 1)
            tree[best_feature][value] = subtree
            
        return tree

# Train the ID3 classification tree on the training data
features = X_train.columns.tolist()  # Use all columns as features
classification_tree = id3_classification(train_data, train_data, features)

# Pretty-print the generated classification tree
pprint(classification_tree)

# Function to predict using the classification tree
def predict_classification(query, tree, default=None):
    # Check if the tree is a leaf node (i.e., a class label)
    if not isinstance(tree, dict):
        return tree  # Leaf node with predicted class label
    
    # Traverse the tree using the query
    for key in list(query.keys()):
        if key in tree:
            result = tree[key].get(query[key], default)
            # If result is a subtree, continue down the tree
            if isinstance(result, dict):
                return predict_classification(query, result, default)
            else:
                return result
    return default  # Return the default if no key is found in the tree

# Test the classification tree on the test data
def test_classification_tree(test_data, tree):
    queries = test_data.to_dict(orient="records")
    predictions = pd.Series([predict_classification(query, tree, default=train_data['class'].mode()[0]) for query in queries], index=test_data.index)
    return predictions

# Predict the values for the test set
predictions = test_classification_tree(X_test, classification_tree)

# Print actual vs predicted values
print("\nActual vs Predicted:")
print(pd.DataFrame({'Actual': y_test['class'], 'Predicted': predictions}))

# Calculate accuracy
accuracy = np.mean(predictions == y_test['class'])
print("\nAccuracy of ID3 Classification Tree:", accuracy)

print(f"\nTest Accuracy: {accuracy*100:.2f}%")
# Out:
# {'alm1': {np.int64(0): 'cp',
#           np.int64(1): {'gvh': {np.int64(0): 'cp',
#                                 np.int64(1): {'mcg': {np.int64(0): 'cp',
#                                                       np.int64(1): {'aac': {np.int64(1): 'cp',
#                                                                             np.int64(2): {'alm2': {np.int64(1): 'cp',
#                                                                                                    np.int64(2): {'lip': {np.int64(0): {'chg': {np.int64(0): 'cp'}}}}}},
#                                                                             np.int64(3): {'alm2': {np.int64(1): 'pp',
#                                                                                                    np.int64(2): 'cp'}}}},
#                                                       np.int64(2): 'cp',
#                                                       np.int64(3): 'cp'}},
#                                 np.int64(2): {'aac': {np.int64(1): {'mcg': {np.int64(0): 'im',
#                                                                             np.int64(3): 'cp'}},
#                                                       np.int64(2): {'mcg': {np.int64(1): 'cp',
#                                                                             np.int64(2): 'cp',
#                                                                             np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): {'alm2': {np.int64(1): 'pp'}}}}}}}},
#                                                       np.int64(3): 'cp',
#                                                       np.int64(4): 'om'}},
#                                 np.int64(3): {'aac': {np.int64(1): 'pp',
#                                                       np.int64(2): {'alm2': {np.int64(0): 'pp',
#                                                                              np.int64(1): {'mcg': {np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): 'pp'}}}}}},
#                                                                              np.int64(2): 'pp'}},
#                                                       np.int64(3): 'om',
#                                                       np.int64(4): 'om'}},
#                                 np.int64(4): 'pp'}},
#           np.int64(2): {'mcg': {np.int64(0): {'gvh': {np.int64(1): 'cp',
#                                                       np.int64(3): 'im'}},
#                                 np.int64(1): {'alm2': {np.int64(1): 'im',
#                                                        np.int64(2): 'cp'}},
#                                 np.int64(2): {'aac': {np.int64(1): 'cp',
#                                                       np.int64(2): {'gvh': {np.int64(1): 'cp',
#                                                                             np.int64(2): {'lip': {np.int64(0): {'chg': {np.int64(0): {'alm2': {np.int64(2): 'cp'}}}}}}}},
#                                                       np.int64(3): 'cp',
#                                                       np.int64(4): 'im'}},
#                                 np.int64(3): {'gvh': {np.int64(1): {'lip': {np.int64(0): {'aac': {np.int64(2): 'cp',
#                                                                                                   np.int64(3): 'imU'}},
#                                                                             np.int64(4): 'omL'}},
#                                                       np.int64(2): {'alm2': {np.int64(0): 'omL',
#                                                                              np.int64(1): {'aac': {np.int64(2): 'pp',
#                                                                                                    np.int64(3): 'om'}},
#                                                                              np.int64(2): 'pp'}},
#                                                       np.int64(3): {'aac': {np.int64(1): 'pp',
#                                                                             np.int64(2): 'pp',
#                                                                             np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): {'alm2': {np.int64(1): 'om'}}}}}},
#                                                                             np.int64(4): 'om'}},
#                                                       np.int64(4): {'aac': {np.int64(2): 'pp',
#                                                                             np.int64(4): 'om'}}}},
#                                 np.int64(4): {'aac': {np.int64(0): 'pp',
#                                                       np.int64(1): 'pp',
#                                                       np.int64(2): {'alm2': {np.int64(0): 'omL',
#                                                                              np.int64(1): {'gvh': {np.int64(1): 'pp',
#                                                                                                    np.int64(2): 'imL'}},
#                                                                              np.int64(2): 'pp',
#                                                                              np.int64(3): 'imU'}},
#                                                       np.int64(3): {'gvh': {np.int64(2): 'imS',
#                                                                             np.int64(3): 'pp'}},
#                                                       np.int64(4): 'om'}}}},
#           np.int64(3): {'mcg': {np.int64(0): 'im',
#                                 np.int64(1): 'im',
#                                 np.int64(2): {'aac': {np.int64(2): 'im',
#                                                       np.int64(3): {'gvh': {np.int64(1): {'alm2': {np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): 'im'}}}},
#                                                                                                    np.int64(4): 'im'}},
#                                                                             np.int64(2): 'im'}}}},
#                                 np.int64(3): {'alm2': {np.int64(1): 'pp',
#                                                        np.int64(2): 'pp',
#                                                        np.int64(3): {'gvh': {np.int64(0): 'imU',
#                                                                              np.int64(1): {'aac': {np.int64(2): 'imU',
#                                                                                                    np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): 'imU'}}}}}},
#                                                                              np.int64(2): {'aac': {np.int64(2): 'im',
#                                                                                                    np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): 'im'}}}},
#                                                                                                    np.int64(4): 'im'}},
#                                                                              np.int64(3): 'im'}},
#                                                        np.int64(4): {'aac': {np.int64(2): 'imU',
#                                                                              np.int64(3): 'im'}}}},
#                                 np.int64(4): {'alm2': {np.int64(1): 'pp',
#                                                        np.int64(3): {'gvh': {np.int64(0): 'imU',
#                                                                              np.int64(1): {'aac': {np.int64(2): {'lip': {np.int64(0): {'chg': {np.int64(0): 'im'}}}},
#                                                                                                    np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): 'imU'}}}}}},
#                                                                              np.int64(2): {'lip': {np.int64(0): {'chg': {np.int64(0): {'aac': {np.int64(2): 'imU'}}}}}},
#                                                                              np.int64(3): 'im'}},
#                                                        np.int64(4): 'imU'}}}},
#           np.int64(4): {'mcg': {np.int64(0): 'im',
#                                 np.int64(1): 'im',
#                                 np.int64(2): 'im',
#                                 np.int64(3): {'gvh': {np.int64(1): {'lip': {np.int64(0): 'im',
#                                                                             np.int64(4): 'imL'}},
#                                                       np.int64(2): {'lip': {np.int64(0): {'chg': {np.int64(0): {'aac': {np.int64(3): {'alm2': {np.int64(4): 'im'}}}}}}}},
#                                                       np.int64(3): 'pp'}},
#                                 np.int64(4): {'gvh': {np.int64(1): {'aac': {np.int64(2): 'imU',
#                                                                             np.int64(3): {'lip': {np.int64(0): {'chg': {np.int64(0): {'alm2': {np.int64(4): 'im'}}}}}}}},
#                                                       np.int64(2): 'imU'}}}}}}
#
# Actual vs Predicted:
#     Actual Predicted
# 292     pp        pp
# 236    imU       imU
# 207     im        im
# 212     im        im
# 306     pp        om
# ..     ...       ...
# 188     im        im
# 71      cp        cp
# 106     cp        cp
# 270     om        om
# 102     cp        cp
#
# [68 rows x 2 columns]
#
# Accuracy of ID3 Classification Tree: 0.75
#
# Test Accuracy: 75.00%

# %% [markdown]
# # Ecoli Classification Tree

# %%
import pandas as pd
import numpy as np
from pprint import pprint
from ucimlrepo import fetch_ucirepo

# Fetch the E. coli dataset
ecoli = fetch_ucirepo(id=39)

# Data (as pandas DataFrames)
X = ecoli.data.features  # Features
y = ecoli.data.targets    # Target variable (class)
z = ecoli.attributes      # Attribute names

# Combine features and target into a single DataFrame
data = pd.DataFrame(data=X, columns=z)
data['class'] = y  # Add the target variable to the DataFrame

# Function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1, random_state=42)  # Shuffle with a fixed seed for reproducibility
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * test_size):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)

# Calculate entropy
def entropy(data, target_col):
    values, counts = np.unique(data[target_col], return_counts=True)
    entropy = -sum((counts[i] / np.sum(counts)) * np.log2(counts[i] / np.sum(counts)) for i in range(len(values)))
    return entropy

# Calculate information gain
def info_gain(data, split_attribute, target_col):
    total_entropy = entropy(data, target_col)
    values, counts = np.unique(data[split_attribute], return_counts=True)
    weighted_entropy = sum((counts[i] / np.sum(counts)) * entropy(data[data[split_attribute] == values[i]], target_col)
                           for i in range(len(values)))
    return total_entropy - weighted_entropy

# ID3 algorithm to build the classification tree
def id3(data, original_data, features, target_col, parent_node=None):
    unique_targets = np.unique(data[target_col])

    # If all target values are the same, return that value
    if len(unique_targets) == 1:
        return unique_targets[0]

    # If the dataset is empty, return the mode target in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_col])[np.argmax(np.unique(original_data[target_col], return_counts=True)[1])]

    # If there are no more features to split on, return the parent node
    elif len(features) == 0:
        return parent_node

    # Otherwise, select the best feature to split on
    else:
        # Set the default value for the parent node (majority class)
        parent_node = np.unique(data[target_col])[np.argmax(np.unique(data[target_col], return_counts=True)[1])]
        
        # Select the feature with the highest information gain
        item_gains = [info_gain(data, feature, target_col) for feature in features]
        best_feature_index = np.argmax(item_gains)
        best_feature = features[best_feature_index]
        
        # Create the tree structure
        tree = {best_feature: {}}
        
        # Remove the best feature from the list of features
        features = [f for f in features if f != best_feature]
        
        # Grow a branch under each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_col, parent_node)
            tree[best_feature][value] = subtree
        
        return tree

# Build the tree using the ID3 algorithm
features = train_data.columns[:-1]  # All columns except the target
target_col = 'class'
tree = id3(train_data, train_data, features, target_col)
print("\nID3 Classification Tree for E. coli Dataset:")
pprint(tree)

# Prediction function to classify new data based on the tree
def predict(tree, instance):
    if not isinstance(tree, dict):
        return tree
    feature = next(iter(tree))
    value = instance[feature]
    if value in tree[feature]:
        return predict(tree[feature][value], instance)
    else:
        return None  # Handle unseen feature values gracefully

# Evaluate the model on the test data
def evaluate(tree, test_data, target_col):
    predictions = test_data.apply(lambda x: predict(tree, x), axis=1)
    actual_values = test_data[target_col]
    accuracy = (predictions == actual_values).mean() * 100
    print("\nPredicted vs Actual:")
    for pred, actual in zip(predictions, actual_values):
        print(f"Predicted: {pred}, Actual: {actual}")
    print(f"\nAccuracy: {accuracy:.2f}%")
    return accuracy

# Test and evaluate the tree
accuracy = evaluate(tree, test_data, target_col)
print(f"\nTest Accuracy: {accuracy:.2f}%")
# Out:
# ID3 Classification Tree for E. coli Dataset:
# {'alm1': {np.float64(0.03): 'cp',
#           np.float64(0.06): 'cp',
#           np.float64(0.11): 'cp',
#           np.float64(0.14): 'cp',
#           np.float64(0.16): 'cp',
#           np.float64(0.17): 'cp',
#           np.float64(0.18): 'cp',
#           np.float64(0.2): 'cp',
#           np.float64(0.21): 'cp',
#           np.float64(0.22): 'cp',
#           np.float64(0.23): 'cp',
#           np.float64(0.24): 'cp',
#           np.float64(0.25): 'cp',
#           np.float64(0.26): 'cp',
#           np.float64(0.27): 'cp',
#           np.float64(0.28): {'gvh': {np.float64(0.3): 'cp',
#                                      np.float64(0.34): 'cp',
#                                      np.float64(0.36): 'cp',
#                                      np.float64(0.39): 'pp',
#                                      np.float64(0.4): 'cp',
#                                      np.float64(0.42): 'cp',
#                                      np.float64(0.43): 'cp',
#                                      np.float64(0.47): 'cp',
#                                      np.float64(0.54): 'cp'}},
#           np.float64(0.29): 'cp',
#           np.float64(0.3): 'cp',
#           np.float64(0.31): {'mcg': {np.float64(0.34): 'cp',
#                                      np.float64(0.41): 'cp',
#                                      np.float64(0.43): 'cp',
#                                      np.float64(0.63): 'pp'}},
#           np.float64(0.32): 'cp',
#           np.float64(0.33): {'mcg': {np.float64(0.25): 'cp',
#                                      np.float64(0.4): 'cp',
#                                      np.float64(0.47): 'cp',
#                                      np.float64(0.54): 'cp',
#                                      np.float64(0.61): 'om'}},
#           np.float64(0.34): 'cp',
#           np.float64(0.35): {'mcg': {np.float64(0.34): 'cp',
#                                      np.float64(0.4): 'cp',
#                                      np.float64(0.43): 'cp',
#                                      np.float64(0.61): 'cp',
#                                      np.float64(0.64): 'cp',
#                                      np.float64(0.71): 'pp'}},
#           np.float64(0.36): {'mcg': {np.float64(0.37): 'cp',
#                                      np.float64(0.51): 'cp',
#                                      np.float64(0.62): 'pp',
#                                      np.float64(0.64): 'pp'}},
#           np.float64(0.37): 'cp',
#           np.float64(0.38): {'mcg': {np.float64(0.27): 'cp',
#                                      np.float64(0.29): 'cp',
#                                      np.float64(0.36): 'cp',
#                                      np.float64(0.52): 'om',
#                                      np.float64(0.66): 'pp',
#                                      np.float64(0.67): 'cp'}},
#           np.float64(0.39): {'mcg': {np.float64(0.16): 'im',
#                                      np.float64(0.37): 'cp',
#                                      np.float64(0.4): 'cp',
#                                      np.float64(0.61): 'pp',
#                                      np.float64(0.63): 'pp',
#                                      np.float64(0.64): 'pp',
#                                      np.float64(0.69): 'om'}},
#           np.float64(0.4): {'gvh': {np.float64(0.39): 'pp',
#                                     np.float64(0.48): 'cp',
#                                     np.float64(0.63): 'om',
#                                     np.float64(0.67): 'pp'}},
#           np.float64(0.41): {'mcg': {np.float64(0.3): 'cp',
#                                      np.float64(0.63): 'om',
#                                      np.float64(0.66): 'pp'}},
#           np.float64(0.42): {'mcg': {np.float64(0.17): 'cp',
#                                      np.float64(0.25): 'cp',
#                                      np.float64(0.29): 'cp',
#                                      np.float64(0.64): 'pp',
#                                      np.float64(0.67): 'pp'}},
#           np.float64(0.43): 'om',
#           np.float64(0.44): {'mcg': {np.float64(0.25): 'cp',
#                                      np.float64(0.29): 'cp',
#                                      np.float64(0.41): 'cp',
#                                      np.float64(0.63): 'pp',
#                                      np.float64(0.69): 'pp'}},
#           np.float64(0.45): {'mcg': {np.float64(0.36): 'cp',
#                                      np.float64(0.43): 'cp',
#                                      np.float64(0.59): 'cp',
#                                      np.float64(0.64): 'pp',
#                                      np.float64(0.67): 'pp'}},
#           np.float64(0.46): 'cp',
#           np.float64(0.47): {'mcg': {np.float64(0.36): 'cp',
#                                      np.float64(0.44): 'im',
#                                      np.float64(0.52): 'cp',
#                                      np.float64(0.57): 'pp',
#                                      np.float64(0.63): 'pp',
#                                      np.float64(0.65): 'pp',
#                                      np.float64(0.75): 'imL'}},
#           np.float64(0.48): 'pp',
#           np.float64(0.49): {'mcg': {np.float64(0.34): 'cp',
#                                      np.float64(0.4): 'cp',
#                                      np.float64(0.62): 'pp',
#                                      np.float64(0.67): 'pp',
#                                      np.float64(0.74): 'pp'}},
#           np.float64(0.5): {'mcg': {np.float64(0.66): 'pp',
#                                     np.float64(0.67): 'om',
#                                     np.float64(0.69): 'pp'}},
#           np.float64(0.51): {'mcg': {np.float64(0.2): 'cp',
#                                      np.float64(0.7): 'pp',
#                                      np.float64(0.73): 'pp'}},
#           np.float64(0.52): {'mcg': {np.float64(0.24): 'cp',
#                                      np.float64(0.44): 'cp',
#                                      np.float64(0.7): 'pp',
#                                      np.float64(0.75): 'pp',
#                                      np.float64(0.85): 'imS'}},
#           np.float64(0.53): 'om',
#           np.float64(0.54): {'gvh': {np.float64(0.49): 'pp',
#                                      np.float64(0.51): 'om',
#                                      np.float64(0.57): 'omL',
#                                      np.float64(0.71): 'pp',
#                                      np.float64(0.78): 'om'}},
#           np.float64(0.55): {'mcg': {np.float64(0.44): 'cp',
#                                      np.float64(0.68): 'omL',
#                                      np.float64(0.72): 'pp'}},
#           np.float64(0.56): 'omL',
#           np.float64(0.57): {'mcg': {np.float64(0.69): 'pp',
#                                      np.float64(0.74): 'pp',
#                                      np.float64(0.75): 'om'}},
#           np.float64(0.58): {'mcg': {np.float64(0.12): 'im',
#                                      np.float64(0.67): 'omL',
#                                      np.float64(0.73): 'om'}},
#           np.float64(0.59): {'mcg': {np.float64(0.6): 'om',
#                                      np.float64(0.71): 'omL',
#                                      np.float64(0.76): 'imU'}},
#           np.float64(0.61): {'mcg': {np.float64(0.3): 'im',
#                                      np.float64(0.5): 'im',
#                                      np.float64(0.64): 'imU'}},
#           np.float64(0.62): 'im',
#           np.float64(0.64): {'mcg': {np.float64(0.5): 'im',
#                                      np.float64(0.67): 'imU'}},
#           np.float64(0.65): {'mcg': {np.float64(0.29): 'im',
#                                      np.float64(0.68): 'pp',
#                                      np.float64(0.74): 'im'}},
#           np.float64(0.66): {'mcg': {np.float64(0.66): 'im',
#                                      np.float64(0.72): 'im',
#                                      np.float64(0.79): 'imU'}},
#           np.float64(0.67): {'mcg': {np.float64(0.1): 'im',
#                                      np.float64(0.6): 'im',
#                                      np.float64(0.81): 'imU'}},
#           np.float64(0.68): 'pp',
#           np.float64(0.7): {'mcg': {np.float64(0.58): 'im',
#                                     np.float64(0.63): 'pp',
#                                     np.float64(0.66): 'imU',
#                                     np.float64(0.75): 'imU'}},
#           np.float64(0.71): 'im',
#           np.float64(0.72): {'mcg': {np.float64(0.39): 'im',
#                                      np.float64(0.63): 'imU',
#                                      np.float64(0.89): 'im'}},
#           np.float64(0.73): {'mcg': {np.float64(0.58): 'imU',
#                                      np.float64(0.63): 'im',
#                                      np.float64(0.64): 'imU',
#                                      np.float64(0.78): 'imU'}},
#           np.float64(0.74): {'mcg': {np.float64(0.45): 'im',
#                                      np.float64(0.47): 'imU',
#                                      np.float64(0.69): 'imU'}},
#           np.float64(0.75): {'mcg': {np.float64(0.41): 'im',
#                                      np.float64(0.43): 'im',
#                                      np.float64(0.59): 'imU',
#                                      np.float64(0.68): 'im',
#                                      np.float64(0.73): 'imU'}},
#           np.float64(0.76): {'mcg': {np.float64(0.34): 'im',
#                                      np.float64(0.37): 'im',
#                                      np.float64(0.47): 'im',
#                                      np.float64(0.52): 'im',
#                                      np.float64(0.63): 'imS',
#                                      np.float64(0.69): 'im',
#                                      np.float64(0.83): 'imU',
#                                      np.float64(0.87): 'imU'}},
#           np.float64(0.77): {'mcg': {np.float64(0.27): 'im',
#                                      np.float64(0.48): 'im',
#                                      np.float64(0.6): 'im',
#                                      np.float64(0.63): 'imU',
#                                      np.float64(0.72): 'imU',
#                                      np.float64(0.78): 'imU'}},
#           np.float64(0.78): {'mcg': {np.float64(0.2): 'im',
#                                      np.float64(0.33): 'im',
#                                      np.float64(0.48): 'im',
#                                      np.float64(0.55): 'im',
#                                      np.float64(0.64): 'im',
#                                      np.float64(0.77): 'imU',
#                                      np.float64(0.81): 'imU'}},
#           np.float64(0.79): 'im',
#           np.float64(0.8): 'im',
#           np.float64(0.81): {'mcg': {np.float64(0.6): 'im',
#                                      np.float64(0.79): 'imU',
#                                      np.float64(0.86): 'imU'}},
#           np.float64(0.82): {'mcg': {np.float64(0.4): 'im',
#                                      np.float64(0.63): 'im',
#                                      np.float64(0.7): 'imL',
#                                      np.float64(0.79): 'imU'}},
#           np.float64(0.84): {'mcg': {np.float64(0.31): 'im',
#                                      np.float64(0.7): 'pp'}},
#           np.float64(0.85): 'im',
#           np.float64(0.86): {'gvh': {np.float64(0.4): 'im',
#                                      np.float64(0.53): 'imU'}},
#           np.float64(0.87): 'im',
#           np.float64(0.88): 'im',
#           np.float64(0.89): 'imU',
#           np.float64(0.9): 'im',
#           np.float64(0.91): 'im',
#           np.float64(0.92): {'mcg': {np.float64(0.06): 'im',
#                                      np.float64(0.84): 'imU'}},
#           np.float64(0.94): 'im',
#           np.float64(1.0): 'im'}}
#
# Predicted vs Actual:
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: im, Actual: im
# Predicted: om, Actual: om
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: imU, Actual: imU
# Predicted: pp, Actual: pp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imS, Actual: imS
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: om, Actual: om
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: om, Actual: om
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: omL, Actual: omL
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: imU, Actual: imU
# Predicted: im, Actual: im
# Predicted: imU, Actual: imU
# Predicted: imU, Actual: imU
# Predicted: imL, Actual: imL
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: imL, Actual: imL
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: pp, Actual: pp
# Predicted: imU, Actual: imU
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: om, Actual: om
# Predicted: cp, Actual: cp
# Predicted: omL, Actual: omL
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: omL, Actual: omL
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: om, Actual: om
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: om, Actual: om
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: omL, Actual: omL
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: imU, Actual: imU
# Predicted: om, Actual: om
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: pp, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: imU, Actual: imU
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: imU, Actual: imU
# Predicted: pp, Actual: pp
# Predicted: imU, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: cp, Actual: cp
# Predicted: pp, Actual: pp
# Predicted: pp, Actual: pp
# Predicted: im, Actual: im
# Predicted: cp, Actual: pp
# Predicted: None, Actual: imU
# Predicted: None, Actual: im
# Predicted: None, Actual: im
# Predicted: None, Actual: pp
# Predicted: im, Actual: imU
# Predicted: cp, Actual: pp
# Predicted: None, Actual: pp
# Predicted: None, Actual: om
# Predicted: None, Actual: im
# Predicted: None, Actual: im
# Predicted: None, Actual: cp
# Predicted: im, Actual: im
# Predicted: None, Actual: im
# Predicted: None, Actual: om
# Predicted: cp, Actual: cp
# Predicted: om, Actual: cp
# Predicted: None, Actual: cp
# Predicted: None, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: im, Actual: im
# Predicted: None, Actual: cp
# Predicted: None, Actual: om
# Predicted: cp, Actual: cp
# Predicted: None, Actual: cp
# Predicted: om, Actual: om
# Predicted: im, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: cp, Actual: cp
# Predicted: None, Actual: om
# Predicted: None, Actual: im
# Predicted: None, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: None, Actual: pp
# Predicted: im, Actual: imU
# Predicted: cp, Actual: cp
# Predicted: None, Actual: cp
# Predicted: None, Actual: im
# Predicted: None, Actual: im
# Predicted: None, Actual: pp
# Predicted: None, Actual: im
# Predicted: im, Actual: im
# Predicted: None, Actual: cp
# Predicted: None, Actual: cp
# Predicted: im, Actual: imU
# Predicted: None, Actual: imU
# Predicted: None, Actual: cp
# Predicted: om, Actual: pp
# Predicted: im, Actual: im
# Predicted: None, Actual: om
# Predicted: None, Actual: im
# Predicted: None, Actual: pp
# Predicted: None, Actual: imU
# Predicted: None, Actual: pp
# Predicted: None, Actual: im
# Predicted: pp, Actual: cp
# Predicted: im, Actual: im
# Predicted: None, Actual: cp
# Predicted: None, Actual: cp
# Predicted: None, Actual: im
# Predicted: cp, Actual: cp
# Predicted: om, Actual: pp
# Predicted: cp, Actual: cp
# Predicted: None, Actual: im
# Predicted: cp, Actual: cp
# Predicted: None, Actual: cp
# Predicted: None, Actual: om
# Predicted: cp, Actual: cp
#
# Accuracy: 81.04%
#
# Test Accuracy: 81.04%

# %% [markdown]
# # Robot Execution Failures

# %% [markdown]
# # Split test and train data Robot Data Set

# %%
# Read and concatenate the robotic failure datasets
data = pd.concat([pd.read_csv('LP1.csv'), pd.read_csv('LP2.csv'), pd.read_csv('LP3.csv'), pd.read_csv('LP4.csv'), pd.read_csv('LP5.csv')], ignore_index=True)

# Drop the 'ok' column if it exists
if 'ok' in data.columns:
    data = data.drop(columns=['ok'])

# Forward-fill missing values in the 'Target' column and fill remaining NaNs with 'normal'
data['normal'] = data['normal'].ffill().fillna('normal')

# Rename 'normal' to 'Target' and the first six columns as requested
data.columns = ['Target', 'Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'] + list(data.columns[7:])

# Remove rows with any missing values in Fx, Fy, Fz, Tx, Ty, or Tz columns
data.dropna(subset=['Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'], inplace=True)

# Move the 'Target' column to the last position
columns = [col for col in data.columns if col != 'Target'] + ['Target']
data = data[columns]

# Save the cleaned dataset to a new CSV file
data.to_csv('LP_Sorted_Dataset.csv', index=False)

# Display the first few rows of the processed data to verify
print(data)

# 3) Create a function to split the dataset into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1)  # Shuffle the data
    train_data = data.iloc[:int(len(data)*(1-test_size))]
    test_data = data.iloc[int(len(data)*(1-test_size)):]
    return train_data, test_data

# Split the data into 80% training and 20% testing
train_data, test_data = split_data(data, 0.2)
print("Training Data:")
print(train_data.head())
print(train_data.shape)

print("\nTesting Data:")
print(test_data.head())
print(test_data.shape)
# Out:
#        Fx   Fy    Fz   Tx   Ty   Tz             Target
# 0    -1.0 -1.0  63.0 -3.0 -1.0  0.0             normal
# 1     0.0  0.0  62.0 -3.0 -1.0  0.0             normal
# 2    -1.0 -1.0  61.0 -3.0  0.0  0.0             normal
# 3    -1.0 -1.0  63.0 -2.0 -1.0  0.0             normal
# 4    -1.0 -1.0  63.0 -3.0 -1.0  0.0             normal
# ...   ...  ...   ...  ...  ...  ...                ...
# 8314  1.0  1.0   8.0  0.0  3.0 -4.0  collision_in_tool
# 8315  0.0  0.0   5.0  0.0  3.0 -4.0  collision_in_tool
# 8316 -1.0  1.0  -3.0 -3.0 -2.0 -3.0  collision_in_tool
# 8317  0.0 -1.0  -5.0 -1.0  1.0 -3.0  collision_in_tool
# 8318 -1.0  1.0   4.0  0.0 -1.0 -3.0  collision_in_tool
#
# [6945 rows x 7 columns]
# Training Data:
#         Fx    Fy     Fz    Tx     Ty   Tz             Target
# 5733  81.0  18.0  104.0 -44.0  110.0 -7.0  collision_in_tool
# 4806   7.0   3.0 -160.0  10.0    4.0  4.0        obstruction
# 1822  -5.0  -9.0   86.0   9.0  -22.0 -2.0             normal
# 6348  -2.0   1.0   19.0   4.0   -6.0  0.0             normal
# 7970  -3.0   2.0    2.0  -4.0    2.0  3.0   bottom_collision
# (5556, 7)
#
# Testing Data:
#         Fx    Fy    Fz    Tx    Ty   Tz             Target
# 5266 -76.0  46.0 -25.0 -47.0 -95.0 -3.0          collision
# 1689  -5.0   4.0  77.0 -20.0 -22.0 -6.0             normal
# 4853  -1.0  -1.0   7.0  -1.0   2.0  2.0          collision
# 6783   0.0   1.0   8.0   2.0   4.0 -3.0  collision_in_part
# 223   -2.0   1.0  57.0  -6.0  -3.0  0.0             normal
# (1389, 7)

# %% [markdown]
# # Regression Tree Robot Data Set

# %%
# Load the data and clean it as specified
data = pd.concat([pd.read_csv('LP1.csv'), pd.read_csv('LP2.csv'), pd.read_csv('LP3.csv'), pd.read_csv('LP4.csv'), pd.read_csv('LP5.csv')], ignore_index=True)

# Drop 'ok' column if it exists and clean target values
if 'ok' in data.columns:
    data = data.drop(columns=['ok'])

data['normal'] = data['normal'].ffill().fillna('normal')
data.columns = ['Target', 'Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'] + list(data.columns[7:])
data.dropna(subset=['Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'], inplace=True)
data = data[[col for col in data.columns if col != 'Target'] + ['Target']]

# Split data into train and test sets
def split_data(data, test_size):
    data = data.sample(frac=1, random_state=42)  # Shuffle with fixed seed
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * (1 - test_size)):]
    return train_data, test_data

train_data, test_data = split_data(data, 0.2)

# Calculate entropy
def entropy(data, target_col):
    values, counts = np.unique(data[target_col], return_counts=True)
    entropy = -sum((counts[i] / np.sum(counts)) * np.log2(counts[i] / np.sum(counts)) for i in range(len(values)))
    return entropy

# Calculate information gain
def info_gain(data, split_attribute, target_col):
    total_entropy = entropy(data, target_col)
    values, counts = np.unique(data[split_attribute], return_counts=True)
    weighted_entropy = sum((counts[i] / np.sum(counts)) * entropy(data[data[split_attribute] == values[i]], target_col)
                           for i in range(len(values)))
    return total_entropy - weighted_entropy

# ID3 algorithm to build tree
def id3(data, original_data, features, target_col, parent_node=None):
    unique_targets = np.unique(data[target_col])

    if len(unique_targets) == 1:
        return unique_targets[0]

    elif len(data) == 0:
        most_common_target = np.unique(original_data[target_col])[np.argmax(np.unique(original_data[target_col], return_counts=True)[1])]
        return most_common_target

    elif len(features) == 0:
        return parent_node

    else:
        parent_node = np.unique(data[target_col])[np.argmax(np.unique(data[target_col], return_counts=True)[1])]
        item_gains = [info_gain(data, feature, target_col) for feature in features]
        best_feature_index = np.argmax(item_gains)
        best_feature = features[best_feature_index]

        tree = {best_feature: {}}
        features = [f for f in features if f != best_feature]

        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_col, parent_node)
            tree[best_feature][value] = subtree

        return tree

# Build the tree
features = train_data.columns[:-1]  # All columns except the target
target_col = 'Target'
tree = id3(train_data, train_data, features, target_col)
print("\nID3 Decision Tree:")
pprint(tree)

# Prediction function for new data
def predict(tree, instance):
    if not isinstance(tree, dict):
        return tree
    feature = next(iter(tree))
    value = instance[feature]
    if value in tree[feature]:
        return predict(tree[feature][value], instance)
    else:
        return np.nan  # if a value in test set not in training splits

# Make predictions and calculate accuracy
predictions = test_data.apply(lambda x: predict(tree, x), axis=1)
actual_values = test_data['Target']

# Calculate accuracy
accuracy = (predictions == actual_values).mean() * 100
print("\nPredicted vs Actual:")
for pred, actual in zip(predictions, actual_values):
    print(f"Predicted: {pred}, Actual: {actual}")

print(f"\nAccuracy: {accuracy:.2f}%")
# Out:
# ID3 Decision Tree:
# {'Fz': {np.float64(-3617.0): {'Fx': {np.float64(353.0): {'Fy': {np.float64(-169.0): {'Tx': {np.float64(324.0): {'Ty': {np.float64(-265.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3557.0): 'bottom_obstruction',
#         np.float64(-3451.0): {'Fx': {np.float64(-883.0): {'Fy': {np.float64(-260.0): {'Tx': {np.float64(-175.0): {'Ty': {np.float64(-434.0): {'Tz': {np.float64(21.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3348.0): {'Fx': {np.float64(351.0): {'Fy': {np.float64(-368.0): {'Tx': {np.float64(282.0): {'Ty': {np.float64(-62.0): {'Tz': {np.float64(-31.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3292.0): {'Fx': {np.float64(337.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(290.0): {'Ty': {np.float64(-78.0): {'Tz': {np.float64(-34.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3281.0): 'obstruction',
#         np.float64(-3277.0): {'Fx': {np.float64(460.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(307.0): {'Ty': {np.float64(-169.0): {'Tz': {np.float64(23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3275.0): {'Fx': {np.float64(462.0): {'Fy': {np.float64(-59.0): {'Tx': {np.float64(285.0): {'Ty': {np.float64(-183.0): {'Tz': {np.float64(17.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3261.0): {'Fx': {np.float64(337.0): {'Fy': {np.float64(-170.0): {'Tx': {np.float64(300.0): {'Ty': {np.float64(-243.0): {'Tz': {np.float64(54.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3235.0): {'Fx': {np.float64(142.0): {'Fy': {np.float64(438.0): {'Tx': {np.float64(536.0): {'Ty': {np.float64(-250.0): {'Tz': {np.float64(201.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3234.0): {'Fx': {np.float64(448.0): {'Fy': {np.float64(-73.0): {'Tx': {np.float64(313.0): {'Ty': {np.float64(-169.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3226.0): {'Fx': {np.float64(460.0): {'Fy': {np.float64(-41.0): {'Tx': {np.float64(250.0): {'Ty': {np.float64(-205.0): {'Tz': {np.float64(23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3224.0): {'Fx': {np.float64(328.0): {'Fy': {np.float64(-360.0): {'Tx': {np.float64(291.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(-30.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3195.0): {'Fx': {np.float64(322.0): {'Fy': {np.float64(-338.0): {'Tx': {np.float64(280.0): {'Ty': {np.float64(-64.0): {'Tz': {np.float64(-34.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3161.0): 'obstruction',
#         np.float64(-3089.0): {'Fx': {np.float64(119.0): {'Fy': {np.float64(354.0): {'Tx': {np.float64(567.0): {'Ty': {np.float64(-232.0): {'Tz': {np.float64(161.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3051.0): 'bottom_obstruction',
#         np.float64(-3028.0): {'Fx': {np.float64(-473.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(77.0): {'Ty': {np.float64(211.0): {'Tz': {np.float64(-167.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3018.0): {'Fx': {np.float64(-492.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(185.0): {'Ty': {np.float64(72.0): {'Tz': {np.float64(-199.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2992.0): {'Fx': {np.float64(-480.0): {'Fy': {np.float64(-319.0): {'Tx': {np.float64(-132.0): {'Ty': {np.float64(170.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2973.0): {'Fx': {np.float64(-851.0): {'Fy': {np.float64(-235.0): {'Tx': {np.float64(-102.0): {'Ty': {np.float64(-506.0): {'Tz': {np.float64(8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2966.0): 'obstruction',
#         np.float64(-2958.0): 'obstruction',
#         np.float64(-2955.0): {'Fx': {np.float64(-497.0): {'Fy': {np.float64(-297.0): {'Tx': {np.float64(-199.0): {'Ty': {np.float64(169.0): {'Tz': {np.float64(20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2950.0): {'Fx': {np.float64(317.0): {'Fy': {np.float64(242.0): {'Tx': {np.float64(231.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(16.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2943.0): 'obstruction',
#         np.float64(-2929.0): {'Fx': {np.float64(213.0): {'Fy': {np.float64(-189.0): {'Tx': {np.float64(133.0): {'Ty': {np.float64(-35.0): {'Tz': {np.float64(-22.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2804.0): 'bottom_obstruction',
#         np.float64(-2795.0): 'obstruction',
#         np.float64(-2792.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-184.0): {'Tx': {np.float64(113.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-12.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2788.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-184.0): {'Tx': {np.float64(113.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2785.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-183.0): {'Tx': {np.float64(112.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'obstruction'}}}}}}}}}},
#         np.float64(-2781.0): {'Fx': {np.float64(97.0): {'Fy': {np.float64(276.0): {'Tx': {np.float64(620.0): {'Ty': {np.float64(-238.0): {'Tz': {np.float64(144.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(210.0): {'Fy': {np.float64(-183.0): {'Tx': {np.float64(112.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2761.0): {'Fx': {np.float64(-424.0): {'Fy': {np.float64(-328.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(52.0): {'Tz': {np.float64(-21.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2757.0): {'Fx': {np.float64(-389.0): {'Fy': {np.float64(91.0): {'Tx': {np.float64(-107.0): {'Ty': {np.float64(114.0): {'Tz': {np.float64(-55.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2718.0): 'bottom_obstruction',
#         np.float64(-2693.0): {'Fx': {np.float64(-138.0): {'Fy': {np.float64(-331.0): {'Tx': {np.float64(-142.0): {'Ty': {np.float64(194.0): {'Tz': {np.float64(8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2690.0): 'bottom_obstruction',
#         np.float64(-2680.0): {'Fx': {np.float64(-139.0): {'Fy': {np.float64(-328.0): {'Tx': {np.float64(-147.0): {'Ty': {np.float64(223.0): {'Tz': {np.float64(6.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(-136.0): {'Fy': {np.float64(-326.0): {'Tx': {np.float64(-156.0): {'Ty': {np.float64(208.0): {'Tz': {np.float64(4.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2672.0): {'Fx': {np.float64(-134.0): {'Fy': {np.float64(-325.0): {'Tx': {np.float64(-158.0): {'Ty': {np.float64(207.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2652.0): 'bottom_obstruction',
#         np.float64(-2619.0): 'obstruction',
#         np.float64(-2616.0): {'Fx': {np.float64(-125.0): {'Fy': {np.float64(-311.0): {'Tx': {np.float64(-189.0): {'Ty': {np.float64(227.0): {'Tz': {np.float64(3.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(-123.0): 'obstruction'}},
#         np.float64(-2589.0): 'obstruction',
#         np.float64(-2542.0): {'Fx': {np.float64(-262.0): {'Fy': {np.float64(98.0): {'Tx': {np.float64(-131.0): {'Ty': {np.float64(305.0): {'Tz': {np.float64(-13.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(166.0): {'Fy': {np.float64(-155.0): {'Tx': {np.float64(143.0): {'Ty': {np.float64(-32.0): {'Tz': {np.float64(-35.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2460.0): 'obstruction',
#         np.float64(-2387.0): {'Fx': {np.float64(105.0): {'Fy': {np.float64(197.0): {'Tx': {np.float64(605.0): {'Ty': {np.float64(-171.0): {'Tz': {np.float64(135.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2325.0): {'Fx': {np.float64(206.0): {'Fy': {np.float64(-344.0): {'Tx': {np.float64(-287.0): {'Ty': {np.float64(-499.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2323.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-345.0): {'Tx': {np.float64(-287.0): {'Ty': {np.float64(-501.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2319.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-344.0): {'Tx': {np.float64(-284.0): {'Ty': {np.float64(-498.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2316.0): 'obstruction',
#         np.float64(-2315.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-343.0): {'Tx': {np.float64(-284.0): {'Ty': {np.float64(-499.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2306.0): {'Fx': {np.float64(260.0): {'Fy': {np.float64(107.0): {'Tx': {np.float64(377.0): {'Ty': {np.float64(40.0): {'Tz': {np.float64(45.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2305.0): {'Fx': {np.float64(211.0): {'Fy': {np.float64(-165.0): {'Tx': {np.float64(-43.0): {'Ty': {np.float64(-567.0): {'Tz': {np.float64(30.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2303.0): {'Fx': {np.float64(305.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(225.0): {'Ty': {np.float64(-125.0): {'Tz': {np.float64(88.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2233.0): {'Fx': {np.float64(-240.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(-153.0): {'Ty': {np.float64(274.0): {'Tz': {np.float64(-248.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2203.0): 'obstruction',
#         np.float64(-2176.0): {'Fx': {np.float64(-49.0): {'Fy': {np.float64(-98.0): {'Tx': {np.float64(282.0): {'Ty': {np.float64(-126.0): {'Tz': {np.float64(-128.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2135.0): {'Fx': {np.float64(-168.0): {'Fy': {np.float64(107.0): {'Tx': {np.float64(-172.0): {'Ty': {np.float64(406.0): {'Tz': {np.float64(32.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2112.0): {'Fx': {np.float64(87.0): {'Fy': {np.float64(-117.0): {'Tx': {np.float64(154.0): {'Ty': {np.float64(81.0): {'Tz': {np.float64(-150.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-2088.0): {'Fx': {np.float64(217.0): {'Fy': {np.float64(-155.0): {'Tx': {np.float64(-100.0): {'Ty': {np.float64(-568.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2043.0): {'Fx': {np.float64(241.0): {'Fy': {np.float64(-175.0): {'Tx': {np.float64(-110.0): {'Ty': {np.float64(-576.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2021.0): {'Fx': {np.float64(-377.0): {'Fy': {np.float64(-198.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(167.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1995.0): 'bottom_obstruction',
#         np.float64(-1744.0): {'Fx': {np.float64(112.0): {'Fy': {np.float64(115.0): {'Tx': {np.float64(476.0): {'Ty': {np.float64(-13.0): {'Tz': {np.float64(149.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1738.0): {'Fx': {np.float64(204.0): {'Fy': {np.float64(-154.0): {'Tx': {np.float64(-76.0): {'Ty': {np.float64(-498.0): {'Tz': {np.float64(35.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1654.0): 'obstruction',
#         np.float64(-1627.0): {'Fx': {np.float64(-64.0): {'Fy': {np.float64(84.0): {'Tx': {np.float64(-127.0): {'Ty': {np.float64(464.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(205.0): {'Fy': {np.float64(-147.0): {'Tx': {np.float64(-68.0): {'Ty': {np.float64(-487.0): {'Tz': {np.float64(19.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1622.0): 'bottom_obstruction',
#         np.float64(-1619.0): {'Fx': {np.float64(227.0): {'Fy': {np.float64(-141.0): {'Tx': {np.float64(-130.0): {'Ty': {np.float64(-492.0): {'Tz': {np.float64(18.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1615.0): {'Fx': {np.float64(-261.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(106.0): {'Ty': {np.float64(58.0): {'Tz': {np.float64(-36.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1582.0): {'Fx': {np.float64(-253.0): {'Fy': {np.float64(-69.0): {'Tx': {np.float64(136.0): {'Ty': {np.float64(48.0): {'Tz': {np.float64(-27.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1547.0): 'obstruction',
#         np.float64(-1491.0): 'obstruction',
#         np.float64(-1437.0): 'obstruction',
#         np.float64(-1436.0): 'obstruction',
#         np.float64(-1428.0): 'obstruction',
#         np.float64(-1421.0): 'bottom_obstruction',
#         np.float64(-1415.0): {'Fx': {np.float64(-3.0): {'Fy': {np.float64(-95.0): {'Tx': {np.float64(-68.0): {'Ty': {np.float64(207.0): {'Tz': {np.float64(-29.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1409.0): 'obstruction',
#         np.float64(-1407.0): 'obstruction',
#         np.float64(-1387.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(229.0): {'Ty': {np.float64(402.0): {'Tz': {np.float64(-43.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-1384.0): {'Fx': {np.float64(36.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-101.0): {'Ty': {np.float64(-161.0): {'Tz': {np.float64(-59.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1371.0): 'obstruction',
#         np.float64(-1368.0): 'obstruction',
#         np.float64(-1360.0): 'obstruction',
#         np.float64(-1358.0): {'Fx': {np.float64(-254.0): {'Fy': {np.float64(-76.0): {'Tx': {np.float64(170.0): {'Ty': {np.float64(-44.0): {'Tz': {np.float64(-20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1357.0): 'obstruction',
#         np.float64(-1344.0): 'obstruction',
#         np.float64(-1340.0): 'obstruction',
#         np.float64(-1337.0): {'Fx': {np.float64(-43.0): {'Fy': {np.float64(-52.0): {'Tx': {np.float64(237.0): {'Ty': {np.float64(-95.0): {'Tz': {np.float64(-88.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1334.0): 'obstruction',
#         np.float64(-1326.0): 'obstruction',
#         np.float64(-1302.0): 'obstruction',
#         np.float64(-1299.0): 'obstruction',
#         np.float64(-1287.0): 'obstruction',
#         np.float64(-1286.0): 'obstruction',
#         np.float64(-1278.0): 'obstruction',
#         np.float64(-1274.0): 'obstruction',
#         np.float64(-1267.0): 'obstruction',
#         np.float64(-1266.0): 'obstruction',
#         np.float64(-1264.0): 'obstruction',
#         np.float64(-1262.0): 'obstruction',
#         np.float64(-1252.0): 'obstruction',
#         np.float64(-1251.0): 'obstruction',
#         np.float64(-1248.0): 'obstruction',
#         np.float64(-1242.0): 'obstruction',
#         np.float64(-1241.0): 'obstruction',
#         np.float64(-1238.0): 'obstruction',
#         np.float64(-1235.0): 'obstruction',
#         np.float64(-1230.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-166.0): {'Ty': {np.float64(-199.0): {'Tz': {np.float64(-91.0): 'obstruction'}}}}}}}}}},
#         np.float64(-1227.0): 'obstruction',
#         np.float64(-1221.0): {'Fx': {np.float64(-1.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-169.0): {'Ty': {np.float64(-216.0): {'Tz': {np.float64(-83.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1218.0): 'obstruction',
#         np.float64(-1175.0): 'collision',
#         np.float64(-1173.0): 'obstruction',
#         np.float64(-1168.0): 'obstruction',
#         np.float64(-1162.0): 'obstruction',
#         np.float64(-1130.0): 'obstruction',
#         np.float64(-1120.0): {'Fx': {np.float64(88.0): {'Fy': {np.float64(4.0): {'Tx': {np.float64(283.0): {'Ty': {np.float64(-89.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1108.0): 'obstruction',
#         np.float64(-1107.0): 'obstruction',
#         np.float64(-1104.0): 'obstruction',
#         np.float64(-1083.0): 'obstruction',
#         np.float64(-1082.0): 'obstruction',
#         np.float64(-1077.0): 'obstruction',
#         np.float64(-1074.0): 'obstruction',
#         np.float64(-1041.0): 'obstruction',
#         np.float64(-1036.0): 'obstruction',
#         np.float64(-1018.0): 'obstruction',
#         np.float64(-1008.0): 'obstruction',
#         np.float64(-996.0): {'Fx': {np.float64(-241.0): {'Fy': {np.float64(-72.0): {'Tx': {np.float64(174.0): {'Ty': {np.float64(-171.0): {'Tz': {np.float64(-20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-991.0): 'obstruction',
#         np.float64(-987.0): 'obstruction',
#         np.float64(-969.0): {'Fx': {np.float64(129.0): {'Fy': {np.float64(49.0): {'Tx': {np.float64(155.0): {'Ty': {np.float64(103.0): {'Tz': {np.float64(38.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-968.0): 'obstruction',
#         np.float64(-966.0): 'obstruction',
#         np.float64(-957.0): 'obstruction',
#         np.float64(-931.0): {'Fx': {np.float64(-86.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(-94.0): {'Ty': {np.float64(100.0): {'Tz': {np.float64(-15.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-930.0): 'obstruction',
#         np.float64(-929.0): 'obstruction',
#         np.float64(-927.0): 'obstruction',
#         np.float64(-923.0): 'obstruction',
#         np.float64(-918.0): 'obstruction',
#         np.float64(-912.0): 'obstruction',
#         np.float64(-887.0): 'obstruction',
#         np.float64(-878.0): 'obstruction',
#         np.float64(-877.0): 'obstruction',
#         np.float64(-866.0): 'obstruction',
#         np.float64(-860.0): {'Fx': {np.float64(20.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(143.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-844.0): {'Fx': {np.float64(-47.0): {'Fy': {np.float64(-59.0): {'Tx': {np.float64(747.0): {'Ty': {np.float64(85.0): {'Tz': {np.float64(244.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-843.0): 'obstruction',
#         np.float64(-826.0): 'obstruction',
#         np.float64(-812.0): 'obstruction',
#         np.float64(-807.0): 'obstruction',
#         np.float64(-800.0): 'obstruction',
#         np.float64(-786.0): 'obstruction',
#         np.float64(-783.0): 'obstruction',
#         np.float64(-780.0): 'obstruction',
#         np.float64(-779.0): 'obstruction',
#         np.float64(-771.0): {'Fx': {np.float64(-203.0): {'Fy': {np.float64(-57.0): {'Tx': {np.float64(138.0): {'Ty': {np.float64(-188.0): {'Tz': {np.float64(-9.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-768.0): 'obstruction',
#         np.float64(-738.0): 'obstruction',
#         np.float64(-735.0): 'obstruction',
#         np.float64(-728.0): 'obstruction',
#         np.float64(-727.0): 'obstruction',
#         np.float64(-723.0): 'obstruction',
#         np.float64(-702.0): 'obstruction',
#         np.float64(-701.0): 'collision',
#         np.float64(-685.0): 'obstruction',
#         np.float64(-683.0): 'obstruction',
#         np.float64(-669.0): 'obstruction',
#         np.float64(-667.0): 'obstruction',
#         np.float64(-657.0): 'obstruction',
#         np.float64(-655.0): {'Fx': {np.float64(87.0): {'Fy': {np.float64(-86.0): {'Tx': {np.float64(-9.0): {'Ty': {np.float64(-193.0): {'Tz': {np.float64(21.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-654.0): 'obstruction',
#         np.float64(-650.0): 'obstruction',
#         np.float64(-640.0): 'obstruction',
#         np.float64(-637.0): 'obstruction',
#         np.float64(-629.0): {'Fx': {np.float64(-1.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(156.0): {'Ty': {np.float64(247.0): {'Tz': {np.float64(-21.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-628.0): 'obstruction',
#         np.float64(-626.0): 'obstruction',
#         np.float64(-621.0): 'obstruction',
#         np.float64(-614.0): 'obstruction',
#         np.float64(-606.0): 'obstruction',
#         np.float64(-605.0): 'obstruction',
#         np.float64(-604.0): 'bottom_obstruction',
#         np.float64(-603.0): 'obstruction',
#         np.float64(-601.0): 'obstruction',
#         np.float64(-599.0): 'obstruction',
#         np.float64(-598.0): 'obstruction',
#         np.float64(-595.0): 'obstruction',
#         np.float64(-594.0): 'obstruction',
#         np.float64(-590.0): 'obstruction',
#         np.float64(-589.0): 'obstruction',
#         np.float64(-588.0): 'obstruction',
#         np.float64(-586.0): 'obstruction',
#         np.float64(-584.0): 'obstruction',
#         np.float64(-581.0): 'obstruction',
#         np.float64(-567.0): 'obstruction',
#         np.float64(-564.0): 'bottom_obstruction',
#         np.float64(-559.0): {'Fx': {np.float64(-45.0): {'Fy': {np.float64(-24.0): {'Tx': {np.float64(122.0): {'Ty': {np.float64(-98.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-558.0): 'obstruction',
#         np.float64(-554.0): 'obstruction',
#         np.float64(-553.0): 'obstruction',
#         np.float64(-540.0): 'obstruction',
#         np.float64(-526.0): {'Fx': {np.float64(-33.0): {'Fy': {np.float64(-13.0): {'Tx': {np.float64(-114.0): {'Ty': {np.float64(39.0): {'Tz': {np.float64(-47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-524.0): 'obstruction',
#         np.float64(-517.0): {'Fx': {np.float64(1.0): {'Fy': {np.float64(-26.0): {'Tx': {np.float64(95.0): {'Ty': {np.float64(40.0): {'Tz': {np.float64(-33.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-515.0): 'obstruction',
#         np.float64(-511.0): 'obstruction',
#         np.float64(-498.0): 'obstruction',
#         np.float64(-496.0): 'bottom_collision',
#         np.float64(-491.0): {'Fx': {np.float64(-198.0): {'Fy': {np.float64(68.0): {'Tx': {np.float64(-381.0): {'Ty': {np.float64(-459.0): {'Tz': {np.float64(38.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-488.0): 'obstruction',
#         np.float64(-487.0): 'obstruction',
#         np.float64(-486.0): 'obstruction',
#         np.float64(-481.0): 'obstruction',
#         np.float64(-477.0): 'obstruction',
#         np.float64(-476.0): 'obstruction',
#         np.float64(-472.0): 'obstruction',
#         np.float64(-469.0): {'Fx': {np.float64(86.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(-52.0): {'Ty': {np.float64(-92.0): {'Tz': {np.float64(0.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-462.0): 'obstruction',
#         np.float64(-461.0): 'obstruction',
#         np.float64(-457.0): 'obstruction',
#         np.float64(-456.0): 'obstruction',
#         np.float64(-454.0): 'obstruction',
#         np.float64(-451.0): 'obstruction',
#         np.float64(-445.0): {'Fx': {np.float64(-101.0): {'Fy': {np.float64(-47.0): {'Tx': {np.float64(80.0): {'Ty': {np.float64(-72.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-444.0): 'obstruction',
#         np.float64(-441.0): 'obstruction',
#         np.float64(-438.0): 'obstruction',
#         np.float64(-437.0): 'obstruction',
#         np.float64(-434.0): 'obstruction',
#         np.float64(-431.0): {'Fx': {np.float64(-21.0): {'Fy': {np.float64(-40.0): {'Tx': {np.float64(-90.0): {'Ty': {np.float64(96.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-2.0): 'obstruction'}},
#         np.float64(-429.0): 'obstruction',
#         np.float64(-426.0): 'obstruction',
#         np.float64(-424.0): 'obstruction',
#         np.float64(-421.0): 'obstruction',
#         np.float64(-417.0): {'Fx': {np.float64(-79.0): {'Fy': {np.float64(-43.0): {'Tx': {np.float64(79.0): {'Ty': {np.float64(-20.0): {'Tz': {np.float64(-11.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-415.0): 'obstruction',
#         np.float64(-414.0): 'obstruction',
#         np.float64(-413.0): {'Fx': {np.float64(-107.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(70.0): {'Ty': {np.float64(-101.0): {'Tz': {np.float64(-12.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-411.0): 'obstruction',
#         np.float64(-408.0): 'obstruction',
#         np.float64(-406.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-20.0): {'Tx': {np.float64(63.0): {'Ty': {np.float64(68.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-405.0): 'bottom_obstruction',
#         np.float64(-404.0): 'obstruction',
#         np.float64(-399.0): 'obstruction',
#         np.float64(-398.0): 'obstruction',
#         np.float64(-396.0): 'obstruction',
#         np.float64(-394.0): 'fr_collision',
#         np.float64(-386.0): 'obstruction',
#         np.float64(-380.0): 'obstruction',
#         np.float64(-378.0): 'obstruction',
#         np.float64(-371.0): 'bottom_obstruction',
#         np.float64(-368.0): 'obstruction',
#         np.float64(-364.0): 'obstruction',
#         np.float64(-359.0): {'Fx': {np.float64(-27.0): {'Fy': {np.float64(-28.0): {'Tx': {np.float64(-2.0): {'Ty': {np.float64(5.0): {'Tz': {np.float64(-45.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(-18.0): 'obstruction'}},
#         np.float64(-355.0): 'bottom_collision',
#         np.float64(-353.0): 'obstruction',
#         np.float64(-348.0): 'obstruction',
#         np.float64(-346.0): 'obstruction',
#         np.float64(-345.0): {'Fx': {np.float64(-81.0): 'collision',
#                                     np.float64(-15.0): 'obstruction',
#                                     np.float64(5.0): 'obstruction'}},
#         np.float64(-343.0): 'obstruction',
#         np.float64(-342.0): 'obstruction',
#         np.float64(-341.0): 'obstruction',
#         np.float64(-338.0): 'obstruction',
#         np.float64(-336.0): 'obstruction',
#         np.float64(-335.0): 'obstruction',
#         np.float64(-332.0): {'Fx': {np.float64(-52.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(49.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(49.0): 'obstruction',
#                                     np.float64(59.0): 'bottom_collision'}},
#         np.float64(-331.0): 'obstruction',
#         np.float64(-328.0): {'Fx': {np.float64(-16.0): 'fr_collision',
#                                     np.float64(49.0): 'obstruction'}},
#         np.float64(-325.0): 'obstruction',
#         np.float64(-324.0): 'obstruction',
#         np.float64(-323.0): 'obstruction',
#         np.float64(-322.0): 'obstruction',
#         np.float64(-316.0): {'Fx': {np.float64(45.0): {'Fy': {np.float64(-71.0): {'Tx': {np.float64(62.0): {'Ty': {np.float64(-79.0): {'Tz': {np.float64(25.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-313.0): {'Fx': {np.float64(-20.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(-20.0): {'Ty': {np.float64(11.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(53.0): 'obstruction'}},
#         np.float64(-305.0): 'obstruction',
#         np.float64(-303.0): 'fr_collision',
#         np.float64(-302.0): {'Fx': {np.float64(-272.0): {'Fy': {np.float64(-227.0): {'Tx': {np.float64(173.0): {'Ty': {np.float64(-413.0): {'Tz': {np.float64(-49.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(43.0): {'Fy': {np.float64(-46.0): {'Tx': {np.float64(35.0): {'Ty': {np.float64(-76.0): {'Tz': {np.float64(6.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-301.0): 'obstruction',
#         np.float64(-300.0): 'obstruction',
#         np.float64(-297.0): 'obstruction',
#         np.float64(-296.0): 'obstruction',
#         np.float64(-294.0): 'obstruction',
#         np.float64(-293.0): {'Fx': {np.float64(44.0): {'Fy': {np.float64(-38.0): {'Tx': {np.float64(-17.0): {'Ty': {np.float64(-75.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-291.0): 'obstruction',
#         np.float64(-284.0): {'Fx': {np.float64(38.0): {'Fy': {np.float64(-64.0): {'Tx': {np.float64(63.0): {'Ty': {np.float64(-78.0): {'Tz': {np.float64(32.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-278.0): 'fr_collision',
#         np.float64(-276.0): 'obstruction',
#         np.float64(-273.0): {'Fx': {np.float64(-71.0): 'obstruction',
#                                     np.float64(41.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-19.0): {'Ty': {np.float64(33.0): {'Tz': {np.float64(-9.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-270.0): {'Fx': {np.float64(-16.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(-97.0): {'Ty': {np.float64(-3.0): {'Tz': {np.float64(-26.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-264.0): 'obstruction',
#         np.float64(-261.0): {'Fx': {np.float64(54.0): {'Fy': {np.float64(-22.0): {'Tx': {np.float64(-16.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(-6.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-257.0): 'obstruction',
#         np.float64(-256.0): {'Fx': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(45.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(-8.0): {'Ty': {np.float64(-55.0): {'Tz': {np.float64(0.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-254.0): 'obstruction',
#         np.float64(-250.0): {'Fx': {np.float64(51.0): {'Fy': {np.float64(-19.0): {'Tx': {np.float64(-22.0): {'Ty': {np.float64(-21.0): {'Tz': {np.float64(-7.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-248.0): 'obstruction',
#         np.float64(-246.0): 'obstruction',
#         np.float64(-244.0): {'Fx': {np.float64(10.0): {'Fy': {np.float64(-75.0): {'Tx': {np.float64(108.0): {'Ty': {np.float64(-136.0): {'Tz': {np.float64(48.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-243.0): 'obstruction',
#         np.float64(-242.0): 'obstruction',
#         np.float64(-240.0): {'Fx': {np.float64(15.0): {'Fy': {np.float64(2.0): {'Tx': {np.float64(36.0): {'Ty': {np.float64(38.0): {'Tz': {np.float64(0.0): 'collision'}}}}}}}}}},
#         np.float64(-239.0): 'obstruction',
#         np.float64(-235.0): 'fr_collision',
#         np.float64(-234.0): 'obstruction',
#         np.float64(-233.0): 'bottom_obstruction',
#         np.float64(-227.0): 'obstruction',
#         np.float64(-224.0): {'Fx': {np.float64(28.0): {'Fy': {np.float64(-42.0): {'Tx': {np.float64(-41.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(8.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-222.0): 'bottom_collision',
#         np.float64(-218.0): 'obstruction',
#         np.float64(-217.0): 'obstruction',
#         np.float64(-216.0): {'Fx': {np.float64(-15.0): 'fr_collision',
#                                     np.float64(-8.0): 'obstruction',
#                                     np.float64(33.0): {'Fy': {np.float64(-37.0): {'Tx': {np.float64(-33.0): {'Ty': {np.float64(-46.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(37.0): {'Fy': {np.float64(-33.0): {'Tx': {np.float64(-64.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-215.0): 'obstruction',
#         np.float64(-214.0): 'obstruction',
#         np.float64(-213.0): 'obstruction',
#         np.float64(-210.0): {'Fx': {np.float64(-28.0): {'Fy': {np.float64(-20.0): {'Tx': {np.float64(37.0): {'Ty': {np.float64(-59.0): {'Tz': {np.float64(-1.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(-8.0): 'obstruction',
#                                     np.float64(3.0): {'Fy': {np.float64(-14.0): {'Tx': {np.float64(26.0): {'Ty': {np.float64(11.0): {'Tz': {np.float64(-68.0): 'collision'}}}}}}}}}},
#         np.float64(-209.0): {'Fx': {np.float64(38.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(-56.0): {'Tz': {np.float64(-10.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-208.0): {'Fx': {np.float64(-29.0): 'obstruction',
#                                     np.float64(36.0): {'Fy': {np.float64(-39.0): {'Tx': {np.float64(-32.0): {'Ty': {np.float64(-72.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-207.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(7.0): {'Ty': {np.float64(37.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-205.0): 'obstruction',
#         np.float64(-203.0): 'bottom_collision',
#         np.float64(-201.0): {'Fx': {np.float64(-9.0): {'Fy': {np.float64(0.0): {'Tx': {np.float64(-70.0): {'Ty': {np.float64(-6.0): {'Tz': {np.float64(-25.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(35.0): 'bottom_collision'}},
#         np.float64(-199.0): 'obstruction',
#         np.float64(-197.0): 'obstruction',
#         np.float64(-196.0): {'Fx': {np.float64(31.0): {'Fy': {np.float64(-38.0): {'Tx': {np.float64(-28.0): {'Ty': {np.float64(-71.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-195.0): {'Fx': {np.float64(-29.0): 'bottom_collision',
#                                     np.float64(-12.0): 'fr_collision',
#                                     np.float64(36.0): 'collision'}},
#         np.float64(-193.0): {'Fx': {np.float64(-39.0): 'bottom_collision',
#                                     np.float64(-33.0): 'collision',
#                                     np.float64(13.0): 'collision'}},
#         np.float64(-192.0): 'obstruction',
#         np.float64(-191.0): {'Fx': {np.float64(9.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(18.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-189.0): 'obstruction',
#         np.float64(-185.0): {'Fx': {np.float64(-21.0): 'obstruction',
#                                     np.float64(3.0): 'bottom_collision'}},
#         np.float64(-182.0): {'Fx': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(13.0): 'bottom_collision'}},
#         np.float64(-181.0): 'fr_collision',
#         np.float64(-180.0): {'Fx': {np.float64(8.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-14.0): {'Ty': {np.float64(21.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-179.0): {'Tx': {np.float64(-44.0): {'Fx': {np.float64(14.0): {'Fy': {np.float64(-7.0): {'Ty': {np.float64(71.0): {'Tz': {np.float64(-18.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-13.0): {'Fx': {np.float64(8.0): {'Fy': {np.float64(-10.0): {'Ty': {np.float64(21.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-11.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-10.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(4.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-178.0): {'Fy': {np.float64(-19.0): {'Fx': {np.float64(29.0): {'Tx': {np.float64(-71.0): {'Ty': {np.float64(-70.0): {'Tz': {np.float64(-8.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-16.0): 'bottom_collision',
#                                     np.float64(-11.0): 'bottom_collision',
#                                     np.float64(13.0): {'Fx': {np.float64(8.0): {'Tx': {np.float64(-17.0): {'Ty': {np.float64(10.0): {'Tz': {np.float64(2.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-177.0): {'Fx': {np.float64(19.0): 'obstruction',
#                                     np.float64(29.0): 'collision'}},
#         np.float64(-176.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-13.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(1.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-172.0): 'collision',
#         np.float64(-171.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(6.0): {'Ty': {np.float64(9.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-170.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-10.0): {'Tx': {np.float64(-13.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(6.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(16.0): {'Fy': {np.float64(-39.0): {'Tx': {np.float64(-20.0): {'Ty': {np.float64(-116.0): {'Tz': {np.float64(17.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-169.0): {'Fx': {np.float64(-7.0): 'obstruction',
#                                     np.float64(1.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(-7.0): {'Ty': {np.float64(-21.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(7.0): {'Fy': {np.float64(-9.0): {'Tx': {np.float64(-12.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(4.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(24.0): {'Fy': {np.float64(-34.0): {'Tx': {np.float64(-38.0): {'Ty': {np.float64(-93.0): {'Tz': {np.float64(10.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-165.0): {'Ty': {np.float64(-101.0): {'Fx': {np.float64(17.0): {'Fy': {np.float64(-32.0): {'Tx': {np.float64(-32.0): {'Tz': {np.float64(15.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(18.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(-9.0): {'Tx': {np.float64(-13.0): {'Tz': {np.float64(4.0): 'collision'}}}}}}}},
#                                     np.float64(23.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(9.0): {'Tz': {np.float64(-5.0): 'collision'}}}}}}}},
#                                     np.float64(24.0): 'collision_in_part'}},
#         np.float64(-164.0): {'Fx': {np.float64(5.0): 'collision_in_part',
#                                     np.float64(24.0): {'Fy': {np.float64(-36.0): {'Tx': {np.float64(-36.0): {'Ty': {np.float64(-96.0): {'Tz': {np.float64(12.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-163.0): {'Fx': {np.float64(-17.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(-115.0): {'Ty': {np.float64(33.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-10.0): {'Fy': {np.float64(18.0): {'Tx': {np.float64(108.0): {'Ty': {np.float64(22.0): {'Tz': {np.float64(-11.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(70.0): 'obstruction'}},
#         np.float64(-160.0): 'bottom_obstruction',
#         np.float64(-159.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(1.0): {'Tx': {np.float64(9.0): {'Ty': {np.float64(4.0): {'Tz': {np.float64(2.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-157.0): 'obstruction',
#         np.float64(-156.0): {'Fx': {np.float64(23.0): {'Fy': {np.float64(-29.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(-91.0): {'Tz': {np.float64(11.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-155.0): {'Fx': {np.float64(-29.0): 'bottom_collision',
#                                     np.float64(-12.0): 'fr_collision'}},
#         np.float64(-152.0): 'obstruction',
#         np.float64(-150.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(10.0): {'Ty': {np.float64(15.0): {'Tz': {np.float64(-6.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(8.0): 'obstruction'}},
#         np.float64(-149.0): 'obstruction',
#         np.float64(-146.0): 'obstruction',
#         np.float64(-144.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-14.0): {'Tx': {np.float64(17.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(-3.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-142.0): {'Fx': {np.float64(-29.0): {'Fy': {np.float64(5.0): {'Tx': {np.float64(77.0): {'Ty': {np.float64(115.0): {'Tz': {np.float64(-20.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-11.0): 'fr_collision'}},
#         np.float64(-141.0): 'bottom_collision',
#         np.float64(-140.0): {'Fx': {np.float64(5.0): {'Fy': {np.float64(-19.0): {'Tx': {np.float64(27.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}},
#                                                              np.float64(-18.0): {'Tx': {np.float64(27.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-139.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Ty': {np.float64(15.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(17.0): 'fr_collision',
#                                     np.float64(20.0): 'obstruction'}},
#         np.float64(-138.0): {'Ty': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(15.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}},
#                                                               np.float64(5.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(16.0): 'bottom_collision',
#                                     np.float64(23.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-16.0): {'Tx': {np.float64(29.0): {'Tz': {np.float64(-3.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-136.0): {'Tx': {np.float64(-145.0): 'fr_collision',
#                                     np.float64(15.0): 'collision',
#                                     np.float64(17.0): 'bottom_collision'}},
#         np.float64(-135.0): {'Fx': {np.float64(-4.0): 'collision',
#                                     np.float64(5.0): {'Fy': {np.float64(-11.0): {'Tx': {np.float64(16.0): {'Ty': {np.float64(10.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(60.0): 'obstruction'}},
#         np.float64(-134.0): {'Fx': {np.float64(-5.0): {'Fy': {np.float64(-6.0): {'Tx': {np.float64(-54.0): {'Ty': {np.float64(-10.0): {'Tz': {np.float64(-23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-133.0): {'Fx': {np.float64(-12.0): 'fr_collision',
#                                     np.float64(-2.0): {'Fy': {np.float64(-6.0): {'Tx': {np.float64(-40.0): {'Ty': {np.float64(-8.0): {'Tz': {np.float64(-18.0): 'collision'}}}}}}}},
#                                     np.float64(6.0): {'Fy': {np.float64(-16.0): {'Tx': {np.float64(32.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(0.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-131.0): 'bottom_collision',
#         np.float64(-128.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(29.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(-2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-127.0): 'obstruction',
#         np.float64(-125.0): {'Fx': {np.float64(-23.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(89.0): {'Ty': {np.float64(106.0): {'Tz': {np.float64(-21.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(12.0): {'Fy': {np.float64(18.0): {'Tx': {np.float64(37.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(9.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(17.0): {'Fy': {np.float64(11.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-124.0): 'obstruction',
#         np.float64(-122.0): {'Fx': {np.float64(-11.0): {'Fy': {np.float64(-26.0): {'Tx': {np.float64(68.0): {'Ty': {np.float64(147.0): {'Tz': {np.float64(-13.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(36.0): {'Fy': {np.float64(2.0): {'Tx': {np.float64(10.0): {'Ty': {np.float64(12.0): {'Tz': {np.float64(5.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-120.0): 'obstruction',
#         np.float64(-119.0): 'obstruction',
#         np.float64(-118.0): 'obstruction',
#         np.float64(-117.0): 'obstruction',
#         np.float64(-116.0): 'obstruction',
#         np.float64(-115.0): 'obstruction',
#         np.float64(-114.0): 'fr_collision',
#         np.float64(-113.0): {'Fx': {np.float64(3.0): 'obstruction',
#                                     np.float64(16.0): 'fr_collision',
#                                     np.float64(18.0): 'obstruction'}},
#         np.float64(-112.0): {'Fx': {np.float64(-1.0): 'obstruction',
#                                     np.float64(1.0): 'obstruction',
#                                     np.float64(6.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(15.0): {'Ty': {np.float64(-3.0): {'Tz': {np.float64(15.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(15.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(-48.0): {'Ty': {np.float64(46.0): {'Tz': {np.float64(-2.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(18.0): 'collision'}},
#         np.float64(-111.0): 'obstruction',
#         np.float64(-110.0): 'obstruction',
#         np.float64(-109.0): 'collision',
#         np.float64(-108.0): {'Fx': {np.float64(4.0): 'obstruction',
#                                     np.float64(23.0): {'Fy': {np.float64(29.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(41.0): {'Tz': {np.float64(11.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(33.0): {'Fy': {np.float64(0.0): {'Tx': {np.float64(21.0): {'Ty': {np.float64(7.0): {'Tz': {np.float64(8.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-107.0): 'obstruction',
#         np.float64(-106.0): 'bottom_collision',
#         np.float64(-104.0): 'obstruction',
#         np.float64(-103.0): 'obstruction',
#         np.float64(-101.0): {'Fx': {np.float64(-41.0): 'fr_collision',
#                                     np.float64(5.0): 'obstruction'}},
#         np.float64(-100.0): 'obstruction',
#         np.float64(-99.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(7.0): {'Ty': {np.float64(12.0): {'Tz': {np.float64(-1.0): 'collision'}}}}}}}},
#                                    np.float64(14.0): 'fr_collision'}},
#         np.float64(-98.0): 'obstruction',
#         np.float64(-97.0): 'obstruction',
#         np.float64(-95.0): 'obstruction',
#         np.float64(-94.0): {'Fx': {np.float64(10.0): 'obstruction',
#                                    np.float64(16.0): 'fr_collision'}},
#         np.float64(-93.0): {'Fx': {np.float64(3.0): 'obstruction',
#                                    np.float64(25.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-7.0): {'Tz': {np.float64(0.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-91.0): {'Fx': {np.float64(4.0): 'obstruction',
#                                    np.float64(10.0): 'obstruction',
#                                    np.float64(17.0): 'fr_collision',
#                                    np.float64(37.0): {'Fy': {np.float64(22.0): {'Tx': {np.float64(-74.0): {'Ty': {np.float64(82.0): {'Tz': {np.float64(-8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-90.0): {'Fx': {np.float64(-24.0): 'fr_collision',
#                                    np.float64(4.0): 'obstruction',
#                                    np.float64(7.0): 'obstruction',
#                                    np.float64(10.0): 'obstruction'}},
#         np.float64(-89.0): 'obstruction',
#         np.float64(-88.0): 'fr_collision',
#         np.float64(-87.0): {'Fx': {np.float64(8.0): 'obstruction',
#                                    np.float64(15.0): {'Fy': {np.float64(11.0): {'Tx': {np.float64(43.0): {'Ty': {np.float64(28.0): {'Tz': {np.float64(11.0): 'bottom_obstruction'}}}}}}}},
#                                    np.float64(24.0): 'collision'}},
#         np.float64(-85.0): {'Fx': {np.float64(2.0): 'bottom_collision',
#                                    np.float64(19.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-9.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-84.0): 'obstruction',
#         np.float64(-83.0): {'Fx': {np.float64(-35.0): 'fr_collision',
#                                    np.float64(16.0): 'fr_collision',
#                                    np.float64(45.0): 'obstruction'}},
#         np.float64(-81.0): 'collision',
#         np.float64(-78.0): 'obstruction',
#         np.float64(-77.0): 'obstruction',
#         np.float64(-76.0): {'Fx': {np.float64(-33.0): 'fr_collision',
#                                    np.float64(13.0): 'obstruction'}},
#         np.float64(-75.0): {'Fx': {np.float64(23.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-13.0): {'Tz': {np.float64(-1.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-74.0): {'Fx': {np.float64(-14.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(-41.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-73.0): {'Fx': {np.float64(-2.0): {'Fy': {np.float64(-11.0): {'Tx': {np.float64(-4.0): {'Ty': {np.float64(54.0): {'Tz': {np.float64(-9.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-72.0): {'Fx': {np.float64(-5.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(25.0): {'Ty': {np.float64(-20.0): {'Tz': {np.float64(-5.0): 'bottom_obstruction'}}}}}}}},
# ...
# Predicted: nan, Actual: collision_in_part
# Predicted: obstruction, Actual: obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: left_col, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: back_col
# Predicted: nan, Actual: obstruction
# Predicted: collision_in_tool, Actual: collision
# Predicted: nan, Actual: bottom_collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: back_col, Actual: left_col
# Predicted: nan, Actual: fr_collision
# Predicted: collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: bottom_collision
# Predicted: nan, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: nan, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: obstruction, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: normal
# Predicted: back_col, Actual: front_col
# Predicted: back_col, Actual: normal
# Predicted: back_col, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: bottom_obstruction
# Predicted: fr_collision, Actual: collision
# Predicted: nan, Actual: fr_collision
# Predicted: normal, Actual: back_col
# Predicted: back_col, Actual: left_col
# Predicted: nan, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: left_col, Actual: collision_in_part
# Predicted: bottom_collision, Actual: collision
# Predicted: nan, Actual: collision_in_part
# Predicted: obstruction, Actual: obstruction
# Predicted: nan, Actual: bottom_obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_tool
# Predicted: nan, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: nan, Actual: bottom_collision
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: front_col
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: collision
# Predicted: back_col, Actual: right_col
# Predicted: back_col, Actual: left_col
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: collision_in_part
# Predicted: back_col, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: bottom_collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: fr_collision
# Predicted: nan, Actual: collision
# Predicted: nan, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: nan, Actual: obstruction
# Predicted: collision_in_part, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: back_col
# Predicted: nan, Actual: collision
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: collision
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: normal
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: collision
# Predicted: bottom_collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: nan, Actual: fr_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: obstruction
# Predicted: nan, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: back_col, Actual: front_col
# Predicted: collision_in_tool, Actual: collision
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: bottom_collision
# Predicted: nan, Actual: collision_in_part
# Predicted: collision_in_part, Actual: front_col
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: nan, Actual: collision_in_part
# Predicted: nan, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: back_col
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: collision
# Predicted: nan, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: nan, Actual: obstruction
# Predicted: obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_part
# Predicted: collision_in_part, Actual: back_col
# Predicted: nan, Actual: obstruction
# Predicted: nan, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision_in_tool, Actual: right_col
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_tool
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_tool
# Predicted: back_col, Actual: collision_in_tool
# Predicted: back_col, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: back_col
# Predicted: collision_in_part, Actual: back_col
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision
# Predicted: nan, Actual: right_col
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: bottom_collision
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: collision
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: left_col
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: nan, Actual: obstruction
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: collision_in_tool
# Predicted: nan, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: collision
# Predicted: normal, Actual: fr_collision
# Predicted: fr_collision, Actual: collision
# Predicted: nan, Actual: collision
# Predicted: nan, Actual: fr_collision
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_part
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: bottom_obstruction
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: nan, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_tool, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: bottom_obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: back_col
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: back_col
# Predicted: fr_collision, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: back_col
# Predicted: nan, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: nan, Actual: normal
# Predicted: normal, Actual: collision
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: nan, Actual: bottom_collision
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: nan, Actual: collision_in_tool
# Predicted: nan, Actual: fr_collision
# Predicted: nan, Actual: fr_collision
# Predicted: collision, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: nan, Actual: normal
# Predicted: nan, Actual: obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: bottom_collision
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: back_col
# Predicted: nan, Actual: collision
# Predicted: nan, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: back_col
# Predicted: collision_in_tool, Actual: collision
# Predicted: fr_collision, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: front_col
# Predicted: collision_in_part, Actual: collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: nan, Actual: obstruction
# Predicted: front_col, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_tool, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: left_col, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: bottom_obstruction
# Predicted: nan, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: fr_collision
# Predicted: back_col, Actual: front_col
# Predicted: nan, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: nan, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: obstruction
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_part, Actual: back_col
# Predicted: nan, Actual: obstruction
# Predicted: normal, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: bottom_collision
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: nan, Actual: obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: left_col, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: back_col
# Predicted: nan, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: nan, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: nan, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: nan, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: obstruction
#
# Accuracy: 21.67%

# %% [markdown]
# # Classification Tree Robot Data Set

# %%
# Load and clean the dataset
data = pd.concat([pd.read_csv('LP1.csv'), pd.read_csv('LP2.csv'), pd.read_csv('LP3.csv'), pd.read_csv('LP4.csv'), pd.read_csv('LP5.csv')], ignore_index=True)

# Drop 'ok' column if it exists
if 'ok' in data.columns:
    data = data.drop(columns=['ok'])

# Forward-fill missing values in the 'Target' column and fill remaining NaNs with 'normal'
data['normal'] = data['normal'].ffill().fillna('normal')
data.columns = ['Target', 'Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'] + list(data.columns[7:])
data.dropna(subset=['Fx', 'Fy', 'Fz', 'Tx', 'Ty', 'Tz'], inplace=True)
data = data[[col for col in data.columns if col != 'Target'] + ['Target']]

# Split data into training and testing sets
def split_data(data, test_size):
    data = data.sample(frac=1, random_state=42)  # Shuffle with fixed seed
    train_data = data.iloc[:int(len(data) * (1 - test_size))]
    test_data = data.iloc[int(len(data) * test_size):]
    return train_data, test_data

train_data, test_data = split_data(data, 0.2)

# Calculate entropy
def entropy(data, target_col):
    values, counts = np.unique(data[target_col], return_counts=True)
    entropy = -sum((counts[i] / np.sum(counts)) * np.log2(counts[i] / np.sum(counts)) for i in range(len(values)))
    return entropy

# Calculate information gain
def info_gain(data, split_attribute, target_col):
    total_entropy = entropy(data, target_col)
    values, counts = np.unique(data[split_attribute], return_counts=True)
    weighted_entropy = sum((counts[i] / np.sum(counts)) * entropy(data[data[split_attribute] == values[i]], target_col)
                           for i in range(len(values)))
    return total_entropy - weighted_entropy

# ID3 algorithm to build the classification tree
def id3(data, original_data, features, target_col, parent_node=None):
    unique_targets = np.unique(data[target_col])
    
    # If all targets are the same, return this value
    if len(unique_targets) == 1:
        return unique_targets[0]

    # If the dataset is empty, return the mode target in the original dataset
    elif len(data) == 0:
        return np.unique(original_data[target_col])[np.argmax(np.unique(original_data[target_col], return_counts=True)[1])]

    # If there are no more features to split on, return the parent node
    elif len(features) == 0:
        return parent_node

    # Otherwise, select the best feature to split on
    else:
        # Set the default value for the parent node (majority class)
        parent_node = np.unique(data[target_col])[np.argmax(np.unique(data[target_col], return_counts=True)[1])]
        
        # Select the feature which best splits the dataset
        item_gains = [info_gain(data, feature, target_col) for feature in features]
        best_feature_index = np.argmax(item_gains)
        best_feature = features[best_feature_index]
        
        # Create the tree structure
        tree = {best_feature: {}}
        
        # Remove the best feature from the list of features
        features = [f for f in features if f != best_feature]
        
        # Grow a branch under each value of the best feature
        for value in np.unique(data[best_feature]):
            sub_data = data.where(data[best_feature] == value).dropna()
            subtree = id3(sub_data, original_data, features, target_col, parent_node)
            tree[best_feature][value] = subtree
        
        return tree

# Build the tree using the ID3 algorithm
features = train_data.columns[:-1]  # All columns except the target
target_col = 'Target'
tree = id3(train_data, train_data, features, target_col)
print("\nID3 Classification Tree:")
pprint(tree)

# Prediction function to classify new data based on the tree
def predict(tree, instance):
    if not isinstance(tree, dict):
        return tree
    feature = next(iter(tree))
    value = instance[feature]
    if value in tree[feature]:
        return predict(tree[feature][value], instance)
    else:
        return None  # Handle unseen feature values gracefully

# Evaluate the model on the test data
def evaluate(tree, test_data, target_col):
    predictions = test_data.apply(lambda x: predict(tree, x), axis=1)
    actual_values = test_data[target_col]
    accuracy = (predictions == actual_values).mean() * 100
    print("\nPredicted vs Actual:")
    for pred, actual in zip(predictions, actual_values):
        print(f"Predicted: {pred}, Actual: {actual}")
    print(f"\nAccuracy: {accuracy:.2f}%")
    return accuracy

# Test and evaluate the tree
accuracy = evaluate(tree, test_data, target_col)
print(f"\nTest Accuracy: {accuracy:.2f}%")
# Out:
# ID3 Classification Tree:
# {'Fz': {np.float64(-3617.0): {'Fx': {np.float64(353.0): {'Fy': {np.float64(-169.0): {'Tx': {np.float64(324.0): {'Ty': {np.float64(-265.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3557.0): 'bottom_obstruction',
#         np.float64(-3451.0): {'Fx': {np.float64(-883.0): {'Fy': {np.float64(-260.0): {'Tx': {np.float64(-175.0): {'Ty': {np.float64(-434.0): {'Tz': {np.float64(21.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3348.0): {'Fx': {np.float64(351.0): {'Fy': {np.float64(-368.0): {'Tx': {np.float64(282.0): {'Ty': {np.float64(-62.0): {'Tz': {np.float64(-31.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3292.0): {'Fx': {np.float64(337.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(290.0): {'Ty': {np.float64(-78.0): {'Tz': {np.float64(-34.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3281.0): 'obstruction',
#         np.float64(-3277.0): {'Fx': {np.float64(460.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(307.0): {'Ty': {np.float64(-169.0): {'Tz': {np.float64(23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3275.0): {'Fx': {np.float64(462.0): {'Fy': {np.float64(-59.0): {'Tx': {np.float64(285.0): {'Ty': {np.float64(-183.0): {'Tz': {np.float64(17.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3261.0): {'Fx': {np.float64(337.0): {'Fy': {np.float64(-170.0): {'Tx': {np.float64(300.0): {'Ty': {np.float64(-243.0): {'Tz': {np.float64(54.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3235.0): {'Fx': {np.float64(142.0): {'Fy': {np.float64(438.0): {'Tx': {np.float64(536.0): {'Ty': {np.float64(-250.0): {'Tz': {np.float64(201.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3234.0): {'Fx': {np.float64(448.0): {'Fy': {np.float64(-73.0): {'Tx': {np.float64(313.0): {'Ty': {np.float64(-169.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3226.0): {'Fx': {np.float64(460.0): {'Fy': {np.float64(-41.0): {'Tx': {np.float64(250.0): {'Ty': {np.float64(-205.0): {'Tz': {np.float64(23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3224.0): {'Fx': {np.float64(328.0): {'Fy': {np.float64(-360.0): {'Tx': {np.float64(291.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(-30.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3195.0): {'Fx': {np.float64(322.0): {'Fy': {np.float64(-338.0): {'Tx': {np.float64(280.0): {'Ty': {np.float64(-64.0): {'Tz': {np.float64(-34.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3161.0): 'obstruction',
#         np.float64(-3089.0): {'Fx': {np.float64(119.0): {'Fy': {np.float64(354.0): {'Tx': {np.float64(567.0): {'Ty': {np.float64(-232.0): {'Tz': {np.float64(161.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3051.0): 'bottom_obstruction',
#         np.float64(-3028.0): {'Fx': {np.float64(-473.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(77.0): {'Ty': {np.float64(211.0): {'Tz': {np.float64(-167.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-3018.0): {'Fx': {np.float64(-492.0): {'Fy': {np.float64(-364.0): {'Tx': {np.float64(185.0): {'Ty': {np.float64(72.0): {'Tz': {np.float64(-199.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2992.0): {'Fx': {np.float64(-480.0): {'Fy': {np.float64(-319.0): {'Tx': {np.float64(-132.0): {'Ty': {np.float64(170.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2973.0): {'Fx': {np.float64(-851.0): {'Fy': {np.float64(-235.0): {'Tx': {np.float64(-102.0): {'Ty': {np.float64(-506.0): {'Tz': {np.float64(8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2966.0): 'obstruction',
#         np.float64(-2958.0): 'obstruction',
#         np.float64(-2955.0): {'Fx': {np.float64(-497.0): {'Fy': {np.float64(-297.0): {'Tx': {np.float64(-199.0): {'Ty': {np.float64(169.0): {'Tz': {np.float64(20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2950.0): {'Fx': {np.float64(317.0): {'Fy': {np.float64(242.0): {'Tx': {np.float64(231.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(16.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2943.0): 'obstruction',
#         np.float64(-2929.0): {'Fx': {np.float64(213.0): {'Fy': {np.float64(-189.0): {'Tx': {np.float64(133.0): {'Ty': {np.float64(-35.0): {'Tz': {np.float64(-22.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2804.0): 'bottom_obstruction',
#         np.float64(-2795.0): 'obstruction',
#         np.float64(-2792.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-184.0): {'Tx': {np.float64(113.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-12.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2788.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-184.0): {'Tx': {np.float64(113.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2785.0): {'Fx': {np.float64(210.0): {'Fy': {np.float64(-183.0): {'Tx': {np.float64(112.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'obstruction'}}}}}}}}}},
#         np.float64(-2781.0): {'Fx': {np.float64(97.0): {'Fy': {np.float64(276.0): {'Tx': {np.float64(620.0): {'Ty': {np.float64(-238.0): {'Tz': {np.float64(144.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(210.0): {'Fy': {np.float64(-183.0): {'Tx': {np.float64(112.0): {'Ty': {np.float64(-29.0): {'Tz': {np.float64(-11.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2761.0): {'Fx': {np.float64(-424.0): {'Fy': {np.float64(-328.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(52.0): {'Tz': {np.float64(-21.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2757.0): {'Fx': {np.float64(-389.0): {'Fy': {np.float64(91.0): {'Tx': {np.float64(-107.0): {'Ty': {np.float64(114.0): {'Tz': {np.float64(-55.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2718.0): 'bottom_obstruction',
#         np.float64(-2693.0): {'Fx': {np.float64(-138.0): {'Fy': {np.float64(-331.0): {'Tx': {np.float64(-142.0): {'Ty': {np.float64(194.0): {'Tz': {np.float64(8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2690.0): 'bottom_obstruction',
#         np.float64(-2680.0): {'Fx': {np.float64(-139.0): {'Fy': {np.float64(-328.0): {'Tx': {np.float64(-147.0): {'Ty': {np.float64(223.0): {'Tz': {np.float64(6.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(-136.0): {'Fy': {np.float64(-326.0): {'Tx': {np.float64(-156.0): {'Ty': {np.float64(208.0): {'Tz': {np.float64(4.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2672.0): {'Fx': {np.float64(-134.0): {'Fy': {np.float64(-325.0): {'Tx': {np.float64(-158.0): {'Ty': {np.float64(207.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2652.0): 'bottom_obstruction',
#         np.float64(-2619.0): 'obstruction',
#         np.float64(-2616.0): {'Fx': {np.float64(-125.0): {'Fy': {np.float64(-311.0): {'Tx': {np.float64(-189.0): {'Ty': {np.float64(227.0): {'Tz': {np.float64(3.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(-123.0): 'obstruction'}},
#         np.float64(-2589.0): 'obstruction',
#         np.float64(-2542.0): {'Fx': {np.float64(-262.0): {'Fy': {np.float64(98.0): {'Tx': {np.float64(-131.0): {'Ty': {np.float64(305.0): {'Tz': {np.float64(-13.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(166.0): {'Fy': {np.float64(-155.0): {'Tx': {np.float64(143.0): {'Ty': {np.float64(-32.0): {'Tz': {np.float64(-35.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2460.0): 'obstruction',
#         np.float64(-2387.0): {'Fx': {np.float64(105.0): {'Fy': {np.float64(197.0): {'Tx': {np.float64(605.0): {'Ty': {np.float64(-171.0): {'Tz': {np.float64(135.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2325.0): {'Fx': {np.float64(206.0): {'Fy': {np.float64(-344.0): {'Tx': {np.float64(-287.0): {'Ty': {np.float64(-499.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2323.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-345.0): {'Tx': {np.float64(-287.0): {'Ty': {np.float64(-501.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2319.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-344.0): {'Tx': {np.float64(-284.0): {'Ty': {np.float64(-498.0): {'Tz': {np.float64(52.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2316.0): 'obstruction',
#         np.float64(-2315.0): {'Fx': {np.float64(205.0): {'Fy': {np.float64(-343.0): {'Tx': {np.float64(-284.0): {'Ty': {np.float64(-499.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2306.0): {'Fx': {np.float64(260.0): {'Fy': {np.float64(107.0): {'Tx': {np.float64(377.0): {'Ty': {np.float64(40.0): {'Tz': {np.float64(45.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2305.0): {'Fx': {np.float64(211.0): {'Fy': {np.float64(-165.0): {'Tx': {np.float64(-43.0): {'Ty': {np.float64(-567.0): {'Tz': {np.float64(30.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2303.0): {'Fx': {np.float64(305.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(225.0): {'Ty': {np.float64(-125.0): {'Tz': {np.float64(88.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2233.0): {'Fx': {np.float64(-240.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(-153.0): {'Ty': {np.float64(274.0): {'Tz': {np.float64(-248.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2203.0): 'obstruction',
#         np.float64(-2176.0): {'Fx': {np.float64(-49.0): {'Fy': {np.float64(-98.0): {'Tx': {np.float64(282.0): {'Ty': {np.float64(-126.0): {'Tz': {np.float64(-128.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2135.0): {'Fx': {np.float64(-168.0): {'Fy': {np.float64(107.0): {'Tx': {np.float64(-172.0): {'Ty': {np.float64(406.0): {'Tz': {np.float64(32.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2112.0): {'Fx': {np.float64(87.0): {'Fy': {np.float64(-117.0): {'Tx': {np.float64(154.0): {'Ty': {np.float64(81.0): {'Tz': {np.float64(-150.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-2088.0): {'Fx': {np.float64(217.0): {'Fy': {np.float64(-155.0): {'Tx': {np.float64(-100.0): {'Ty': {np.float64(-568.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2043.0): {'Fx': {np.float64(241.0): {'Fy': {np.float64(-175.0): {'Tx': {np.float64(-110.0): {'Ty': {np.float64(-576.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-2021.0): {'Fx': {np.float64(-377.0): {'Fy': {np.float64(-198.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(167.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1995.0): 'bottom_obstruction',
#         np.float64(-1744.0): {'Fx': {np.float64(112.0): {'Fy': {np.float64(115.0): {'Tx': {np.float64(476.0): {'Ty': {np.float64(-13.0): {'Tz': {np.float64(149.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1738.0): {'Fx': {np.float64(204.0): {'Fy': {np.float64(-154.0): {'Tx': {np.float64(-76.0): {'Ty': {np.float64(-498.0): {'Tz': {np.float64(35.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1654.0): 'obstruction',
#         np.float64(-1627.0): {'Fx': {np.float64(-64.0): {'Fy': {np.float64(84.0): {'Tx': {np.float64(-127.0): {'Ty': {np.float64(464.0): {'Tz': {np.float64(51.0): 'bottom_obstruction'}}}}}}}},
#                                      np.float64(205.0): {'Fy': {np.float64(-147.0): {'Tx': {np.float64(-68.0): {'Ty': {np.float64(-487.0): {'Tz': {np.float64(19.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1622.0): 'bottom_obstruction',
#         np.float64(-1619.0): {'Fx': {np.float64(227.0): {'Fy': {np.float64(-141.0): {'Tx': {np.float64(-130.0): {'Ty': {np.float64(-492.0): {'Tz': {np.float64(18.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1615.0): {'Fx': {np.float64(-261.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(106.0): {'Ty': {np.float64(58.0): {'Tz': {np.float64(-36.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1582.0): {'Fx': {np.float64(-253.0): {'Fy': {np.float64(-69.0): {'Tx': {np.float64(136.0): {'Ty': {np.float64(48.0): {'Tz': {np.float64(-27.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1547.0): 'obstruction',
#         np.float64(-1491.0): 'obstruction',
#         np.float64(-1437.0): 'obstruction',
#         np.float64(-1436.0): 'obstruction',
#         np.float64(-1428.0): 'obstruction',
#         np.float64(-1421.0): 'bottom_obstruction',
#         np.float64(-1415.0): {'Fx': {np.float64(-3.0): {'Fy': {np.float64(-95.0): {'Tx': {np.float64(-68.0): {'Ty': {np.float64(207.0): {'Tz': {np.float64(-29.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1409.0): 'obstruction',
#         np.float64(-1407.0): 'obstruction',
#         np.float64(-1387.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(229.0): {'Ty': {np.float64(402.0): {'Tz': {np.float64(-43.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-1384.0): {'Fx': {np.float64(36.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-101.0): {'Ty': {np.float64(-161.0): {'Tz': {np.float64(-59.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1371.0): 'obstruction',
#         np.float64(-1368.0): 'obstruction',
#         np.float64(-1360.0): 'obstruction',
#         np.float64(-1358.0): {'Fx': {np.float64(-254.0): {'Fy': {np.float64(-76.0): {'Tx': {np.float64(170.0): {'Ty': {np.float64(-44.0): {'Tz': {np.float64(-20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1357.0): 'obstruction',
#         np.float64(-1344.0): 'obstruction',
#         np.float64(-1340.0): 'obstruction',
#         np.float64(-1337.0): {'Fx': {np.float64(-43.0): {'Fy': {np.float64(-52.0): {'Tx': {np.float64(237.0): {'Ty': {np.float64(-95.0): {'Tz': {np.float64(-88.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1334.0): 'obstruction',
#         np.float64(-1326.0): 'obstruction',
#         np.float64(-1302.0): 'obstruction',
#         np.float64(-1299.0): 'obstruction',
#         np.float64(-1287.0): 'obstruction',
#         np.float64(-1286.0): 'obstruction',
#         np.float64(-1278.0): 'obstruction',
#         np.float64(-1274.0): 'obstruction',
#         np.float64(-1267.0): 'obstruction',
#         np.float64(-1266.0): 'obstruction',
#         np.float64(-1264.0): 'obstruction',
#         np.float64(-1262.0): 'obstruction',
#         np.float64(-1252.0): 'obstruction',
#         np.float64(-1251.0): 'obstruction',
#         np.float64(-1248.0): 'obstruction',
#         np.float64(-1242.0): 'obstruction',
#         np.float64(-1241.0): 'obstruction',
#         np.float64(-1238.0): 'obstruction',
#         np.float64(-1235.0): 'obstruction',
#         np.float64(-1230.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-166.0): {'Ty': {np.float64(-199.0): {'Tz': {np.float64(-91.0): 'obstruction'}}}}}}}}}},
#         np.float64(-1227.0): 'obstruction',
#         np.float64(-1221.0): {'Fx': {np.float64(-1.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-169.0): {'Ty': {np.float64(-216.0): {'Tz': {np.float64(-83.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1218.0): 'obstruction',
#         np.float64(-1175.0): 'collision',
#         np.float64(-1173.0): 'obstruction',
#         np.float64(-1168.0): 'obstruction',
#         np.float64(-1162.0): 'obstruction',
#         np.float64(-1130.0): 'obstruction',
#         np.float64(-1120.0): {'Fx': {np.float64(88.0): {'Fy': {np.float64(4.0): {'Tx': {np.float64(283.0): {'Ty': {np.float64(-89.0): {'Tz': {np.float64(47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-1108.0): 'obstruction',
#         np.float64(-1107.0): 'obstruction',
#         np.float64(-1104.0): 'obstruction',
#         np.float64(-1083.0): 'obstruction',
#         np.float64(-1082.0): 'obstruction',
#         np.float64(-1077.0): 'obstruction',
#         np.float64(-1074.0): 'obstruction',
#         np.float64(-1041.0): 'obstruction',
#         np.float64(-1036.0): 'obstruction',
#         np.float64(-1018.0): 'obstruction',
#         np.float64(-1008.0): 'obstruction',
#         np.float64(-996.0): {'Fx': {np.float64(-241.0): {'Fy': {np.float64(-72.0): {'Tx': {np.float64(174.0): {'Ty': {np.float64(-171.0): {'Tz': {np.float64(-20.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-991.0): 'obstruction',
#         np.float64(-987.0): 'obstruction',
#         np.float64(-969.0): {'Fx': {np.float64(129.0): {'Fy': {np.float64(49.0): {'Tx': {np.float64(155.0): {'Ty': {np.float64(103.0): {'Tz': {np.float64(38.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-968.0): 'obstruction',
#         np.float64(-966.0): 'obstruction',
#         np.float64(-957.0): 'obstruction',
#         np.float64(-931.0): {'Fx': {np.float64(-86.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(-94.0): {'Ty': {np.float64(100.0): {'Tz': {np.float64(-15.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-930.0): 'obstruction',
#         np.float64(-929.0): 'obstruction',
#         np.float64(-927.0): 'obstruction',
#         np.float64(-923.0): 'obstruction',
#         np.float64(-918.0): 'obstruction',
#         np.float64(-912.0): 'obstruction',
#         np.float64(-887.0): 'obstruction',
#         np.float64(-878.0): 'obstruction',
#         np.float64(-877.0): 'obstruction',
#         np.float64(-866.0): 'obstruction',
#         np.float64(-860.0): {'Fx': {np.float64(20.0): {'Fy': {np.float64(-65.0): {'Tx': {np.float64(143.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-844.0): {'Fx': {np.float64(-47.0): {'Fy': {np.float64(-59.0): {'Tx': {np.float64(747.0): {'Ty': {np.float64(85.0): {'Tz': {np.float64(244.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-843.0): 'obstruction',
#         np.float64(-826.0): 'obstruction',
#         np.float64(-812.0): 'obstruction',
#         np.float64(-807.0): 'obstruction',
#         np.float64(-800.0): 'obstruction',
#         np.float64(-786.0): 'obstruction',
#         np.float64(-783.0): 'obstruction',
#         np.float64(-780.0): 'obstruction',
#         np.float64(-779.0): 'obstruction',
#         np.float64(-771.0): {'Fx': {np.float64(-203.0): {'Fy': {np.float64(-57.0): {'Tx': {np.float64(138.0): {'Ty': {np.float64(-188.0): {'Tz': {np.float64(-9.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-768.0): 'obstruction',
#         np.float64(-738.0): 'obstruction',
#         np.float64(-735.0): 'obstruction',
#         np.float64(-728.0): 'obstruction',
#         np.float64(-727.0): 'obstruction',
#         np.float64(-723.0): 'obstruction',
#         np.float64(-702.0): 'obstruction',
#         np.float64(-701.0): 'collision',
#         np.float64(-685.0): 'obstruction',
#         np.float64(-683.0): 'obstruction',
#         np.float64(-669.0): 'obstruction',
#         np.float64(-667.0): 'obstruction',
#         np.float64(-657.0): 'obstruction',
#         np.float64(-655.0): {'Fx': {np.float64(87.0): {'Fy': {np.float64(-86.0): {'Tx': {np.float64(-9.0): {'Ty': {np.float64(-193.0): {'Tz': {np.float64(21.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-654.0): 'obstruction',
#         np.float64(-650.0): 'obstruction',
#         np.float64(-640.0): 'obstruction',
#         np.float64(-637.0): 'obstruction',
#         np.float64(-629.0): {'Fx': {np.float64(-1.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(156.0): {'Ty': {np.float64(247.0): {'Tz': {np.float64(-21.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-628.0): 'obstruction',
#         np.float64(-626.0): 'obstruction',
#         np.float64(-621.0): 'obstruction',
#         np.float64(-614.0): 'obstruction',
#         np.float64(-606.0): 'obstruction',
#         np.float64(-605.0): 'obstruction',
#         np.float64(-604.0): 'bottom_obstruction',
#         np.float64(-603.0): 'obstruction',
#         np.float64(-601.0): 'obstruction',
#         np.float64(-599.0): 'obstruction',
#         np.float64(-598.0): 'obstruction',
#         np.float64(-595.0): 'obstruction',
#         np.float64(-594.0): 'obstruction',
#         np.float64(-590.0): 'obstruction',
#         np.float64(-589.0): 'obstruction',
#         np.float64(-588.0): 'obstruction',
#         np.float64(-586.0): 'obstruction',
#         np.float64(-584.0): 'obstruction',
#         np.float64(-581.0): 'obstruction',
#         np.float64(-567.0): 'obstruction',
#         np.float64(-564.0): 'bottom_obstruction',
#         np.float64(-559.0): {'Fx': {np.float64(-45.0): {'Fy': {np.float64(-24.0): {'Tx': {np.float64(122.0): {'Ty': {np.float64(-98.0): {'Tz': {np.float64(-25.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-558.0): 'obstruction',
#         np.float64(-554.0): 'obstruction',
#         np.float64(-553.0): 'obstruction',
#         np.float64(-540.0): 'obstruction',
#         np.float64(-526.0): {'Fx': {np.float64(-33.0): {'Fy': {np.float64(-13.0): {'Tx': {np.float64(-114.0): {'Ty': {np.float64(39.0): {'Tz': {np.float64(-47.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-524.0): 'obstruction',
#         np.float64(-517.0): {'Fx': {np.float64(1.0): {'Fy': {np.float64(-26.0): {'Tx': {np.float64(95.0): {'Ty': {np.float64(40.0): {'Tz': {np.float64(-33.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-515.0): 'obstruction',
#         np.float64(-511.0): 'obstruction',
#         np.float64(-498.0): 'obstruction',
#         np.float64(-496.0): 'bottom_collision',
#         np.float64(-491.0): {'Fx': {np.float64(-198.0): {'Fy': {np.float64(68.0): {'Tx': {np.float64(-381.0): {'Ty': {np.float64(-459.0): {'Tz': {np.float64(38.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-488.0): 'obstruction',
#         np.float64(-487.0): 'obstruction',
#         np.float64(-486.0): 'obstruction',
#         np.float64(-481.0): 'obstruction',
#         np.float64(-477.0): 'obstruction',
#         np.float64(-476.0): 'obstruction',
#         np.float64(-472.0): 'obstruction',
#         np.float64(-469.0): {'Fx': {np.float64(86.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(-52.0): {'Ty': {np.float64(-92.0): {'Tz': {np.float64(0.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-462.0): 'obstruction',
#         np.float64(-461.0): 'obstruction',
#         np.float64(-457.0): 'obstruction',
#         np.float64(-456.0): 'obstruction',
#         np.float64(-454.0): 'obstruction',
#         np.float64(-451.0): 'obstruction',
#         np.float64(-445.0): {'Fx': {np.float64(-101.0): {'Fy': {np.float64(-47.0): {'Tx': {np.float64(80.0): {'Ty': {np.float64(-72.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-444.0): 'obstruction',
#         np.float64(-441.0): 'obstruction',
#         np.float64(-438.0): 'obstruction',
#         np.float64(-437.0): 'obstruction',
#         np.float64(-434.0): 'obstruction',
#         np.float64(-431.0): {'Fx': {np.float64(-21.0): {'Fy': {np.float64(-40.0): {'Tx': {np.float64(-90.0): {'Ty': {np.float64(96.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-2.0): 'obstruction'}},
#         np.float64(-429.0): 'obstruction',
#         np.float64(-426.0): 'obstruction',
#         np.float64(-424.0): 'obstruction',
#         np.float64(-421.0): 'obstruction',
#         np.float64(-417.0): {'Fx': {np.float64(-79.0): {'Fy': {np.float64(-43.0): {'Tx': {np.float64(79.0): {'Ty': {np.float64(-20.0): {'Tz': {np.float64(-11.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-415.0): 'obstruction',
#         np.float64(-414.0): 'obstruction',
#         np.float64(-413.0): {'Fx': {np.float64(-107.0): {'Fy': {np.float64(-45.0): {'Tx': {np.float64(70.0): {'Ty': {np.float64(-101.0): {'Tz': {np.float64(-12.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-411.0): 'obstruction',
#         np.float64(-408.0): 'obstruction',
#         np.float64(-406.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-20.0): {'Tx': {np.float64(63.0): {'Ty': {np.float64(68.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-405.0): 'bottom_obstruction',
#         np.float64(-404.0): 'obstruction',
#         np.float64(-399.0): 'obstruction',
#         np.float64(-398.0): 'obstruction',
#         np.float64(-396.0): 'obstruction',
#         np.float64(-394.0): 'fr_collision',
#         np.float64(-386.0): 'obstruction',
#         np.float64(-380.0): 'obstruction',
#         np.float64(-378.0): 'obstruction',
#         np.float64(-371.0): 'bottom_obstruction',
#         np.float64(-368.0): 'obstruction',
#         np.float64(-364.0): 'obstruction',
#         np.float64(-359.0): {'Fx': {np.float64(-27.0): {'Fy': {np.float64(-28.0): {'Tx': {np.float64(-2.0): {'Ty': {np.float64(5.0): {'Tz': {np.float64(-45.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(-18.0): 'obstruction'}},
#         np.float64(-355.0): 'bottom_collision',
#         np.float64(-353.0): 'obstruction',
#         np.float64(-348.0): 'obstruction',
#         np.float64(-346.0): 'obstruction',
#         np.float64(-345.0): {'Fx': {np.float64(-81.0): 'collision',
#                                     np.float64(-15.0): 'obstruction',
#                                     np.float64(5.0): 'obstruction'}},
#         np.float64(-343.0): 'obstruction',
#         np.float64(-342.0): 'obstruction',
#         np.float64(-341.0): 'obstruction',
#         np.float64(-338.0): 'obstruction',
#         np.float64(-336.0): 'obstruction',
#         np.float64(-335.0): 'obstruction',
#         np.float64(-332.0): {'Fx': {np.float64(-52.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(49.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(49.0): 'obstruction',
#                                     np.float64(59.0): 'bottom_collision'}},
#         np.float64(-331.0): 'obstruction',
#         np.float64(-328.0): {'Fx': {np.float64(-16.0): 'fr_collision',
#                                     np.float64(49.0): 'obstruction'}},
#         np.float64(-325.0): 'obstruction',
#         np.float64(-324.0): 'obstruction',
#         np.float64(-323.0): 'obstruction',
#         np.float64(-322.0): 'obstruction',
#         np.float64(-316.0): {'Fx': {np.float64(45.0): {'Fy': {np.float64(-71.0): {'Tx': {np.float64(62.0): {'Ty': {np.float64(-79.0): {'Tz': {np.float64(25.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-313.0): {'Fx': {np.float64(-20.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(-20.0): {'Ty': {np.float64(11.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(53.0): 'obstruction'}},
#         np.float64(-305.0): 'obstruction',
#         np.float64(-303.0): 'fr_collision',
#         np.float64(-302.0): {'Fx': {np.float64(-272.0): {'Fy': {np.float64(-227.0): {'Tx': {np.float64(173.0): {'Ty': {np.float64(-413.0): {'Tz': {np.float64(-49.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(43.0): {'Fy': {np.float64(-46.0): {'Tx': {np.float64(35.0): {'Ty': {np.float64(-76.0): {'Tz': {np.float64(6.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-301.0): 'obstruction',
#         np.float64(-300.0): 'obstruction',
#         np.float64(-297.0): 'obstruction',
#         np.float64(-296.0): 'obstruction',
#         np.float64(-294.0): 'obstruction',
#         np.float64(-293.0): {'Fx': {np.float64(44.0): {'Fy': {np.float64(-38.0): {'Tx': {np.float64(-17.0): {'Ty': {np.float64(-75.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-291.0): 'obstruction',
#         np.float64(-284.0): {'Fx': {np.float64(38.0): {'Fy': {np.float64(-64.0): {'Tx': {np.float64(63.0): {'Ty': {np.float64(-78.0): {'Tz': {np.float64(32.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-278.0): 'fr_collision',
#         np.float64(-276.0): 'obstruction',
#         np.float64(-273.0): {'Fx': {np.float64(-71.0): 'obstruction',
#                                     np.float64(41.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-19.0): {'Ty': {np.float64(33.0): {'Tz': {np.float64(-9.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-270.0): {'Fx': {np.float64(-16.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(-97.0): {'Ty': {np.float64(-3.0): {'Tz': {np.float64(-26.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-264.0): 'obstruction',
#         np.float64(-261.0): {'Fx': {np.float64(54.0): {'Fy': {np.float64(-22.0): {'Tx': {np.float64(-16.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(-6.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-257.0): 'obstruction',
#         np.float64(-256.0): {'Fx': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(45.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(-8.0): {'Ty': {np.float64(-55.0): {'Tz': {np.float64(0.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-254.0): 'obstruction',
#         np.float64(-250.0): {'Fx': {np.float64(51.0): {'Fy': {np.float64(-19.0): {'Tx': {np.float64(-22.0): {'Ty': {np.float64(-21.0): {'Tz': {np.float64(-7.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-248.0): 'obstruction',
#         np.float64(-246.0): 'obstruction',
#         np.float64(-244.0): {'Fx': {np.float64(10.0): {'Fy': {np.float64(-75.0): {'Tx': {np.float64(108.0): {'Ty': {np.float64(-136.0): {'Tz': {np.float64(48.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-243.0): 'obstruction',
#         np.float64(-242.0): 'obstruction',
#         np.float64(-240.0): {'Fx': {np.float64(15.0): {'Fy': {np.float64(2.0): {'Tx': {np.float64(36.0): {'Ty': {np.float64(38.0): {'Tz': {np.float64(0.0): 'collision'}}}}}}}}}},
#         np.float64(-239.0): 'obstruction',
#         np.float64(-235.0): 'fr_collision',
#         np.float64(-234.0): 'obstruction',
#         np.float64(-233.0): 'bottom_obstruction',
#         np.float64(-227.0): 'obstruction',
#         np.float64(-224.0): {'Fx': {np.float64(28.0): {'Fy': {np.float64(-42.0): {'Tx': {np.float64(-41.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(8.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-222.0): 'bottom_collision',
#         np.float64(-218.0): 'obstruction',
#         np.float64(-217.0): 'obstruction',
#         np.float64(-216.0): {'Fx': {np.float64(-15.0): 'fr_collision',
#                                     np.float64(-8.0): 'obstruction',
#                                     np.float64(33.0): {'Fy': {np.float64(-37.0): {'Tx': {np.float64(-33.0): {'Ty': {np.float64(-46.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(37.0): {'Fy': {np.float64(-33.0): {'Tx': {np.float64(-64.0): {'Ty': {np.float64(-74.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-215.0): 'obstruction',
#         np.float64(-214.0): 'obstruction',
#         np.float64(-213.0): 'obstruction',
#         np.float64(-210.0): {'Fx': {np.float64(-28.0): {'Fy': {np.float64(-20.0): {'Tx': {np.float64(37.0): {'Ty': {np.float64(-59.0): {'Tz': {np.float64(-1.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(-8.0): 'obstruction',
#                                     np.float64(3.0): {'Fy': {np.float64(-14.0): {'Tx': {np.float64(26.0): {'Ty': {np.float64(11.0): {'Tz': {np.float64(-68.0): 'collision'}}}}}}}}}},
#         np.float64(-209.0): {'Fx': {np.float64(38.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(-56.0): {'Tz': {np.float64(-10.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-208.0): {'Fx': {np.float64(-29.0): 'obstruction',
#                                     np.float64(36.0): {'Fy': {np.float64(-39.0): {'Tx': {np.float64(-32.0): {'Ty': {np.float64(-72.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-207.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(7.0): {'Ty': {np.float64(37.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-205.0): 'obstruction',
#         np.float64(-203.0): 'bottom_collision',
#         np.float64(-201.0): {'Fx': {np.float64(-9.0): {'Fy': {np.float64(0.0): {'Tx': {np.float64(-70.0): {'Ty': {np.float64(-6.0): {'Tz': {np.float64(-25.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(35.0): 'bottom_collision'}},
#         np.float64(-199.0): 'obstruction',
#         np.float64(-197.0): 'obstruction',
#         np.float64(-196.0): {'Fx': {np.float64(31.0): {'Fy': {np.float64(-38.0): {'Tx': {np.float64(-28.0): {'Ty': {np.float64(-71.0): {'Tz': {np.float64(7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-195.0): {'Fx': {np.float64(-29.0): 'bottom_collision',
#                                     np.float64(-12.0): 'fr_collision',
#                                     np.float64(36.0): 'collision'}},
#         np.float64(-193.0): {'Fx': {np.float64(-39.0): 'bottom_collision',
#                                     np.float64(-33.0): 'collision',
#                                     np.float64(13.0): 'collision'}},
#         np.float64(-192.0): 'obstruction',
#         np.float64(-191.0): {'Fx': {np.float64(9.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(18.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-189.0): 'obstruction',
#         np.float64(-185.0): {'Fx': {np.float64(-21.0): 'obstruction',
#                                     np.float64(3.0): 'bottom_collision'}},
#         np.float64(-182.0): {'Fx': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(13.0): 'bottom_collision'}},
#         np.float64(-181.0): 'fr_collision',
#         np.float64(-180.0): {'Fx': {np.float64(8.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-14.0): {'Ty': {np.float64(21.0): {'Tz': {np.float64(1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-179.0): {'Tx': {np.float64(-44.0): {'Fx': {np.float64(14.0): {'Fy': {np.float64(-7.0): {'Ty': {np.float64(71.0): {'Tz': {np.float64(-18.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-13.0): {'Fx': {np.float64(8.0): {'Fy': {np.float64(-10.0): {'Ty': {np.float64(21.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-11.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-10.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(4.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-178.0): {'Fy': {np.float64(-19.0): {'Fx': {np.float64(29.0): {'Tx': {np.float64(-71.0): {'Ty': {np.float64(-70.0): {'Tz': {np.float64(-8.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-16.0): 'bottom_collision',
#                                     np.float64(-11.0): 'bottom_collision',
#                                     np.float64(13.0): {'Fx': {np.float64(8.0): {'Tx': {np.float64(-17.0): {'Ty': {np.float64(10.0): {'Tz': {np.float64(2.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-177.0): {'Fx': {np.float64(19.0): 'obstruction',
#                                     np.float64(29.0): 'collision'}},
#         np.float64(-176.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(-13.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(1.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-172.0): 'collision',
#         np.float64(-171.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(6.0): {'Ty': {np.float64(9.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-170.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-10.0): {'Tx': {np.float64(-13.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(6.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(16.0): {'Fy': {np.float64(-39.0): {'Tx': {np.float64(-20.0): {'Ty': {np.float64(-116.0): {'Tz': {np.float64(17.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-169.0): {'Fx': {np.float64(-7.0): 'obstruction',
#                                     np.float64(1.0): {'Fy': {np.float64(-25.0): {'Tx': {np.float64(-7.0): {'Ty': {np.float64(-21.0): {'Tz': {np.float64(5.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(7.0): {'Fy': {np.float64(-9.0): {'Tx': {np.float64(-12.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(4.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(24.0): {'Fy': {np.float64(-34.0): {'Tx': {np.float64(-38.0): {'Ty': {np.float64(-93.0): {'Tz': {np.float64(10.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-165.0): {'Ty': {np.float64(-101.0): {'Fx': {np.float64(17.0): {'Fy': {np.float64(-32.0): {'Tx': {np.float64(-32.0): {'Tz': {np.float64(15.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(18.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(-9.0): {'Tx': {np.float64(-13.0): {'Tz': {np.float64(4.0): 'collision'}}}}}}}},
#                                     np.float64(23.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-8.0): {'Tx': {np.float64(9.0): {'Tz': {np.float64(-5.0): 'collision'}}}}}}}},
#                                     np.float64(24.0): 'collision_in_part'}},
#         np.float64(-164.0): {'Fx': {np.float64(5.0): 'collision_in_part',
#                                     np.float64(24.0): {'Fy': {np.float64(-36.0): {'Tx': {np.float64(-36.0): {'Ty': {np.float64(-96.0): {'Tz': {np.float64(12.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-163.0): {'Fx': {np.float64(-17.0): {'Fy': {np.float64(-30.0): {'Tx': {np.float64(-115.0): {'Ty': {np.float64(33.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-10.0): {'Fy': {np.float64(18.0): {'Tx': {np.float64(108.0): {'Ty': {np.float64(22.0): {'Tz': {np.float64(-11.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(70.0): 'obstruction'}},
#         np.float64(-160.0): 'bottom_obstruction',
#         np.float64(-159.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(1.0): {'Tx': {np.float64(9.0): {'Ty': {np.float64(4.0): {'Tz': {np.float64(2.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-157.0): 'obstruction',
#         np.float64(-156.0): {'Fx': {np.float64(23.0): {'Fy': {np.float64(-29.0): {'Tx': {np.float64(-45.0): {'Ty': {np.float64(-91.0): {'Tz': {np.float64(11.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-155.0): {'Fx': {np.float64(-29.0): 'bottom_collision',
#                                     np.float64(-12.0): 'fr_collision'}},
#         np.float64(-152.0): 'obstruction',
#         np.float64(-150.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(10.0): {'Ty': {np.float64(15.0): {'Tz': {np.float64(-6.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(8.0): 'obstruction'}},
#         np.float64(-149.0): 'obstruction',
#         np.float64(-146.0): 'obstruction',
#         np.float64(-144.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-14.0): {'Tx': {np.float64(17.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(-3.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-142.0): {'Fx': {np.float64(-29.0): {'Fy': {np.float64(5.0): {'Tx': {np.float64(77.0): {'Ty': {np.float64(115.0): {'Tz': {np.float64(-20.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(-11.0): 'fr_collision'}},
#         np.float64(-141.0): 'bottom_collision',
#         np.float64(-140.0): {'Fx': {np.float64(5.0): {'Fy': {np.float64(-19.0): {'Tx': {np.float64(27.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}},
#                                                              np.float64(-18.0): {'Tx': {np.float64(27.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-139.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Ty': {np.float64(15.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(17.0): 'fr_collision',
#                                     np.float64(20.0): 'obstruction'}},
#         np.float64(-138.0): {'Ty': {np.float64(-14.0): 'fr_collision',
#                                     np.float64(15.0): {'Fx': {np.float64(4.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}},
#                                                               np.float64(5.0): {'Fy': {np.float64(-18.0): {'Tx': {np.float64(26.0): {'Tz': {np.float64(-7.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(16.0): 'bottom_collision',
#                                     np.float64(23.0): {'Fx': {np.float64(7.0): {'Fy': {np.float64(-16.0): {'Tx': {np.float64(29.0): {'Tz': {np.float64(-3.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-136.0): {'Tx': {np.float64(-145.0): 'fr_collision',
#                                     np.float64(15.0): 'collision',
#                                     np.float64(17.0): 'bottom_collision'}},
#         np.float64(-135.0): {'Fx': {np.float64(-4.0): 'collision',
#                                     np.float64(5.0): {'Fy': {np.float64(-11.0): {'Tx': {np.float64(16.0): {'Ty': {np.float64(10.0): {'Tz': {np.float64(3.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(60.0): 'obstruction'}},
#         np.float64(-134.0): {'Fx': {np.float64(-5.0): {'Fy': {np.float64(-6.0): {'Tx': {np.float64(-54.0): {'Ty': {np.float64(-10.0): {'Tz': {np.float64(-23.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-133.0): {'Fx': {np.float64(-12.0): 'fr_collision',
#                                     np.float64(-2.0): {'Fy': {np.float64(-6.0): {'Tx': {np.float64(-40.0): {'Ty': {np.float64(-8.0): {'Tz': {np.float64(-18.0): 'collision'}}}}}}}},
#                                     np.float64(6.0): {'Fy': {np.float64(-16.0): {'Tx': {np.float64(32.0): {'Ty': {np.float64(19.0): {'Tz': {np.float64(0.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-131.0): 'bottom_collision',
#         np.float64(-128.0): {'Fx': {np.float64(6.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(29.0): {'Ty': {np.float64(18.0): {'Tz': {np.float64(-2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-127.0): 'obstruction',
#         np.float64(-125.0): {'Fx': {np.float64(-23.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(89.0): {'Ty': {np.float64(106.0): {'Tz': {np.float64(-21.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(12.0): {'Fy': {np.float64(18.0): {'Tx': {np.float64(37.0): {'Ty': {np.float64(16.0): {'Tz': {np.float64(9.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(17.0): {'Fy': {np.float64(11.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-25.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-124.0): 'obstruction',
#         np.float64(-122.0): {'Fx': {np.float64(-11.0): {'Fy': {np.float64(-26.0): {'Tx': {np.float64(68.0): {'Ty': {np.float64(147.0): {'Tz': {np.float64(-13.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(36.0): {'Fy': {np.float64(2.0): {'Tx': {np.float64(10.0): {'Ty': {np.float64(12.0): {'Tz': {np.float64(5.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-120.0): 'obstruction',
#         np.float64(-119.0): 'obstruction',
#         np.float64(-118.0): 'obstruction',
#         np.float64(-117.0): 'obstruction',
#         np.float64(-116.0): 'obstruction',
#         np.float64(-115.0): 'obstruction',
#         np.float64(-114.0): 'fr_collision',
#         np.float64(-113.0): {'Fx': {np.float64(3.0): 'obstruction',
#                                     np.float64(16.0): 'fr_collision',
#                                     np.float64(18.0): 'obstruction'}},
#         np.float64(-112.0): {'Fx': {np.float64(-1.0): 'obstruction',
#                                     np.float64(1.0): 'obstruction',
#                                     np.float64(6.0): {'Fy': {np.float64(-12.0): {'Tx': {np.float64(15.0): {'Ty': {np.float64(-3.0): {'Tz': {np.float64(15.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(15.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(-48.0): {'Ty': {np.float64(46.0): {'Tz': {np.float64(-2.0): 'bottom_collision'}}}}}}}},
#                                     np.float64(18.0): 'collision'}},
#         np.float64(-111.0): 'obstruction',
#         np.float64(-110.0): 'obstruction',
#         np.float64(-109.0): 'collision',
#         np.float64(-108.0): {'Fx': {np.float64(4.0): 'obstruction',
#                                     np.float64(23.0): {'Fy': {np.float64(29.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(41.0): {'Tz': {np.float64(11.0): 'bottom_obstruction'}}}}}}}},
#                                     np.float64(33.0): {'Fy': {np.float64(0.0): {'Tx': {np.float64(21.0): {'Ty': {np.float64(7.0): {'Tz': {np.float64(8.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-107.0): 'obstruction',
#         np.float64(-106.0): 'bottom_collision',
#         np.float64(-104.0): 'obstruction',
#         np.float64(-103.0): 'obstruction',
#         np.float64(-101.0): {'Fx': {np.float64(-41.0): 'fr_collision',
#                                     np.float64(5.0): 'obstruction'}},
#         np.float64(-100.0): 'obstruction',
#         np.float64(-99.0): {'Fx': {np.float64(3.0): {'Fy': {np.float64(-5.0): {'Tx': {np.float64(7.0): {'Ty': {np.float64(12.0): {'Tz': {np.float64(-1.0): 'collision'}}}}}}}},
#                                    np.float64(14.0): 'fr_collision'}},
#         np.float64(-98.0): 'obstruction',
#         np.float64(-97.0): 'obstruction',
#         np.float64(-95.0): 'obstruction',
#         np.float64(-94.0): {'Fx': {np.float64(10.0): 'obstruction',
#                                    np.float64(16.0): 'fr_collision'}},
#         np.float64(-93.0): {'Fx': {np.float64(3.0): 'obstruction',
#                                    np.float64(25.0): {'Fy': {np.float64(10.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-7.0): {'Tz': {np.float64(0.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-91.0): {'Fx': {np.float64(4.0): 'obstruction',
#                                    np.float64(10.0): 'obstruction',
#                                    np.float64(17.0): 'fr_collision',
#                                    np.float64(37.0): {'Fy': {np.float64(22.0): {'Tx': {np.float64(-74.0): {'Ty': {np.float64(82.0): {'Tz': {np.float64(-8.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-90.0): {'Fx': {np.float64(-24.0): 'fr_collision',
#                                    np.float64(4.0): 'obstruction',
#                                    np.float64(7.0): 'obstruction',
#                                    np.float64(10.0): 'obstruction'}},
#         np.float64(-89.0): 'obstruction',
#         np.float64(-88.0): 'fr_collision',
#         np.float64(-87.0): {'Fx': {np.float64(8.0): 'obstruction',
#                                    np.float64(15.0): {'Fy': {np.float64(11.0): {'Tx': {np.float64(43.0): {'Ty': {np.float64(28.0): {'Tz': {np.float64(11.0): 'bottom_obstruction'}}}}}}}},
#                                    np.float64(24.0): 'collision'}},
#         np.float64(-85.0): {'Fx': {np.float64(2.0): 'bottom_collision',
#                                    np.float64(19.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-9.0): {'Ty': {np.float64(-16.0): {'Tz': {np.float64(-1.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-84.0): 'obstruction',
#         np.float64(-83.0): {'Fx': {np.float64(-35.0): 'fr_collision',
#                                    np.float64(16.0): 'fr_collision',
#                                    np.float64(45.0): 'obstruction'}},
#         np.float64(-81.0): 'collision',
#         np.float64(-78.0): 'obstruction',
#         np.float64(-77.0): 'obstruction',
#         np.float64(-76.0): {'Fx': {np.float64(-33.0): 'fr_collision',
#                                    np.float64(13.0): 'obstruction'}},
#         np.float64(-75.0): {'Fx': {np.float64(23.0): {'Fy': {np.float64(7.0): {'Tx': {np.float64(-6.0): {'Ty': {np.float64(-13.0): {'Tz': {np.float64(-1.0): 'bottom_obstruction'}}}}}}}}}},
#         np.float64(-74.0): {'Fx': {np.float64(-14.0): {'Fy': {np.float64(-4.0): {'Tx': {np.float64(19.0): {'Ty': {np.float64(-41.0): {'Tz': {np.float64(2.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-73.0): {'Fx': {np.float64(-2.0): {'Fy': {np.float64(-11.0): {'Tx': {np.float64(-4.0): {'Ty': {np.float64(54.0): {'Tz': {np.float64(-9.0): 'bottom_collision'}}}}}}}}}},
#         np.float64(-72.0): {'Fx': {np.float64(-5.0): {'Fy': {np.float64(-15.0): {'Tx': {np.float64(25.0): {'Ty': {np.float64(-20.0): {'Tz': {np.float64(-5.0): 'bottom_obstruction'}}}}}}}},
# ...
# Predicted: left_col, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: back_col
# Predicted: None, Actual: obstruction
# Predicted: collision_in_tool, Actual: collision
# Predicted: None, Actual: bottom_collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: back_col, Actual: left_col
# Predicted: None, Actual: fr_collision
# Predicted: collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: bottom_collision
# Predicted: None, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: None, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: None, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: obstruction, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: None, Actual: normal
# Predicted: back_col, Actual: front_col
# Predicted: back_col, Actual: normal
# Predicted: back_col, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: None, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: bottom_obstruction
# Predicted: fr_collision, Actual: collision
# Predicted: None, Actual: fr_collision
# Predicted: normal, Actual: back_col
# Predicted: back_col, Actual: left_col
# Predicted: None, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: None, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: left_col, Actual: collision_in_part
# Predicted: bottom_collision, Actual: collision
# Predicted: None, Actual: collision_in_part
# Predicted: obstruction, Actual: obstruction
# Predicted: None, Actual: bottom_obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_tool
# Predicted: None, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: None, Actual: bottom_collision
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: front_col
# Predicted: normal, Actual: normal
# Predicted: None, Actual: collision
# Predicted: back_col, Actual: right_col
# Predicted: back_col, Actual: left_col
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: None, Actual: collision_in_part
# Predicted: back_col, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: bottom_collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: normal, Actual: fr_collision
# Predicted: None, Actual: collision
# Predicted: None, Actual: normal
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: None, Actual: obstruction
# Predicted: collision_in_part, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: back_col
# Predicted: None, Actual: collision
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: collision
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: normal
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: back_col, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: collision
# Predicted: bottom_collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: None, Actual: fr_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: obstruction
# Predicted: None, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: back_col, Actual: front_col
# Predicted: collision_in_tool, Actual: collision
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: bottom_collision
# Predicted: None, Actual: collision_in_part
# Predicted: collision_in_part, Actual: front_col
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: None, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: None, Actual: collision_in_part
# Predicted: None, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: back_col, Actual: back_col
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: collision
# Predicted: None, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: None, Actual: obstruction
# Predicted: obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_part
# Predicted: collision_in_part, Actual: back_col
# Predicted: None, Actual: obstruction
# Predicted: None, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision_in_tool, Actual: right_col
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_tool
# Predicted: None, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_tool
# Predicted: back_col, Actual: collision_in_tool
# Predicted: back_col, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: back_col
# Predicted: collision_in_part, Actual: back_col
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_part, Actual: collision
# Predicted: collision, Actual: collision
# Predicted: None, Actual: right_col
# Predicted: normal, Actual: normal
# Predicted: None, Actual: bottom_collision
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: collision
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: left_col
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: None, Actual: obstruction
# Predicted: normal, Actual: normal
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: collision_in_tool
# Predicted: None, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: collision
# Predicted: normal, Actual: fr_collision
# Predicted: fr_collision, Actual: collision
# Predicted: None, Actual: collision
# Predicted: None, Actual: fr_collision
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: back_col, Actual: collision_in_part
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: None, Actual: bottom_obstruction
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: None, Actual: obstruction
# Predicted: collision, Actual: collision_in_part
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_tool, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: bottom_obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: back_col
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision, Actual: collision_in_tool
# Predicted: collision_in_tool, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: None, Actual: collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: back_col
# Predicted: fr_collision, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: back_col
# Predicted: None, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: normal, Actual: back_col
# Predicted: None, Actual: normal
# Predicted: normal, Actual: collision
# Predicted: None, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: None, Actual: bottom_collision
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: None, Actual: collision_in_tool
# Predicted: None, Actual: fr_collision
# Predicted: None, Actual: fr_collision
# Predicted: collision, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: None, Actual: normal
# Predicted: None, Actual: obstruction
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: bottom_collision
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: back_col
# Predicted: None, Actual: collision
# Predicted: None, Actual: normal
# Predicted: collision, Actual: collision_in_part
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_tool
# Predicted: normal, Actual: normal
# Predicted: collision, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: None, Actual: back_col
# Predicted: collision_in_tool, Actual: collision
# Predicted: fr_collision, Actual: fr_collision
# Predicted: normal, Actual: normal
# Predicted: bottom_collision, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: front_col
# Predicted: collision_in_part, Actual: collision
# Predicted: obstruction, Actual: bottom_obstruction
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: None, Actual: obstruction
# Predicted: front_col, Actual: back_col
# Predicted: back_col, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: None, Actual: bottom_collision
# Predicted: back_col, Actual: normal
# Predicted: collision_in_part, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: obstruction, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_tool, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: left_col, Actual: back_col
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: bottom_collision
# Predicted: normal, Actual: normal
# Predicted: bottom_obstruction, Actual: bottom_obstruction
# Predicted: None, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: bottom_obstruction, Actual: obstruction
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: fr_collision
# Predicted: back_col, Actual: front_col
# Predicted: None, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: None, Actual: normal
# Predicted: back_col, Actual: left_col
# Predicted: collision, Actual: obstruction
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: back_col
# Predicted: collision_in_part, Actual: back_col
# Predicted: None, Actual: obstruction
# Predicted: normal, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: back_col, Actual: collision_in_tool
# Predicted: collision, Actual: bottom_collision
# Predicted: bottom_collision, Actual: collision
# Predicted: collision_in_part, Actual: collision
# Predicted: back_col, Actual: normal
# Predicted: None, Actual: obstruction
# Predicted: collision, Actual: bottom_collision
# Predicted: back_col, Actual: collision_in_part
# Predicted: normal, Actual: normal
# Predicted: left_col, Actual: back_col
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: back_col
# Predicted: None, Actual: obstruction
# Predicted: back_col, Actual: left_col
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: collision_in_part, Actual: collision
# Predicted: collision_in_tool, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: None, Actual: collision_in_part
# Predicted: collision_in_tool, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: None, Actual: collision
# Predicted: collision, Actual: bottom_collision
# Predicted: collision, Actual: collision_in_part
# Predicted: collision_in_part, Actual: collision
# Predicted: None, Actual: collision
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: normal, Actual: normal
# Predicted: obstruction, Actual: obstruction
#
# Accuracy: 57.34%
#
# Test Accuracy: 57.34%
